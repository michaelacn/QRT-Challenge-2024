# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn import model_selection
from sklearn.metrics import accuracy_score
import xgboost as xgb
import warnings
import matplotlib.pyplot as plt
from pathlib import Path

warnings.filterwarnings('ignore')
# Out:
# /Users/maichoun/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
PROJ_ROOT = Path("QRT-Challenge-2024").resolve().parents[1]
DATA_DIR = PROJ_ROOT / "data"
RAW_DATA_DIR = DATA_DIR / "raw"

# %% [markdown]
# ## Read Train data

# %%
train_home_team_statistics_df = pd.read_csv(RAW_DATA_DIR / "train_home_team_statistics_df.csv", index_col=0)
train_away_team_statistics_df = pd.read_csv(RAW_DATA_DIR / "train_away_team_statistics_df.csv", index_col=0)
train_scores = pd.read_csv(RAW_DATA_DIR / "Y_train.csv", index_col=0)

train_home = train_home_team_statistics_df.iloc[:,2:]
train_away = train_away_team_statistics_df.iloc[:,2:]

train_home.columns = 'HOME_' + train_home.columns
train_away.columns = 'AWAY_' + train_away.columns

train_data =  pd.concat([train_home,train_away],join='inner',axis=1)
train_scores = train_scores.loc[train_data.index]

train_data = train_data.replace({np.inf:np.nan,-np.inf:np.nan})

# %%
train_home_team_statistics_df.head()
# Out:
#             LEAGUE                TEAM_NAME  TEAM_SHOTS_TOTAL_season_sum  \
# ID
# 0          Ligue 1                 Toulouse                          3.0
# 1          Ligue 2                    Brest                          6.0
# 2          Serie A                Sampdoria                          4.0
# 3       League One            Coventry City                          7.0
# 4   Premier League  Wolverhampton Wanderers                          3.0
#
#     TEAM_SHOTS_INSIDEBOX_season_sum  TEAM_SHOTS_OFF_TARGET_season_sum  \
# ID
# 0                               2.0                               5.0
# 1                               8.0                               3.0
# 2                               2.0                               5.0
# 3                               5.0                               5.0
# 4                               3.0                               2.0
#
#     TEAM_SHOTS_ON_TARGET_season_sum  TEAM_SHOTS_OUTSIDEBOX_season_sum  \
# ID
# 0                               2.0                               1.0
# 1                               6.0                               5.0
# 2                               2.0                               8.0
# 3                               6.0                               6.0
# 4                               3.0                               4.0
#
#     TEAM_PASSES_season_sum  TEAM_SUCCESSFUL_PASSES_season_sum  \
# ID
# 0                      2.0                                2.0
# 1                      8.0                                7.0
# 2                      1.0                                1.0
# 3                      9.0                                9.0
# 4                      4.0                                3.0
#
#     TEAM_SAVES_season_sum  ...  TEAM_YELLOWCARDS_5_last_match_std  \
# ID                         ...
# 0                     5.0  ...                                3.0
# 1                    10.0  ...                                4.0
# 2                     2.0  ...                                4.0
# 3                     2.0  ...                                4.0
# 4                     4.0  ...                                1.0
#
#     TEAM_REDCARDS_5_last_match_std  TEAM_OFFSIDES_5_last_match_std  \
# ID
# 0                              0.0                             6.0
# 1                              0.0                             4.0
# 2                              5.0                             6.0
# 3                              0.0                             1.0
# 4                              0.0                             2.0
#
#     TEAM_ATTACKS_5_last_match_std  TEAM_PENALTIES_5_last_match_std  \
# ID
# 0                             0.0                             10.0
# 1                             3.0                             10.0
# 2                             3.0                              6.0
# 3                             8.0                              8.0
# 4                             5.0                              8.0
#
#     TEAM_SUBSTITUTIONS_5_last_match_std  TEAM_BALL_SAFE_5_last_match_std  \
# ID
# 0                                   8.0                              7.0
# 1                                   0.0                              1.0
# 2                                   7.0                              2.0
# 3                                   5.0                              5.0
# 4                                   7.0                              2.0
#
#     TEAM_DANGEROUS_ATTACKS_5_last_match_std  TEAM_INJURIES_5_last_match_std  \
# ID
# 0                                       2.0                             4.0
# 1                                       2.0                             8.0
# 2                                       3.0                             2.0
# 3                                       5.0                             NaN
# 4                                       6.0                             4.0
#
#     TEAM_GOALS_5_last_match_std
# ID
# 0                           3.0
# 1                           4.0
# 2                           4.0
# 3                           6.0
# 4                           4.0
#
# [5 rows x 142 columns]

# %%
train_scores.head()
# Out:
#     HOME_WINS  DRAW  AWAY_WINS
# ID
# 0           0     0          1
# 1           0     1          0
# 2           0     0          1
# 3           1     0          0
# 4           0     1          0

# %% [markdown]
# ## Benchmark
#
# We try to model if AWAY wins

# %%
train_new_y = train_scores['AWAY_WINS']

# %% [markdown]
# ### train, valid test split

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(train_data, train_new_y, train_size=0.8, random_state=42)
X_train, X_valid, y_train, y_valid = model_selection.train_test_split(X_train, y_train, train_size=0.8, random_state=42)

# %% [markdown]
# ### xgb model

# %%
params_1 = {
    'booster': 'gbtree',
    'tree_method':'hist',
    'max_depth': 8, 
    'learning_rate': 0.025,
    'objective': 'multi:softprob',
    'num_class': 2,
    'eval_metric':'mlogloss'
    }


d_train = xgb.DMatrix(X_train.replace({0:np.nan}), y_train)
d_valid = xgb.DMatrix(X_valid.replace({0:np.nan}), y_valid)

num_round = 10000
evallist = [(d_train, 'train'), (d_valid, 'eval')]

bst = xgb.train(params_1, d_train, num_round, evallist, early_stopping_rounds=100)
# Out:
# [0]	train-mlogloss:0.68338	eval-mlogloss:0.68785
# [1]	train-mlogloss:0.67389	eval-mlogloss:0.68266
# [2]	train-mlogloss:0.66467	eval-mlogloss:0.67757
# [3]	train-mlogloss:0.65574	eval-mlogloss:0.67304
# [4]	train-mlogloss:0.64724	eval-mlogloss:0.66849
# [5]	train-mlogloss:0.63894	eval-mlogloss:0.66438
# [6]	train-mlogloss:0.63052	eval-mlogloss:0.66062
# [7]	train-mlogloss:0.62230	eval-mlogloss:0.65697
# [8]	train-mlogloss:0.61454	eval-mlogloss:0.65359
# [9]	train-mlogloss:0.60701	eval-mlogloss:0.65015
# [10]	train-mlogloss:0.59949	eval-mlogloss:0.64682
# [11]	train-mlogloss:0.59224	eval-mlogloss:0.64347
# [12]	train-mlogloss:0.58520	eval-mlogloss:0.64026
# [13]	train-mlogloss:0.57876	eval-mlogloss:0.63741
# [14]	train-mlogloss:0.57188	eval-mlogloss:0.63467
# [15]	train-mlogloss:0.56536	eval-mlogloss:0.63191
# [16]	train-mlogloss:0.55888	eval-mlogloss:0.62946
# [17]	train-mlogloss:0.55254	eval-mlogloss:0.62681
# [18]	train-mlogloss:0.54669	eval-mlogloss:0.62444
# [19]	train-mlogloss:0.54078	eval-mlogloss:0.62231
# [20]	train-mlogloss:0.53480	eval-mlogloss:0.62011
# [21]	train-mlogloss:0.52936	eval-mlogloss:0.61779
# [22]	train-mlogloss:0.52361	eval-mlogloss:0.61583
# [23]	train-mlogloss:0.51836	eval-mlogloss:0.61384
# [24]	train-mlogloss:0.51311	eval-mlogloss:0.61174
# [25]	train-mlogloss:0.50791	eval-mlogloss:0.60963
# [26]	train-mlogloss:0.50283	eval-mlogloss:0.60765
# [27]	train-mlogloss:0.49785	eval-mlogloss:0.60627
# [28]	train-mlogloss:0.49317	eval-mlogloss:0.60491
# [29]	train-mlogloss:0.48820	eval-mlogloss:0.60316
# [30]	train-mlogloss:0.48328	eval-mlogloss:0.60168
# [31]	train-mlogloss:0.47863	eval-mlogloss:0.60012
# [32]	train-mlogloss:0.47402	eval-mlogloss:0.59886
# [33]	train-mlogloss:0.46950	eval-mlogloss:0.59719
# [34]	train-mlogloss:0.46521	eval-mlogloss:0.59597
# [35]	train-mlogloss:0.46112	eval-mlogloss:0.59486
# [36]	train-mlogloss:0.45688	eval-mlogloss:0.59363
# [37]	train-mlogloss:0.45289	eval-mlogloss:0.59267
# [38]	train-mlogloss:0.44895	eval-mlogloss:0.59149
# [39]	train-mlogloss:0.44457	eval-mlogloss:0.59050
# [40]	train-mlogloss:0.44045	eval-mlogloss:0.58974
# [41]	train-mlogloss:0.43618	eval-mlogloss:0.58902
# [42]	train-mlogloss:0.43248	eval-mlogloss:0.58818
# [43]	train-mlogloss:0.42851	eval-mlogloss:0.58708
# [44]	train-mlogloss:0.42491	eval-mlogloss:0.58653
# [45]	train-mlogloss:0.42125	eval-mlogloss:0.58583
# [46]	train-mlogloss:0.41774	eval-mlogloss:0.58481
# [47]	train-mlogloss:0.41387	eval-mlogloss:0.58423
# [48]	train-mlogloss:0.41078	eval-mlogloss:0.58364
# [49]	train-mlogloss:0.40759	eval-mlogloss:0.58309
# [50]	train-mlogloss:0.40412	eval-mlogloss:0.58247
# [51]	train-mlogloss:0.40104	eval-mlogloss:0.58163
# [52]	train-mlogloss:0.39765	eval-mlogloss:0.58100
# [53]	train-mlogloss:0.39457	eval-mlogloss:0.58032
# [54]	train-mlogloss:0.39130	eval-mlogloss:0.57984
# [55]	train-mlogloss:0.38815	eval-mlogloss:0.57945
# [56]	train-mlogloss:0.38517	eval-mlogloss:0.57893
# [57]	train-mlogloss:0.38206	eval-mlogloss:0.57864
# [58]	train-mlogloss:0.37892	eval-mlogloss:0.57818
# [59]	train-mlogloss:0.37625	eval-mlogloss:0.57765
# [60]	train-mlogloss:0.37310	eval-mlogloss:0.57745
# [61]	train-mlogloss:0.37014	eval-mlogloss:0.57723
# [62]	train-mlogloss:0.36735	eval-mlogloss:0.57666
# [63]	train-mlogloss:0.36433	eval-mlogloss:0.57632
# [64]	train-mlogloss:0.36121	eval-mlogloss:0.57565
# [65]	train-mlogloss:0.35871	eval-mlogloss:0.57544
# [66]	train-mlogloss:0.35619	eval-mlogloss:0.57519
# [67]	train-mlogloss:0.35362	eval-mlogloss:0.57479
# [68]	train-mlogloss:0.35051	eval-mlogloss:0.57465
# [69]	train-mlogloss:0.34796	eval-mlogloss:0.57424
# [70]	train-mlogloss:0.34566	eval-mlogloss:0.57414
# [71]	train-mlogloss:0.34325	eval-mlogloss:0.57377
# [72]	train-mlogloss:0.34098	eval-mlogloss:0.57385
# [73]	train-mlogloss:0.33867	eval-mlogloss:0.57362
# [74]	train-mlogloss:0.33623	eval-mlogloss:0.57313
# [75]	train-mlogloss:0.33367	eval-mlogloss:0.57271
# [76]	train-mlogloss:0.33142	eval-mlogloss:0.57254
# [77]	train-mlogloss:0.32929	eval-mlogloss:0.57253
# [78]	train-mlogloss:0.32720	eval-mlogloss:0.57246
# [79]	train-mlogloss:0.32494	eval-mlogloss:0.57205
# [80]	train-mlogloss:0.32277	eval-mlogloss:0.57205
# [81]	train-mlogloss:0.32058	eval-mlogloss:0.57174
# [82]	train-mlogloss:0.31856	eval-mlogloss:0.57151
# [83]	train-mlogloss:0.31673	eval-mlogloss:0.57132
# [84]	train-mlogloss:0.31437	eval-mlogloss:0.57136
# [85]	train-mlogloss:0.31230	eval-mlogloss:0.57122
# [86]	train-mlogloss:0.31057	eval-mlogloss:0.57100
# [87]	train-mlogloss:0.30847	eval-mlogloss:0.57072
# [88]	train-mlogloss:0.30649	eval-mlogloss:0.57067
# [89]	train-mlogloss:0.30466	eval-mlogloss:0.57062
# [90]	train-mlogloss:0.30264	eval-mlogloss:0.57064
# [91]	train-mlogloss:0.30034	eval-mlogloss:0.57052
# [92]	train-mlogloss:0.29852	eval-mlogloss:0.57025
# [93]	train-mlogloss:0.29667	eval-mlogloss:0.57020
# [94]	train-mlogloss:0.29490	eval-mlogloss:0.57009
# [95]	train-mlogloss:0.29291	eval-mlogloss:0.56991
# [96]	train-mlogloss:0.29116	eval-mlogloss:0.56995
# [97]	train-mlogloss:0.28905	eval-mlogloss:0.56976
# [98]	train-mlogloss:0.28690	eval-mlogloss:0.56961
# [99]	train-mlogloss:0.28515	eval-mlogloss:0.56978
# [100]	train-mlogloss:0.28347	eval-mlogloss:0.56978
# [101]	train-mlogloss:0.28176	eval-mlogloss:0.56978
# [102]	train-mlogloss:0.27984	eval-mlogloss:0.56968
# [103]	train-mlogloss:0.27789	eval-mlogloss:0.56986
# [104]	train-mlogloss:0.27643	eval-mlogloss:0.56984
# [105]	train-mlogloss:0.27434	eval-mlogloss:0.56966
# [106]	train-mlogloss:0.27290	eval-mlogloss:0.56953
# [107]	train-mlogloss:0.27107	eval-mlogloss:0.56969
# [108]	train-mlogloss:0.26961	eval-mlogloss:0.56970
# [109]	train-mlogloss:0.26805	eval-mlogloss:0.56948
# [110]	train-mlogloss:0.26659	eval-mlogloss:0.56929
# [111]	train-mlogloss:0.26463	eval-mlogloss:0.56943
# [112]	train-mlogloss:0.26335	eval-mlogloss:0.56948
# [113]	train-mlogloss:0.26141	eval-mlogloss:0.56926
# [114]	train-mlogloss:0.25989	eval-mlogloss:0.56921
# [115]	train-mlogloss:0.25859	eval-mlogloss:0.56927
# [116]	train-mlogloss:0.25681	eval-mlogloss:0.56922
# [117]	train-mlogloss:0.25540	eval-mlogloss:0.56922
# [118]	train-mlogloss:0.25398	eval-mlogloss:0.56929
# [119]	train-mlogloss:0.25234	eval-mlogloss:0.56918
# [120]	train-mlogloss:0.25065	eval-mlogloss:0.56923
# [121]	train-mlogloss:0.24932	eval-mlogloss:0.56930
# [122]	train-mlogloss:0.24786	eval-mlogloss:0.56934
# [123]	train-mlogloss:0.24655	eval-mlogloss:0.56972
# [124]	train-mlogloss:0.24529	eval-mlogloss:0.56987
# [125]	train-mlogloss:0.24362	eval-mlogloss:0.56999
# [126]	train-mlogloss:0.24237	eval-mlogloss:0.57013
# [127]	train-mlogloss:0.24093	eval-mlogloss:0.57013
# [128]	train-mlogloss:0.23937	eval-mlogloss:0.57028
# [129]	train-mlogloss:0.23824	eval-mlogloss:0.57037
# [130]	train-mlogloss:0.23692	eval-mlogloss:0.57040
# [131]	train-mlogloss:0.23577	eval-mlogloss:0.57055
# [132]	train-mlogloss:0.23460	eval-mlogloss:0.57070
# [133]	train-mlogloss:0.23335	eval-mlogloss:0.57066
# [134]	train-mlogloss:0.23214	eval-mlogloss:0.57065
# [135]	train-mlogloss:0.23055	eval-mlogloss:0.57062
# [136]	train-mlogloss:0.22910	eval-mlogloss:0.57049
# [137]	train-mlogloss:0.22791	eval-mlogloss:0.57046
# [138]	train-mlogloss:0.22656	eval-mlogloss:0.57032
# [139]	train-mlogloss:0.22521	eval-mlogloss:0.57061
# [140]	train-mlogloss:0.22386	eval-mlogloss:0.57042
# [141]	train-mlogloss:0.22252	eval-mlogloss:0.57028
# [142]	train-mlogloss:0.22084	eval-mlogloss:0.57013
# [143]	train-mlogloss:0.21947	eval-mlogloss:0.57003
# [144]	train-mlogloss:0.21802	eval-mlogloss:0.57017
# [145]	train-mlogloss:0.21696	eval-mlogloss:0.57029
# [146]	train-mlogloss:0.21576	eval-mlogloss:0.57025
# [147]	train-mlogloss:0.21459	eval-mlogloss:0.57025
# [148]	train-mlogloss:0.21359	eval-mlogloss:0.57020
# [149]	train-mlogloss:0.21227	eval-mlogloss:0.57006
# [150]	train-mlogloss:0.21101	eval-mlogloss:0.56980
# [151]	train-mlogloss:0.20928	eval-mlogloss:0.56969
# [152]	train-mlogloss:0.20823	eval-mlogloss:0.56966
# [153]	train-mlogloss:0.20697	eval-mlogloss:0.56930
# [154]	train-mlogloss:0.20587	eval-mlogloss:0.56936
# [155]	train-mlogloss:0.20468	eval-mlogloss:0.56924
# [156]	train-mlogloss:0.20367	eval-mlogloss:0.56932
# [157]	train-mlogloss:0.20279	eval-mlogloss:0.56911
# [158]	train-mlogloss:0.20123	eval-mlogloss:0.56933
# [159]	train-mlogloss:0.20005	eval-mlogloss:0.56895
# [160]	train-mlogloss:0.19890	eval-mlogloss:0.56884
# [161]	train-mlogloss:0.19797	eval-mlogloss:0.56885
# [162]	train-mlogloss:0.19703	eval-mlogloss:0.56892
# [163]	train-mlogloss:0.19590	eval-mlogloss:0.56893
# [164]	train-mlogloss:0.19480	eval-mlogloss:0.56891
# [165]	train-mlogloss:0.19338	eval-mlogloss:0.56882
# [166]	train-mlogloss:0.19254	eval-mlogloss:0.56889
# [167]	train-mlogloss:0.19129	eval-mlogloss:0.56854
# [168]	train-mlogloss:0.19041	eval-mlogloss:0.56851
# [169]	train-mlogloss:0.18934	eval-mlogloss:0.56867
# [170]	train-mlogloss:0.18827	eval-mlogloss:0.56846
# [171]	train-mlogloss:0.18683	eval-mlogloss:0.56837
# [172]	train-mlogloss:0.18580	eval-mlogloss:0.56860
# [173]	train-mlogloss:0.18485	eval-mlogloss:0.56868
# [174]	train-mlogloss:0.18373	eval-mlogloss:0.56875
# [175]	train-mlogloss:0.18290	eval-mlogloss:0.56876
# [176]	train-mlogloss:0.18175	eval-mlogloss:0.56878
# [177]	train-mlogloss:0.18071	eval-mlogloss:0.56891
# [178]	train-mlogloss:0.17942	eval-mlogloss:0.56898
# [179]	train-mlogloss:0.17835	eval-mlogloss:0.56892
# [180]	train-mlogloss:0.17758	eval-mlogloss:0.56900
# [181]	train-mlogloss:0.17679	eval-mlogloss:0.56899
# [182]	train-mlogloss:0.17585	eval-mlogloss:0.56913
# [183]	train-mlogloss:0.17475	eval-mlogloss:0.56923
# [184]	train-mlogloss:0.17395	eval-mlogloss:0.56928
# [185]	train-mlogloss:0.17295	eval-mlogloss:0.56960
# [186]	train-mlogloss:0.17215	eval-mlogloss:0.56940
# [187]	train-mlogloss:0.17142	eval-mlogloss:0.56950
# [188]	train-mlogloss:0.17034	eval-mlogloss:0.56941
# [189]	train-mlogloss:0.16941	eval-mlogloss:0.56938
# [190]	train-mlogloss:0.16856	eval-mlogloss:0.56959
# [191]	train-mlogloss:0.16759	eval-mlogloss:0.56952
# [192]	train-mlogloss:0.16641	eval-mlogloss:0.56932
# [193]	train-mlogloss:0.16569	eval-mlogloss:0.56928
# [194]	train-mlogloss:0.16484	eval-mlogloss:0.56949
# [195]	train-mlogloss:0.16404	eval-mlogloss:0.56958
# [196]	train-mlogloss:0.16303	eval-mlogloss:0.56979
# [197]	train-mlogloss:0.16204	eval-mlogloss:0.56979
# [198]	train-mlogloss:0.16096	eval-mlogloss:0.57007
# [199]	train-mlogloss:0.16015	eval-mlogloss:0.57016
# [200]	train-mlogloss:0.15942	eval-mlogloss:0.57023
# [201]	train-mlogloss:0.15874	eval-mlogloss:0.57037
# [202]	train-mlogloss:0.15772	eval-mlogloss:0.57014
# [203]	train-mlogloss:0.15679	eval-mlogloss:0.57002
# [204]	train-mlogloss:0.15592	eval-mlogloss:0.57010
# [205]	train-mlogloss:0.15515	eval-mlogloss:0.57006
# [206]	train-mlogloss:0.15430	eval-mlogloss:0.56997
# [207]	train-mlogloss:0.15337	eval-mlogloss:0.57033
# [208]	train-mlogloss:0.15276	eval-mlogloss:0.57044
# [209]	train-mlogloss:0.15174	eval-mlogloss:0.57067
# [210]	train-mlogloss:0.15086	eval-mlogloss:0.57053
# [211]	train-mlogloss:0.15016	eval-mlogloss:0.57066
# [212]	train-mlogloss:0.14926	eval-mlogloss:0.57073
# [213]	train-mlogloss:0.14830	eval-mlogloss:0.57072
# [214]	train-mlogloss:0.14761	eval-mlogloss:0.57089
# [215]	train-mlogloss:0.14683	eval-mlogloss:0.57097
# [216]	train-mlogloss:0.14613	eval-mlogloss:0.57123
# [217]	train-mlogloss:0.14552	eval-mlogloss:0.57133
# [218]	train-mlogloss:0.14500	eval-mlogloss:0.57148
# [219]	train-mlogloss:0.14418	eval-mlogloss:0.57157
# [220]	train-mlogloss:0.14362	eval-mlogloss:0.57177
# [221]	train-mlogloss:0.14301	eval-mlogloss:0.57189
# [222]	train-mlogloss:0.14217	eval-mlogloss:0.57190
# [223]	train-mlogloss:0.14139	eval-mlogloss:0.57199
# [224]	train-mlogloss:0.14043	eval-mlogloss:0.57184
# [225]	train-mlogloss:0.13986	eval-mlogloss:0.57185
# [226]	train-mlogloss:0.13908	eval-mlogloss:0.57201
# [227]	train-mlogloss:0.13832	eval-mlogloss:0.57204
# [228]	train-mlogloss:0.13752	eval-mlogloss:0.57215
# [229]	train-mlogloss:0.13686	eval-mlogloss:0.57222
# [230]	train-mlogloss:0.13622	eval-mlogloss:0.57231
# [231]	train-mlogloss:0.13567	eval-mlogloss:0.57243
# [232]	train-mlogloss:0.13504	eval-mlogloss:0.57251
# [233]	train-mlogloss:0.13430	eval-mlogloss:0.57267
# [234]	train-mlogloss:0.13362	eval-mlogloss:0.57274
# [235]	train-mlogloss:0.13287	eval-mlogloss:0.57279
# [236]	train-mlogloss:0.13239	eval-mlogloss:0.57293
# [237]	train-mlogloss:0.13165	eval-mlogloss:0.57300
# [238]	train-mlogloss:0.13092	eval-mlogloss:0.57319
# [239]	train-mlogloss:0.13036	eval-mlogloss:0.57335
# [240]	train-mlogloss:0.12955	eval-mlogloss:0.57369
# [241]	train-mlogloss:0.12896	eval-mlogloss:0.57381
# [242]	train-mlogloss:0.12849	eval-mlogloss:0.57387
# [243]	train-mlogloss:0.12794	eval-mlogloss:0.57387
# [244]	train-mlogloss:0.12735	eval-mlogloss:0.57395
# [245]	train-mlogloss:0.12666	eval-mlogloss:0.57382
# [246]	train-mlogloss:0.12586	eval-mlogloss:0.57393
# [247]	train-mlogloss:0.12534	eval-mlogloss:0.57409
# [248]	train-mlogloss:0.12480	eval-mlogloss:0.57430
# [249]	train-mlogloss:0.12419	eval-mlogloss:0.57439
# [250]	train-mlogloss:0.12363	eval-mlogloss:0.57459
# [251]	train-mlogloss:0.12311	eval-mlogloss:0.57486
# [252]	train-mlogloss:0.12245	eval-mlogloss:0.57488
# [253]	train-mlogloss:0.12180	eval-mlogloss:0.57509
# [254]	train-mlogloss:0.12130	eval-mlogloss:0.57529
# [255]	train-mlogloss:0.12076	eval-mlogloss:0.57556
# [256]	train-mlogloss:0.12016	eval-mlogloss:0.57558
# [257]	train-mlogloss:0.11933	eval-mlogloss:0.57592
# [258]	train-mlogloss:0.11872	eval-mlogloss:0.57595
# [259]	train-mlogloss:0.11821	eval-mlogloss:0.57613
# [260]	train-mlogloss:0.11750	eval-mlogloss:0.57638
# [261]	train-mlogloss:0.11675	eval-mlogloss:0.57621
# [262]	train-mlogloss:0.11606	eval-mlogloss:0.57643
# [263]	train-mlogloss:0.11553	eval-mlogloss:0.57662
# [264]	train-mlogloss:0.11487	eval-mlogloss:0.57675
# [265]	train-mlogloss:0.11425	eval-mlogloss:0.57679
# [266]	train-mlogloss:0.11368	eval-mlogloss:0.57708
# [267]	train-mlogloss:0.11300	eval-mlogloss:0.57722
# [268]	train-mlogloss:0.11246	eval-mlogloss:0.57758
# [269]	train-mlogloss:0.11193	eval-mlogloss:0.57763
# [270]	train-mlogloss:0.11145	eval-mlogloss:0.57762
# [271]	train-mlogloss:0.11106	eval-mlogloss:0.57775

# %% [markdown]
# ### Some analysis

# %%
xgb.plot_importance(bst, max_num_features=25)
fig = plt.gcf()
fig.set_size_inches(15, 20)

# %% [markdown]
# ### Accuracy on test set

# %% [markdown]
# A simple benchmark is always predicting home wins

# %%
target = train_scores.loc[X_test.index].copy()

home_wins = target
home_wins = 0 * home_wins
home_wins.iloc[:,0] = 1

np.round(accuracy_score(home_wins,target),4)
# Out:
# 0.4401

# %% [markdown]
# Using our model

# %%
X_test_xgb = xgb.DMatrix(X_test)

predictions = bst.predict(X_test_xgb, iteration_range=(0, bst.best_iteration))
predictions = pd.DataFrame(predictions)

predictions[2] = 0
predictions.columns = [0,2,1]
predictions = (predictions.reindex(columns=[0,1,2]).rank(1,ascending=False)==1).astype(int).values
np.round(accuracy_score(predictions,target),4)
# Out:
# 0.4742

# %% [markdown]
# ## Submission

# %%
test_home = pd.read_csv(RAW_DATA_DIR / "test_home_team_statistics_df.csv", index_col=0)
test_away = pd.read_csv(RAW_DATA_DIR / "test_away_team_statistics_df.csv", index_col=0)

test_home.columns = 'HOME_' + test_home.columns
test_away.columns = 'AWAY_' + test_away.columns

test_data = pd.concat([test_home,test_away], join='inner', axis=1)

# %%
# X_bench = xgb.DMatrix(test_data)

# predictions = bst.predict(X_bench, iteration_range=(0, bst.best_iteration))
# predictions = pd.DataFrame(predictions)

# predictions[2] = 0
# predictions.columns = [0,2,1]
# predictions = (predictions.reindex(columns=[0,1,2]).rank(1,ascending=False)==1).astype(int)

# predictions.columns = ['HOME_WINS', 'DRAW', 'AWAY_WINS']
# predictions.index = test_data.index
# submission = predictions.reset_index()
# submission.to_csv('./datas_final/benchmark_submission.csv', index=False)
