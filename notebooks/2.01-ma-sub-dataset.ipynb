# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
elif PROJECT_ROOT.name.startswith("0"):
    PROJECT_ROOT = PROJECT_ROOT.parent.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from pathlib import Path
from sklearn import model_selection
import xgboost as xgb

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from match_forecast.utils import *

# %%
PROJ_ROOT = Path("QRT-Challenge-2024").resolve().parents[1]
DATA_DIR = PROJ_ROOT / "data"
RAW_DATA_DIR = DATA_DIR / "raw"
PROCESSED_DATA_DIR = DATA_DIR / "processed"

# %%
try:
    test_home_team_statistics_df = pd.read_csv(RAW_DATA_DIR / "test_home_team_statistics_df.csv", index_col=0)
    test_away_team_statistics_df = pd.read_csv(RAW_DATA_DIR / "test_away_team_statistics_df.csv", index_col=0)
    print("Files loaded")
    
except FileNotFoundError as e:
    print(e)
# Out:
# Files loaded

# %%
home_teams = test_home_team_statistics_df
away_teams = test_away_team_statistics_df

# Rename
home_teams.columns = 'HOME_' + home_teams.columns
away_teams.columns = 'AWAY_' + away_teams.columns

test_data_teams = pd.concat([home_teams, away_teams], join='inner', axis=1)
test_data_teams = test_data_teams.apply(replace_null_values)

print(test_data_teams.shape)
# Out:
# (25368, 280)

# %%
test_data_teams = test_data_teams.fillna(test_data_teams.select_dtypes(include=['number']).median())

# %%
### DIFFERENCES
# Get the list of HOME and AWAY columns
home_columns = [col for col in test_data_teams.columns if col.startswith('HOME_TEAM_')]
away_columns = [col for col in test_data_teams.columns if col.startswith('AWAY_TEAM_')]

# Ensure there is a corresponding AWAY column for each HOME column
common_columns = [(home, home.replace('HOME_TEAM_', 'AWAY_TEAM_')) for home in home_columns if home.replace('HOME_TEAM_', 'AWAY_TEAM_') in away_columns]

# Add difference features
for home_col, away_col in common_columns:
    diff_col_name = home_col.replace('HOME_TEAM_', 'DIFF_')  # Name of the new column
    test_data_teams[diff_col_name] = test_data_teams[home_col] - test_data_teams[away_col]

# Delete initial features
cols_to_drop = home_columns + away_columns
test_data_teams.drop(columns=cols_to_drop, inplace=True)

# %%
test_data_teams.shape
# Out:
# (25368, 140)

# %%
test_data_teams.head()
# Out:
#        DIFF_SHOTS_TOTAL_season_sum  DIFF_SHOTS_INSIDEBOX_season_sum  \
# ID
# 12303                         -3.0                              0.0
# 12304                         -1.0                             -2.0
# 12305                          6.0                              9.0
# 12306                         -1.0                             -2.0
# 12307                          0.0                             -1.0
#
#        DIFF_SHOTS_OFF_TARGET_season_sum  DIFF_SHOTS_ON_TARGET_season_sum  \
# ID
# 12303                               0.0                             -6.0
# 12304                               0.0                             -2.0
# 12305                               6.0                              6.0
# 12306                              -1.0                              0.0
# 12307                               4.0                             -1.0
#
#        DIFF_SHOTS_OUTSIDEBOX_season_sum  DIFF_PASSES_season_sum  \
# ID
# 12303                              -4.0                     5.0
# 12304                               3.0                    -7.0
# 12305                              -1.0                    -2.0
# 12306                               1.0                     3.0
# 12307                               1.0                    -1.0
#
#        DIFF_SUCCESSFUL_PASSES_season_sum  DIFF_SAVES_season_sum  \
# ID
# 12303                                5.0                    4.0
# 12304                               -7.0                   -2.0
# 12305                                0.0                   -4.0
# 12306                                2.0                    2.0
# 12307                               -2.0                   -1.0
#
#        DIFF_CORNERS_season_sum  DIFF_FOULS_season_sum  \
# ID
# 12303                      3.0                    0.0
# 12304                     -3.0                    7.0
# 12305                      8.0                    2.0
# 12306                     -5.0                    2.0
# 12307                     -6.0                    7.0
#
#        DIFF_YELLOWCARDS_season_sum  DIFF_REDCARDS_season_sum  \
# ID
# 12303                          0.0                       0.0
# 12304                          1.0                       7.0
# 12305                          1.0                      -1.0
# 12306                          1.0                      -2.0
# 12307                          8.0                       5.0
#
#        DIFF_OFFSIDES_season_sum  DIFF_ATTACKS_season_sum  \
# ID
# 12303                      -2.0                      2.0
# 12304                      -2.0                     -3.0
# 12305                      -8.0                      1.0
# 12306                       3.0                     -5.0
# 12307                      -5.0                      0.0
#
#        DIFF_PENALTIES_season_sum  DIFF_SUBSTITUTIONS_season_sum  \
# ID
# 12303                        1.0                            2.0
# 12304                       -7.0                            2.0
# 12305                        4.0                           -3.0
# 12306                        0.0                            6.0
# 12307                        3.0                            9.0
#
#        DIFF_BALL_SAFE_season_sum  DIFF_DANGEROUS_ATTACKS_season_sum  \
# ID
# 12303                        7.0                                0.0
# 12304                       -6.0                               -3.0
# 12305                        3.0                                7.0
# 12306                        1.0                               -7.0
# 12307                       -2.0                               -4.0
#
#        DIFF_INJURIES_season_sum  DIFF_GOALS_season_sum  \
# ID
# 12303                      -5.0                   -3.0
# 12304                      -1.0                   -5.0
# 12305                       1.0                    7.0
# 12306                      -7.0                    1.0
# 12307                       0.0                    3.0
#
#        DIFF_GAME_WON_season_sum  DIFF_GAME_DRAW_season_sum  \
# ID
# 12303                      -2.0                       -3.0
# 12304                      -4.0                        2.0
# 12305                       5.0                        3.0
# 12306                       2.0                        2.0
# 12307                       1.0                       -5.0
#
#        DIFF_GAME_LOST_season_sum  DIFF_SHOTS_TOTAL_season_average  \
# ID
# 12303                        5.0                             -4.0
# 12304                        3.0                             -1.0
# 12305                       -6.0                              7.0
# 12306                       -4.0                             -3.0
# 12307                        3.0                              0.0
#
#        DIFF_SHOTS_INSIDEBOX_season_average  \
# ID
# 12303                                 -1.0
# 12304                                 -2.0
# 12305                                 10.0
# 12306                                 -4.0
# 12307                                  0.0
#
#        DIFF_SHOTS_OFF_TARGET_season_average  \
# ID
# 12303                                  -2.0
# 12304                                   1.0
# 12305                                   7.0
# 12306                                  -2.0
# 12307                                   2.0
#
#        DIFF_SHOTS_ON_TARGET_season_average  \
# ID
# 12303                                 -7.0
# 12304                                 -2.0
# 12305                                  6.0
# 12306                                  0.0
# 12307                                  0.0
#
#        DIFF_SHOTS_OUTSIDEBOX_season_average  DIFF_PASSES_season_average  \
# ID
# 12303                                  -5.0                         4.0
# 12304                                   4.0                        -7.0
# 12305                                   0.0                        -1.0
# 12306                                   1.0                         3.0
# 12307                                   1.0                        -1.0
#
#        DIFF_SUCCESSFUL_PASSES_season_average  \
# ID
# 12303                                    4.0
# 12304                                   -7.0
# 12305                                    0.0
# 12306                                    3.0
# 12307                                   -1.0
#
#        DIFF_SUCCESSFUL_PASSES_PERCENTAGE_season_average  \
# ID
# 12303                                               2.0
# 12304                                              -7.0
# 12305                                               1.0
# 12306                                               1.0
# 12307                                              -2.0
#
#        DIFF_SAVES_season_average  DIFF_CORNERS_season_average  \
# ID
# 12303                        2.0                          2.0
# 12304                       -2.0                         -2.0
# 12305                       -3.0                          9.0
# 12306                        2.0                         -7.0
# 12307                        0.0                         -7.0
#
#        DIFF_BALL_POSSESSION_season_average  DIFF_FOULS_season_average  \
# ID
# 12303                                  2.0                       -2.0
# 12304                                 -6.0                        7.0
# 12305                                  2.0                        3.0
# 12306                                  1.0                        1.0
# 12307                                  0.0                        8.0
#
#        DIFF_YELLOWCARDS_season_average  DIFF_REDCARDS_season_average  \
# ID
# 12303                             -2.0                           0.0
# 12304                              2.0                           7.0
# 12305                              1.0                          -1.0
# 12306                              2.0                          -2.0
# 12307                              7.0                           5.0
#
#        DIFF_OFFSIDES_season_average  DIFF_ATTACKS_season_average  \
# ID
# 12303                          -3.0                          0.0
# 12304                          -1.0                         -2.0
# 12305                          -7.0                          2.0
# 12306                           3.0                         -7.0
# 12307                          -5.0                          0.0
#
#        DIFF_PENALTIES_season_average  DIFF_SUBSTITUTIONS_season_average  \
# ID
# 12303                            1.0                               -1.0
# 12304                           -7.0                                2.0
# 12305                            4.0                               -2.0
# 12306                            0.0                                9.0
# 12307                            2.0                               10.0
#
#        DIFF_BALL_SAFE_season_average  DIFF_DANGEROUS_ATTACKS_season_average  \
# ID
# 12303                            4.0                                   -1.0
# 12304                           -6.0                                   -2.0
# 12305                            8.0                                    7.0
# 12306                           -4.0                                  -10.0
# 12307                           -3.0                                   -2.0
#
#        DIFF_INJURIES_season_average  DIFF_GOALS_season_average  \
# ID
# 12303                          -5.0                       -3.0
# 12304                          -3.0                       -5.0
# 12305                          -1.0                        7.0
# 12306                          -3.0                        0.0
# 12307                           4.0                        3.0
#
#        DIFF_GAME_WON_season_average  DIFF_GAME_DRAW_season_average  \
# ID
# 12303                          -2.0                           -4.0
# 12304                          -4.0                            2.0
# 12305                           5.0                            3.0
# 12306                           2.0                            2.0
# 12307                           1.0                           -6.0
#
#        DIFF_GAME_LOST_season_average  DIFF_SHOTS_TOTAL_season_std  \
# ID
# 12303                            5.0                         -4.0
# 12304                            3.0                          1.0
# 12305                           -5.0                          3.0
# 12306                           -4.0                         -3.0
# 12307                            2.0                         -2.0
#
#        DIFF_SHOTS_INSIDEBOX_season_std  DIFF_SHOTS_OFF_TARGET_season_std  \
# ID
# 12303                             -3.0                               0.0
# 12304                             -3.0                               1.0
# 12305                              6.0                               5.0
# 12306                             -2.0                               0.0
# 12307                             -1.0                               0.0
#
#        DIFF_SHOTS_ON_TARGET_season_std  DIFF_SHOTS_OUTSIDEBOX_season_std  \
# ID
# 12303                             -5.0                              -3.0
# 12304                             -2.0                               4.0
# 12305                              9.0                              -2.0
# 12306                              1.0                               2.0
# 12307                             -2.0                               4.0
#
#        DIFF_PASSES_season_std  DIFF_SUCCESSFUL_PASSES_season_std  \
# ID
# 12303                     6.0                                7.0
# 12304                    -3.0                               -3.0
# 12305                    -2.0                               -1.0
# 12306                     6.0                                6.0
# 12307                    -5.0                               -6.0
#
#        DIFF_SUCCESSFUL_PASSES_PERCENTAGE_season_std  DIFF_SAVES_season_std  \
# ID
# 12303                                           4.0                   -4.0
# 12304                                           6.0                    3.0
# 12305                                           0.0                   -3.0
# 12306                                           2.0                   -1.0
# 12307                                          -2.0                   -4.0
#
#        DIFF_CORNERS_season_std  DIFF_BALL_POSSESSION_season_std  \
# ID
# 12303                      1.0                              4.0
# 12304                     -7.0                              1.0
# 12305                     -5.0                              0.0
# 12306                     -7.0                              2.0
# 12307                     -2.0                             -7.0
#
#        DIFF_FOULS_season_std  DIFF_YELLOWCARDS_season_std  \
# ID
# 12303                    2.0                          1.0
# 12304                   -2.0                         -2.0
# 12305                    0.0                          1.0
# 12306                   -6.0                          3.0
# 12307                    7.0                          6.0
#
#        DIFF_REDCARDS_season_std  DIFF_OFFSIDES_season_std  \
# ID
# 12303                       0.0                       0.0
# 12304                       5.0                       1.0
# 12305                      -1.0                      -6.0
# 12306                       0.0                       5.0
# 12307                       3.0                      -4.0
#
#        DIFF_ATTACKS_season_std  DIFF_PENALTIES_season_std  \
# ID
# 12303                      3.0                        1.0
# 12304                     -2.0                       -5.0
# 12305                     -3.0                        3.0
# 12306                      3.0                        4.0
# 12307                      0.0                        2.0
#
#        DIFF_SUBSTITUTIONS_season_std  DIFF_BALL_SAFE_season_std  \
# ID
# 12303                            2.0                       -2.0
# 12304                           -4.0                       -2.0
# 12305                           -3.0                       -5.0
# 12306                           -8.0                        3.0
# 12307                           -3.0                        2.0
#
#        DIFF_DANGEROUS_ATTACKS_season_std  DIFF_INJURIES_season_std  \
# ID
# 12303                                4.0                      -2.0
# 12304                               -4.0                      -3.0
# 12305                                4.0                      -1.0
# 12306                               -7.0                      -3.0
# 12307                               -3.0                       3.0
#
#        DIFF_GOALS_season_std  DIFF_SHOTS_TOTAL_5_last_match_sum  \
# ID
# 12303                   -5.0                                0.0
# 12304                   -2.0                                2.0
# 12305                    6.0                                2.0
# 12306                   -2.0                               -3.0
# 12307                   -2.0                               -2.0
#
#        DIFF_SHOTS_INSIDEBOX_5_last_match_sum  \
# ID
# 12303                                    1.0
# 12304                                    0.0
# 12305                                    4.0
# 12306                                   -3.0
# 12307                                   -3.0
#
#        DIFF_SHOTS_OFF_TARGET_5_last_match_sum  \
# ID
# 12303                                     0.0
# 12304                                     6.0
# 12305                                     1.0
# 12306                                    -2.0
# 12307                                     0.0
#
#        DIFF_SHOTS_ON_TARGET_5_last_match_sum  \
# ID
# 12303                                   -1.0
# 12304                                   -6.0
# 12305                                    3.0
# 12306                                   -5.0
# 12307                                   -2.0
#
#        DIFF_SHOTS_OUTSIDEBOX_5_last_match_sum  DIFF_PASSES_5_last_match_sum  \
# ID
# 12303                                    -1.0                           5.0
# 12304                                     5.0                          -6.0
# 12305                                    -2.0                          -2.0
# 12306                                    -2.0                           3.0
# 12307                                     0.0                          -2.0
#
#        DIFF_SUCCESSFUL_PASSES_5_last_match_sum  DIFF_SAVES_5_last_match_sum  \
# ID
# 12303                                      5.0                         -4.0
# 12304                                     -7.0                          4.0
# 12305                                     -2.0                         -2.0
# 12306                                      3.0                          3.0
# 12307                                     -1.0                          2.0
#
#        DIFF_CORNERS_5_last_match_sum  DIFF_FOULS_5_last_match_sum  \
# ID
# 12303                            6.0                          0.0
# 12304                            1.0                          6.0
# 12305                            0.0                          4.0
# 12306                           -8.0                         -4.0
# 12307                           -9.0                          6.0
#
#        DIFF_YELLOWCARDS_5_last_match_sum  DIFF_REDCARDS_5_last_match_sum  \
# ID
# 12303                                0.0                            10.0
# 12304                                3.0                            10.0
# 12305                                1.0                             5.0
# 12306                               -3.0                             0.0
# 12307                                3.0                             0.0
#
#        DIFF_OFFSIDES_5_last_match_sum  DIFF_ATTACKS_5_last_match_sum  \
# ID
# 12303                            -4.0                            1.0
# 12304                            -1.0                            0.0
# 12305                             1.0                            2.0
# 12306                            -2.0                            3.0
# 12307                            -8.0                            0.0
#
#        DIFF_PENALTIES_5_last_match_sum  DIFF_SUBSTITUTIONS_5_last_match_sum  \
# ID
# 12303                              0.0                                  2.0
# 12304                              0.0                                  3.0
# 12305                              0.0                                 -4.0
# 12306                             -3.0                                 10.0
# 12307                              5.0                                  8.0
#
#        DIFF_BALL_SAFE_5_last_match_sum  \
# ID
# 12303                              1.0
# 12304                             -1.0
# 12305                              1.0
# 12306                              8.0
# 12307                              0.0
#
#        DIFF_DANGEROUS_ATTACKS_5_last_match_sum  \
# ID
# 12303                                      0.0
# 12304                                      1.0
# 12305                                     10.0
# 12306                                     -4.0
# 12307                                     -4.0
#
#        DIFF_INJURIES_5_last_match_sum  DIFF_GOALS_5_last_match_sum  \
# ID
# 12303                            -3.0                          2.0
# 12304                            -6.0                         -4.0
# 12305                             0.0                         -1.0
# 12306                             3.0                         -3.0
# 12307                             0.0                          2.0
#
#        DIFF_GAME_WON_5_last_match_sum  DIFF_GAME_DRAW_5_last_match_sum  \
# ID
# 12303                             0.0                              0.0
# 12304                            -2.0                              0.0
# 12305                             5.0                              0.0
# 12306                             3.0                             -3.0
# 12307                             2.0                              0.0
#
#        DIFF_GAME_LOST_5_last_match_sum  DIFF_SHOTS_TOTAL_5_last_match_average  \
# ID
# 12303                              0.0                                    0.0
# 12304                              3.0                                    2.0
# 12305                             -5.0                                    2.0
# 12306                              0.0                                   -3.0
# 12307                             -2.0                                   -2.0
#
#        DIFF_SHOTS_INSIDEBOX_5_last_match_average  \
# ID
# 12303                                        1.0
# 12304                                        0.0
# 12305                                        4.0
# 12306                                       -3.0
# 12307                                       -3.0
#
#        DIFF_SHOTS_OFF_TARGET_5_last_match_average  \
# ID
# 12303                                         0.0
# 12304                                         6.0
# 12305                                         1.0
# 12306                                        -2.0
# 12307                                         0.0
#
#        DIFF_SHOTS_ON_TARGET_5_last_match_average  \
# ID
# 12303                                       -1.0
# 12304                                       -6.0
# 12305                                        3.0
# 12306                                       -5.0
# 12307                                       -2.0
#
#        DIFF_SHOTS_OUTSIDEBOX_5_last_match_average  \
# ID
# 12303                                        -1.0
# 12304                                         5.0
# 12305                                        -2.0
# 12306                                        -1.0
# 12307                                         0.0
#
#        DIFF_PASSES_5_last_match_average  \
# ID
# 12303                               5.0
# 12304                              -6.0
# 12305                              -2.0
# 12306                               3.0
# 12307                              -2.0
#
#        DIFF_SUCCESSFUL_PASSES_5_last_match_average  \
# ID
# 12303                                          5.0
# 12304                                         -7.0
# 12305                                         -2.0
# 12306                                          3.0
# 12307                                         -1.0
#
#        DIFF_SUCCESSFUL_PASSES_PERCENTAGE_5_last_match_average  \
# ID
# 12303                                                4.0
# 12304                                               -8.0
# 12305                                               -2.0
# 12306                                                0.0
# 12307                                                0.0
#
#        DIFF_SAVES_5_last_match_average  DIFF_CORNERS_5_last_match_average  \
# ID
# 12303                             -4.0                                6.0
# 12304                              4.0                                1.0
# 12305                             -2.0                                0.0
# 12306                              3.0                               -8.0
# 12307                              1.0                               -9.0
#
#        DIFF_BALL_POSSESSION_5_last_match_average  \
# ID
# 12303                                        3.0
# 12304                                       -5.0
# 12305                                        2.0
# 12306                                       -2.0
# 12307                                       -1.0
#
#        DIFF_FOULS_5_last_match_average  DIFF_YELLOWCARDS_5_last_match_average  \
# ID
# 12303                              0.0                                    0.0
# 12304                              6.0                                    3.0
# 12305                              4.0                                    1.0
# 12306                             -4.0                                   -4.0
# 12307                              6.0                                    3.0
#
#        DIFF_REDCARDS_5_last_match_average  DIFF_OFFSIDES_5_last_match_average  \
# ID
# 12303                                10.0                                -4.0
# 12304                                10.0                                -1.0
# 12305                                 5.0                                 1.0
# 12306                                 0.0                                -2.0
# 12307                                 0.0                                -8.0
#
#        DIFF_ATTACKS_5_last_match_average  DIFF_PENALTIES_5_last_match_average  \
# ID
# 12303                                0.0                                  0.0
# 12304                                0.0                                  0.0
# 12305                                2.0                                  0.0
# 12306                                3.0                                 -3.0
# 12307                                0.0                                  5.0
#
#        DIFF_SUBSTITUTIONS_5_last_match_average  \
# ID
# 12303                                      2.0
# 12304                                      3.0
# 12305                                     -4.0
# 12306                                     10.0
# 12307                                      8.0
#
#        DIFF_BALL_SAFE_5_last_match_average  \
# ID
# 12303                                  1.0
# 12304                                 -1.0
# 12305                                  1.0
# 12306                                 10.0
# 12307                                  0.0
#
#        DIFF_DANGEROUS_ATTACKS_5_last_match_average  \
# ID
# 12303                                          0.0
# 12304                                          1.0
# 12305                                         10.0
# 12306                                         -4.0
# 12307                                         -4.0
#
#        DIFF_INJURIES_5_last_match_average  DIFF_GOALS_5_last_match_average  \
# ID
# 12303                                -3.0                              2.0
# 12304                                -9.0                             -4.0
# 12305                                 0.0                             -1.0
# 12306                                 1.0                             -3.0
# 12307                                 3.0                              2.0
#
#        DIFF_GAME_WON_5_last_match_average  \
# ID
# 12303                                 0.0
# 12304                                -2.0
# 12305                                 5.0
# 12306                                 3.0
# 12307                                 2.0
#
#        DIFF_GAME_DRAW_5_last_match_average  \
# ID
# 12303                                  0.0
# 12304                                  0.0
# 12305                                  0.0
# 12306                                 -3.0
# 12307                                  0.0
#
#        DIFF_GAME_LOST_5_last_match_average  DIFF_SHOTS_TOTAL_5_last_match_std  \
# ID
# 12303                                  0.0                               -3.0
# 12304                                  3.0                                0.0
# 12305                                 -5.0                                5.0
# 12306                                  0.0                               -4.0
# 12307                                 -2.0                               -3.0
#
#        DIFF_SHOTS_INSIDEBOX_5_last_match_std  \
# ID
# 12303                                   -1.0
# 12304                                   -4.0
# 12305                                    6.0
# 12306                                   -4.0
# 12307                                   -6.0
#
#        DIFF_SHOTS_OFF_TARGET_5_last_match_std  \
# ID
# 12303                                    -5.0
# 12304                                    -2.0
# 12305                                     4.0
# 12306                                    -6.0
# 12307                                     2.0
#
#        DIFF_SHOTS_ON_TARGET_5_last_match_std  \
# ID
# 12303                                   -3.0
# 12304                                   -3.0
# 12305                                   -2.0
# 12306                                    1.0
# 12307                                   -7.0
#
#        DIFF_SHOTS_OUTSIDEBOX_5_last_match_std  DIFF_PASSES_5_last_match_std  \
# ID
# 12303                                    -3.0                           3.0
# 12304                                     4.0                           0.0
# 12305                                     1.0                           3.0
# 12306                                     0.0                           6.0
# 12307                                     6.0                          -8.0
#
#        DIFF_SUCCESSFUL_PASSES_5_last_match_std  \
# ID
# 12303                                      5.0
# 12304                                     -1.0
# 12305                                      3.0
# 12306                                      5.0
# 12307                                     -8.0
#
#        DIFF_SUCCESSFUL_PASSES_PERCENTAGE_5_last_match_std  \
# ID
# 12303                                                5.0
# 12304                                                4.0
# 12305                                                2.0
# 12306                                               -2.0
# 12307                                               -6.0
#
#        DIFF_SAVES_5_last_match_std  DIFF_CORNERS_5_last_match_std  \
# ID
# 12303                         -4.0                            1.0
# 12304                          0.0                            1.0
# 12305                         -4.0                            0.0
# 12306                          0.0                           -4.0
# 12307                         -2.0                           -6.0
#
#        DIFF_BALL_POSSESSION_5_last_match_std  DIFF_FOULS_5_last_match_std  \
# ID
# 12303                                    0.0                          1.0
# 12304                                    2.0                        -10.0
# 12305                                    0.0                          5.0
# 12306                                    4.0                         -2.0
# 12307                                   -6.0                          0.0
#
#        DIFF_YELLOWCARDS_5_last_match_std  DIFF_REDCARDS_5_last_match_std  \
# ID
# 12303                               -4.0                             9.0
# 12304                                9.0                            10.0
# 12305                               -4.0                             8.0
# 12306                                3.0                             0.0
# 12307                                2.0                             0.0
#
#        DIFF_OFFSIDES_5_last_match_std  DIFF_ATTACKS_5_last_match_std  \
# ID
# 12303                            -1.0                            6.0
# 12304                             0.0                           -5.0
# 12305                             2.0                            7.0
# 12306                            -2.0                           -2.0
# 12307                            -6.0                            2.0
#
#        DIFF_PENALTIES_5_last_match_std  DIFF_SUBSTITUTIONS_5_last_match_std  \
# ID
# 12303                              0.0                                 -4.0
# 12304                              0.0                                 -2.0
# 12305                              0.0                                  2.0
# 12306                             -2.0                                 -9.0
# 12307                              5.0                                 -4.0
#
#        DIFF_BALL_SAFE_5_last_match_std  \
# ID
# 12303                             -3.0
# 12304                              7.0
# 12305                             -2.0
# 12306                             -4.0
# 12307                             -2.0
#
#        DIFF_DANGEROUS_ATTACKS_5_last_match_std  \
# ID
# 12303                                      4.0
# 12304                                      0.0
# 12305                                      6.0
# 12306                                     -7.0
# 12307                                     -4.0
#
#        DIFF_INJURIES_5_last_match_std  DIFF_GOALS_5_last_match_std
# ID
# 12303                            -5.0                          3.0
# 12304                            -7.0                         -7.0
# 12305                             0.0                         -9.0
# 12306                            -5.0                          0.0
# 12307                             4.0                          0.0

# %%
test_data_teams_avg = test_data_teams.loc[:, test_data_teams.columns.str.endswith('_average')]
print(test_data_teams_avg.shape)

test_data_teams_sum = test_data_teams.loc[:, test_data_teams.columns.str.endswith('_sum')]
print(test_data_teams_sum.shape)

test_data_teams_std = test_data_teams.loc[:, test_data_teams.columns.str.endswith('_std')]
print(test_data_teams_std.shape)
# Out:
# (25368, 50)
# (25368, 46)
# (25368, 44)

# %%
try:
    test_home_player_statistics_df = pd.read_csv(RAW_DATA_DIR / "test_home_player_statistics_df.csv", index_col=0)
    test_away_player_statistics_df = pd.read_csv(RAW_DATA_DIR / "test_away_player_statistics_df.csv", index_col=0)
    print("Files loaded")
    
except FileNotFoundError as e:
    print(e)
# Out:
# Files loaded

# %%
home_players = test_home_player_statistics_df
away_players = test_away_player_statistics_df

# Rename
home_players.columns = 'HOME_' + home_players.columns
away_players.columns = 'AWAY_' + away_players.columns

home_players = home_players.apply(replace_null_values)
away_players = away_players.apply(replace_null_values)

print(home_players.shape)
print(away_players.shape)
# Out:
# (509816, 303)
# (504626, 303)

# %%
home_players = home_players.fillna({'HOME_POSITION': home_players['HOME_POSITION'].mode()[0]})
away_players = away_players.fillna({'AWAY_POSITION': away_players['AWAY_POSITION'].mode()[0]})

# %%
position_map = {
    'attacker': 'offensive',
    'midfielder': 'offensive',
    'defender': 'defender',
    'goalkeeper': 'goalkeeper'
}

# %% [markdown]
# ## Average

# %%
columns_to_aggregate_home = [col for col in home_players.columns if col.endswith(('average'))]
columns_to_aggregate_away = [col for col in away_players.columns if col.endswith(('average'))]

# Building tables
home_agg = home_players.groupby([home_players.index, 'HOME_POSITION']).agg({
    col: ['mean'] for col in columns_to_aggregate_home  # mean agg
}).reset_index()

away_agg = away_players.groupby([away_players.index, 'AWAY_POSITION']).agg({
    col: ['mean'] for col in columns_to_aggregate_away  # mean agg
}).reset_index()

# Flatten multi-level columns from previous groupby
home_agg.columns = ['_'.join(col).strip() for col in home_agg.columns.values]
home_agg = home_agg.rename(columns={'ID_' : 'HOME_ID', 'HOME_POSITION_' : 'HOME_POSITION'})

away_agg.columns = ['_'.join(col).strip() for col in away_agg.columns.values]
away_agg = away_agg.rename(columns={'ID_' : 'AWAY_ID', 'AWAY_POSITION_' : 'AWAY_POSITION'})

# For home aggregation:
home_agg['position_group'] = home_agg['HOME_POSITION'].map(position_map)  # Map positions to groups
agg_columns = [col for col in home_agg.columns 
               if home_agg[col].dtype in ['float64', 'int64'] and col != 'HOME_ID']  # Select numeric columns
home_group = home_agg.groupby(['HOME_ID', 'position_group'])[agg_columns].mean().reset_index()  # Compute mean for each group

home_pivot = home_group.pivot(index='HOME_ID', columns='position_group')  # Pivot to get separate columns per group
home_pivot.columns = ['_'.join(col).strip() for col in home_pivot.columns.values]  # Flatten multi-level column index
home_pivot.reset_index(inplace=True)

# For away aggregation:
away_agg['position_group'] = away_agg['AWAY_POSITION'].map(position_map)  # Map positions to groups
agg_columns = [col for col in away_agg.columns 
               if away_agg[col].dtype in ['float64', 'int64'] and col != 'AWAY_ID']  # Select numeric columns
away_group = away_agg.groupby(['AWAY_ID', 'position_group'])[agg_columns].mean().reset_index()  # Compute mean for each group

away_pivot = away_group.pivot(index='AWAY_ID', columns='position_group')  # Pivot to get separate columns per group
away_pivot.columns = ['_'.join(col).strip() for col in away_pivot.columns.values]  # Flatten multi-level column index
away_pivot.reset_index(inplace=True)

# Merge
home_pivot.rename(columns={'HOME_ID': 'ID'}, inplace=True)
away_pivot.rename(columns={'AWAY_ID': 'ID'}, inplace=True)
test_data_players_avg = home_pivot.merge(away_pivot, on='ID', how='inner')
test_data_players_avg.set_index('ID', inplace=True)

test_data_players_avg = test_data_players_avg.drop(columns=test_data_players_avg.columns[test_data_players_avg.isna().mean() > 0.5])
test_data_players_avg = test_data_players_avg.fillna(test_data_players_avg.select_dtypes(include=['number']).median())

### DIFFERENCES
home_columns = [col for col in test_data_players_avg.columns if col.startswith('HOME_PLAYER_')]
away_columns = [col for col in test_data_players_avg.columns if col.startswith('AWAY_PLAYER_')]

common_columns = [(home, home.replace('HOME_PLAYER_', 'AWAY_PLAYER_')) for home in home_columns if home.replace('HOME_PLAYER_', 'AWAY_PLAYER_') in away_columns]

for home_col, away_col in common_columns:
    diff_col_name = home_col.replace('HOME_PLAYER_', 'DIFF_PLAYER_') 
    test_data_players_avg[diff_col_name] = test_data_players_avg[home_col] - test_data_players_avg[away_col]

cols_to_drop = home_columns + away_columns
test_data_players_avg.drop(columns=cols_to_drop, inplace=True)

# %% [markdown]
# ## Sum

# %%
# columns_to_aggregate_home = [col for col in home_players.columns if col.endswith(('sum'))]
# columns_to_aggregate_away = [col for col in away_players.columns if col.endswith(('sum'))]

# # Building tables
# home_agg = home_players.groupby([home_players.index, 'HOME_POSITION']).agg({
#     col: ['mean'] for col in columns_to_aggregate_home  # mean agg
# }).reset_index()

# away_agg = away_players.groupby([away_players.index, 'AWAY_POSITION']).agg({
#     col: ['mean'] for col in columns_to_aggregate_away  # mean agg
# }).reset_index()

# # Flatten multi-level columns from previous groupby
# home_agg.columns = ['_'.join(col).strip() for col in home_agg.columns.values]
# home_agg = home_agg.rename(columns={'ID_' : 'HOME_ID', 'HOME_POSITION_' : 'HOME_POSITION'})

# away_agg.columns = ['_'.join(col).strip() for col in away_agg.columns.values]
# away_agg = away_agg.rename(columns={'ID_' : 'AWAY_ID', 'AWAY_POSITION_' : 'AWAY_POSITION'})

# # For home aggregation:
# home_agg['position_group'] = home_agg['HOME_POSITION'].map(position_map)  # Map positions to groups
# agg_columns = [col for col in home_agg.columns 
#                if home_agg[col].dtype in ['float64', 'int64'] and col != 'HOME_ID']  # Select numeric columns
# home_group = home_agg.groupby(['HOME_ID', 'position_group'])[agg_columns].mean().reset_index()  # Compute mean for each group

# home_pivot = home_group.pivot(index='HOME_ID', columns='position_group')  # Pivot to get separate columns per group
# home_pivot.columns = ['_'.join(col).strip() for col in home_pivot.columns.values]  # Flatten multi-level column index
# home_pivot.reset_index(inplace=True)

# # For away aggregation:
# away_agg['position_group'] = away_agg['AWAY_POSITION'].map(position_map)  # Map positions to groups
# agg_columns = [col for col in away_agg.columns 
#                if away_agg[col].dtype in ['float64', 'int64'] and col != 'AWAY_ID']  # Select numeric columns
# away_group = away_agg.groupby(['AWAY_ID', 'position_group'])[agg_columns].mean().reset_index()  # Compute mean for each group

# away_pivot = away_group.pivot(index='AWAY_ID', columns='position_group')  # Pivot to get separate columns per group
# away_pivot.columns = ['_'.join(col).strip() for col in away_pivot.columns.values]  # Flatten multi-level column index
# away_pivot.reset_index(inplace=True)

# # Merge
# home_pivot.rename(columns={'HOME_ID': 'ID'}, inplace=True)
# away_pivot.rename(columns={'AWAY_ID': 'ID'}, inplace=True)
# test_data_players_sum = home_pivot.merge(away_pivot, on='ID', how='inner')
# test_data_players_sum.set_index('ID', inplace=True)

# test_data_players_sum = test_data_players_sum.drop(columns=test_data_players_sum.columns[test_data_players_sum.isna().mean() > 0.5])
# test_data_players_sum = test_data_players_sum.fillna(test_data_players_sum.select_dtypes(include=['number']).median())

# ### DIFFERENCES
# home_columns = [col for col in test_data_players_sum.columns if col.startswith('HOME_PLAYER_')]
# away_columns = [col for col in test_data_players_sum.columns if col.startswith('AWAY_PLAYER_')]

# common_columns = [(home, home.replace('HOME_PLAYER_', 'AWAY_PLAYER_')) for home in home_columns if home.replace('HOME_PLAYER_', 'AWAY_PLAYER_') in away_columns]

# for home_col, away_col in common_columns:
#     diff_col_name = home_col.replace('HOME_PLAYER_', 'DIFF_PLAYER_') 
#     test_data_players_sum[diff_col_name] = test_data_players_sum[home_col] - test_data_players_sum[away_col]

# cols_to_drop = home_columns + away_columns
# test_data_players_sum.drop(columns=cols_to_drop, inplace=True)

# %%
# test_data_players_interim = test_data_players_sum.merge(test_data_players_avg, left_index=True, right_index=True, how='inner')

# %% [markdown]
# ## Std

# %%
# columns_to_aggregate_home = [col for col in home_players.columns if col.endswith(('std'))]
# columns_to_aggregate_away = [col for col in away_players.columns if col.endswith(('std'))]

# # Building tables
# home_agg = home_players.groupby([home_players.index, 'HOME_POSITION']).agg({
#     col: ['mean'] for col in columns_to_aggregate_home  # mean agg
# }).reset_index()

# away_agg = away_players.groupby([away_players.index, 'AWAY_POSITION']).agg({
#     col: ['mean'] for col in columns_to_aggregate_away  # mean agg
# }).reset_index()

# # Flatten multi-level columns from previous groupby
# home_agg.columns = ['_'.join(col).strip() for col in home_agg.columns.values]
# home_agg = home_agg.rename(columns={'ID_' : 'HOME_ID', 'HOME_POSITION_' : 'HOME_POSITION'})

# away_agg.columns = ['_'.join(col).strip() for col in away_agg.columns.values]
# away_agg = away_agg.rename(columns={'ID_' : 'AWAY_ID', 'AWAY_POSITION_' : 'AWAY_POSITION'})

# # For home aggregation:
# home_agg['position_group'] = home_agg['HOME_POSITION'].map(position_map)  # Map positions to groups
# agg_columns = [col for col in home_agg.columns 
#                if home_agg[col].dtype in ['float64', 'int64'] and col != 'HOME_ID']  # Select numeric columns
# home_group = home_agg.groupby(['HOME_ID', 'position_group'])[agg_columns].mean().reset_index()  # Compute mean for each group

# home_pivot = home_group.pivot(index='HOME_ID', columns='position_group')  # Pivot to get separate columns per group
# home_pivot.columns = ['_'.join(col).strip() for col in home_pivot.columns.values]  # Flatten multi-level column index
# home_pivot.reset_index(inplace=True)

# # For away aggregation:
# away_agg['position_group'] = away_agg['AWAY_POSITION'].map(position_map)  # Map positions to groups
# agg_columns = [col for col in away_agg.columns 
#                if away_agg[col].dtype in ['float64', 'int64'] and col != 'AWAY_ID']  # Select numeric columns
# away_group = away_agg.groupby(['AWAY_ID', 'position_group'])[agg_columns].mean().reset_index()  # Compute mean for each group

# away_pivot = away_group.pivot(index='AWAY_ID', columns='position_group')  # Pivot to get separate columns per group
# away_pivot.columns = ['_'.join(col).strip() for col in away_pivot.columns.values]  # Flatten multi-level column index
# away_pivot.reset_index(inplace=True)

# # Merge
# home_pivot.rename(columns={'HOME_ID': 'ID'}, inplace=True)
# away_pivot.rename(columns={'AWAY_ID': 'ID'}, inplace=True)
# test_data_players_std = home_pivot.merge(away_pivot, on='ID', how='inner')
# test_data_players_std.set_index('ID', inplace=True)

# test_data_players_std = test_data_players_std.drop(columns=test_data_players_std.columns[test_data_players_std.isna().mean() > 0.5])
# test_data_players_std = test_data_players_std.fillna(test_data_players_std.select_dtypes(include=['number']).median())

# ### DIFFERENCES
# home_columns = [col for col in test_data_players_std.columns if col.startswith('HOME_PLAYER_')]
# away_columns = [col for col in test_data_players_std.columns if col.startswith('AWAY_PLAYER_')]

# common_columns = [(home, home.replace('HOME_PLAYER_', 'AWAY_PLAYER_')) for home in home_columns if home.replace('HOME_PLAYER_', 'AWAY_PLAYER_') in away_columns]

# for home_col, away_col in common_columns:
#     diff_col_name = home_col.replace('HOME_PLAYER_', 'DIFF_PLAYER_') 
#     test_data_players_std[diff_col_name] = test_data_players_std[home_col] - test_data_players_std[away_col]

# cols_to_drop = home_columns + away_columns
# test_data_players_std.drop(columns=cols_to_drop, inplace=True)

# %%
# test_data_players = test_data_players_interim.merge(test_data_players_std, left_index=True, right_index=True, how='inner')

# %%
test_data_players_avg.shape
# Out:
# (25368, 282)

# %% [markdown]
# ## Final dataset

# %%
test_data = test_data_teams_avg.merge(test_data_players_avg, left_index=True, right_index=True, how='inner')

# %%
test_data.shape
# Out:
# (25368, 332)

# %%
try:
    train_data = pd.read_csv(PROCESSED_DATA_DIR / "train_data.csv", index_col=0)
    print("Files loaded")
    
except FileNotFoundError as e:
    print(e)
# Out:
# Files loaded

# %%
common = train_data.columns.intersection(test_data.columns)
test_aligned = test_data[common]
test_aligned.shape
# Out:
# (25368, 275)

# %%
print_perc_nans(test_aligned, threshold=50)
# Out:
# No columns have a percentage of NaN values above the threshold.

# %%
test_aligned = test_aligned.drop(columns=test_aligned.columns[test_aligned.isna().mean() > 0.5])

# %%
print_perc_nans(test_aligned, threshold=0)
# Out:
# No columns have a percentage of NaN values above the threshold.

# %%
test_aligned = test_aligned.fillna(test_aligned.select_dtypes(include=['number']).median())

# %%
test_aligned.head()
# Out:
#        DIFF_GAME_LOST_season_average  \
# ID
# 12303                            5.0
# 12304                            3.0
# 12305                           -5.0
# 12306                           -4.0
# 12307                            2.0
#
#        DIFF_PLAYER_GOALS_CONCEDED_season_average_mean_offensive  \
# ID
# 12303                                           8.352814
# 12304                                          -5.747619
# 12305                                         -12.648810
# 12306                                          -1.300000
# 12307                                          11.539286
#
#        DIFF_SHOTS_TOTAL_season_average  DIFF_BALL_POSSESSION_season_average  \
# ID
# 12303                             -4.0                                  2.0
# 12304                             -1.0                                 -6.0
# 12305                              7.0                                  2.0
# 12306                             -3.0                                  1.0
# 12307                              0.0                                  0.0
#
#        DIFF_SHOTS_INSIDEBOX_season_average  \
# ID
# 12303                                 -1.0
# 12304                                 -2.0
# 12305                                 10.0
# 12306                                 -4.0
# 12307                                  0.0
#
#        DIFF_SHOTS_ON_TARGET_season_average  DIFF_GAME_WON_season_average  \
# ID
# 12303                                 -7.0                          -2.0
# 12304                                 -2.0                          -4.0
# 12305                                  6.0                           5.0
# 12306                                  0.0                           2.0
# 12307                                  0.0                           1.0
#
#        DIFF_PLAYER_GOALS_CONCEDED_season_average_mean_goalkeeper  \
# ID
# 12303                                               18.5
# 12304                                                8.5
# 12305                                              -16.5
# 12306                                                1.0
# 12307                                                9.5
#
#        DIFF_PLAYER_GOALS_CONCEDED_season_average_mean_defender  \
# ID
# 12303                                          24.133333
# 12304                                           2.083333
# 12305                                         -16.083333
# 12306                                          -2.500000
# 12307                                          18.085714
#
#        DIFF_DANGEROUS_ATTACKS_season_average  \
# ID
# 12303                                   -1.0
# 12304                                   -2.0
# 12305                                    7.0
# 12306                                  -10.0
# 12307                                   -2.0
#
#        DIFF_PLAYER_BIG_CHANCES_CREATED_season_average_mean_offensive  \
# ID
# 12303                                           4.490260
# 12304                                         -17.938095
# 12305                                          13.577381
# 12306                                           2.400000
# 12307                                          -3.410714
#
#        DIFF_GOALS_season_average  \
# ID
# 12303                       -3.0
# 12304                       -5.0
# 12305                        7.0
# 12306                        0.0
# 12307                        3.0
#
#        DIFF_PLAYER_ASSISTS_season_average_mean_offensive  \
# ID
# 12303                                           2.432900
# 12304                                          -7.483333
# 12305                                           7.101190
# 12306                                           0.500000
# 12307                                          -0.321429
#
#        DIFF_PLAYER_KEY_PASSES_season_average_mean_offensive  \
# ID
# 12303                                          -9.931277
# 12304                                          -7.850000
# 12305                                           4.416667
# 12306                                          -3.800000
# 12307                                          -5.378571
#
#        DIFF_SHOTS_OFF_TARGET_season_average  \
# ID
# 12303                                  -2.0
# 12304                                   1.0
# 12305                                   7.0
# 12306                                  -2.0
# 12307                                   2.0
#
#        DIFF_BALL_POSSESSION_5_last_match_average  DIFF_ATTACKS_season_average  \
# ID
# 12303                                        3.0                          0.0
# 12304                                       -5.0                         -2.0
# 12305                                        2.0                          2.0
# 12306                                       -2.0                         -7.0
# 12307                                       -1.0                          0.0
#
#        DIFF_CORNERS_season_average  \
# ID
# 12303                          2.0
# 12304                         -2.0
# 12305                          9.0
# 12306                         -7.0
# 12307                         -7.0
#
#        DIFF_PLAYER_ASSISTS_season_average_mean_defender  \
# ID
# 12303                                          1.800000
# 12304                                          1.416667
# 12305                                         -7.083333
# 12306                                         -0.500000
# 12307                                          8.714286
#
#        DIFF_PLAYER_GOALS_season_average_mean_offensive  \
# ID
# 12303                                        -9.475649
# 12304                                       -23.083333
# 12305                                         5.083333
# 12306                                         2.500000
# 12307                                         2.350000
#
#        DIFF_SAVES_season_average  DIFF_SUCCESSFUL_PASSES_season_average  \
# ID
# 12303                        2.0                                    4.0
# 12304                       -2.0                                   -7.0
# 12305                       -3.0                                    0.0
# 12306                        2.0                                    3.0
# 12307                        0.0                                   -1.0
#
#        DIFF_PLAYER_ACCURATE_PASSES_season_average_mean_defender  \
# ID
# 12303                                          12.266667
# 12304                                           9.000000
# 12305                                           7.250000
# 12306                                           2.166667
# 12307                                         -13.000000
#
#        DIFF_PLAYER_GOALS_CONCEDED_5_last_match_average_mean_offensive  \
# ID
# 12303                                           8.109307
# 12304                                           2.073810
# 12305                                         -34.916667
# 12306                                          -5.400000
# 12307                                          -0.525000
#
#        DIFF_PASSES_season_average  \
# ID
# 12303                         4.0
# 12304                        -7.0
# 12305                        -1.0
# 12306                         3.0
# 12307                        -1.0
#
#        DIFF_PLAYER_KEY_PASSES_5_last_match_average_mean_offensive  \
# ID
# 12303                                          -6.672619
# 12304                                          -0.864286
# 12305                                           5.273810
# 12306                                           2.900000
# 12307                                          -2.096429
#
#        DIFF_PLAYER_ACCURATE_PASSES_season_average_mean_offensive  \
# ID
# 12303                                          -4.954545
# 12304                                         -15.711905
# 12305                                          -5.345238
# 12306                                           1.200000
# 12307                                          -1.250000
#
#        DIFF_PLAYER_PASSES_season_average_mean_offensive  \
# ID
# 12303                                         -6.591450
# 12304                                        -15.504762
# 12305                                         -6.470238
# 12306                                          2.000000
# 12307                                         -0.914286
#
#        DIFF_PLAYER_GOALS_CONCEDED_5_last_match_average_mean_defender  \
# ID
# 12303                                          30.466667
# 12304                                          10.166667
# 12305                                         -44.500000
# 12306                                         -11.166667
# 12307                                           4.714286
#
#        DIFF_PLAYER_KEY_PASSES_season_average_mean_defender  \
# ID
# 12303                                           2.866667
# 12304                                          14.583333
# 12305                                          -8.583333
# 12306                                          -3.166667
# 12307                                           3.314286
#
#        DIFF_PLAYER_CLEARANCES_5_last_match_average_mean_offensive  \
# ID
# 12303                                          -2.105519
# 12304                                          -8.750000
# 12305                                           3.178571
# 12306                                           1.500000
# 12307                                           5.800000
#
#        DIFF_PLAYER_ACCURATE_PASSES_PERCENTAGE_season_average_mean_defender  \
# ID
# 12303                                           3.800000
# 12304                                         -11.333333
# 12305                                           1.583333
# 12306                                           8.333333
# 12307                                          -6.200000
#
#        DIFF_PLAYER_GOALS_CONCEDED_5_last_match_average_mean_goalkeeper  \
# ID
# 12303                                               16.5
# 12304                                               18.5
# 12305                                              -39.5
# 12306                                               -7.0
# 12307                                               -6.0
#
#        DIFF_PLAYER_SHOTS_ON_TARGET_season_average_mean_offensive  \
# ID
# 12303                                         -30.721861
# 12304                                         -15.309524
# 12305                                           4.773810
# 12306                                           5.000000
# 12307                                          -3.185714
#
#        DIFF_PLAYER_SHOTS_BLOCKED_season_average_mean_offensive  \
# ID
# 12303                                          -7.522727
# 12304                                          -9.719048
# 12305                                           6.684524
# 12306                                          -1.000000
# 12307                                          -4.664286
#
#        DIFF_SHOTS_TOTAL_5_last_match_average  \
# ID
# 12303                                    0.0
# 12304                                    2.0
# 12305                                    2.0
# 12306                                   -3.0
# 12307                                   -2.0
#
#        DIFF_PLAYER_PASSES_season_average_mean_defender  \
# ID
# 12303                                        11.133333
# 12304                                        13.083333
# 12305                                         6.916667
# 12306                                         1.833333
# 12307                                       -12.800000
#
#        DIFF_PLAYER_SHOTS_TOTAL_season_average_mean_offensive  \
# ID
# 12303                                         -14.192100
# 12304                                         -16.528571
# 12305                                           4.285714
# 12306                                           2.500000
# 12307                                          -5.732143
#
#        DIFF_PLAYER_ACCURATE_PASSES_PERCENTAGE_season_average_mean_offensive  \
# ID
# 12303                                           8.767857
# 12304                                          -7.666667
# 12305                                           6.148810
# 12306                                           3.000000
# 12307                                           1.964286
#
#        DIFF_PLAYER_BIG_CHANCES_MISSED_season_average_mean_offensive  \
# ID
# 12303                                          -6.012987
# 12304                                           1.414286
# 12305                                           1.261905
# 12306                                           6.200000
# 12307                                          -3.275000
#
#        DIFF_PLAYER_CLEARANCES_season_average_mean_offensive  \
# ID
# 12303                                          -0.886364
# 12304                                          -6.388095
# 12305                                           2.148810
# 12306                                           1.700000
# 12307                                           2.592857
#
#        DIFF_PLAYER_BLOCKED_SHOTS_season_average_mean_defender  \
# ID
# 12303                                           2.200000
# 12304                                           9.916667
# 12305                                          11.250000
# 12306                                           7.000000
# 12307                                          -7.857143
#
#        DIFF_CORNERS_5_last_match_average  \
# ID
# 12303                                6.0
# 12304                                1.0
# 12305                                0.0
# 12306                               -8.0
# 12307                               -9.0
#
#        DIFF_SUCCESSFUL_PASSES_PERCENTAGE_5_last_match_average  \
# ID
# 12303                                                4.0
# 12304                                               -8.0
# 12305                                               -2.0
# 12306                                                0.0
# 12307                                                0.0
#
#        DIFF_PLAYER_CLEARANCES_season_average_mean_defender  \
# ID
# 12303                                           3.000000
# 12304                                          17.666667
# 12305                                          -5.500000
# 12306                                          -5.500000
# 12307                                          -7.057143
#
#        DIFF_PASSES_5_last_match_average  \
# ID
# 12303                               5.0
# 12304                              -6.0
# 12305                              -2.0
# 12306                               3.0
# 12307                              -2.0
#
#        DIFF_PLAYER_ACCURATE_PASSES_PERCENTAGE_5_last_match_average_mean_defender  \
# ID
# 12303                                          17.650000
# 12304                                          -1.916667
# 12305                                          -7.350000
# 12306                                           4.000000
# 12307                                          -7.342857
#
#        DIFF_SHOTS_INSIDEBOX_5_last_match_average  \
# ID
# 12303                                        1.0
# 12304                                        0.0
# 12305                                        4.0
# 12306                                       -3.0
# 12307                                       -3.0
#
#        DIFF_PLAYER_ACCURATE_PASSES_5_last_match_average_mean_offensive  \
# ID
# 12303                                          -4.179113
# 12304                                         -14.809524
# 12305                                          -8.107143
# 12306                                           6.800000
# 12307                                           1.889286
#
#        DIFF_PLAYER_BIG_CHANCES_CREATED_5_last_match_average_mean_offensive  \
# ID
# 12303                                           5.984848
# 12304                                          -4.133333
# 12305                                          -5.714286
# 12306                                           8.000000
# 12307                                           4.017857
#
#        DIFF_PLAYER_ACCURATE_PASSES_PERCENTAGE_5_last_match_average_mean_goalkeeper  \
# ID
# 12303                                              -11.5
# 12304                                              -20.0
# 12305                                                3.5
# 12306                                                6.0
# 12307                                               -1.0
#
#        DIFF_SUCCESSFUL_PASSES_5_last_match_average  \
# ID
# 12303                                          5.0
# 12304                                         -7.0
# 12305                                         -2.0
# 12306                                          3.0
# 12307                                         -1.0
#
#        DIFF_PLAYER_REDCARDS_season_average_mean_offensive  \
# ID
# 12303                                           5.500000
# 12304                                          -1.750000
# 12305                                          -0.357143
# 12306                                          -0.200000
# 12307                                           6.714286
#
#        DIFF_PLAYER_ACCURATE_PASSES_5_last_match_average_mean_defender  \
# ID
# 12303                                          16.100000
# 12304                                           7.750000
# 12305                                           6.833333
# 12306                                          10.000000
# 12307                                         -16.600000
#
#        DIFF_GAME_WON_5_last_match_average  \
# ID
# 12303                                 0.0
# 12304                                -2.0
# 12305                                 5.0
# 12306                                 3.0
# 12307                                 2.0
#
#        DIFF_SHOTS_ON_TARGET_5_last_match_average  \
# ID
# 12303                                       -1.0
# 12304                                       -6.0
# 12305                                        3.0
# 12306                                       -5.0
# 12307                                       -2.0
#
#        DIFF_DANGEROUS_ATTACKS_5_last_match_average  \
# ID
# 12303                                          0.0
# 12304                                          1.0
# 12305                                         10.0
# 12306                                         -4.0
# 12307                                         -4.0
#
#        DIFF_PLAYER_BLOCKED_SHOTS_5_last_match_average_mean_defender  \
# ID
# 12303                                           6.400000
# 12304                                           0.000000
# 12305                                         -19.000000
# 12306                                          24.833333
# 12307                                         -12.857143
#
#        DIFF_PLAYER_SAVES_INSIDE_BOX_5_last_match_average_mean_goalkeeper  \
# ID
# 12303                                              -13.0
# 12304                                                2.5
# 12305                                              -17.5
# 12306                                                6.0
# 12307                                              -11.5
#
#        DIFF_ATTACKS_5_last_match_average  \
# ID
# 12303                                0.0
# 12304                                0.0
# 12305                                2.0
# 12306                                3.0
# 12307                                0.0
#
#        DIFF_PLAYER_PASSES_5_last_match_average_mean_offensive  \
# ID
# 12303                                          -5.641775
# 12304                                         -15.288095
# 12305                                          -8.791667
# 12306                                           7.100000
# 12307                                           2.260714
#
#        DIFF_PLAYER_GOALKEEPER_GOALS_CONCEDED_season_average_mean_goalkeeper  \
# ID
# 12303                                                8.5
# 12304                                               -6.5
# 12305                                              -12.0
# 12306                                              -17.5
# 12307                                               11.5
#
#        DIFF_PLAYER_CLEARANCES_5_last_match_average_mean_defender  \
# ID
# 12303                                           7.966667
# 12304                                          13.750000
# 12305                                           1.166667
# 12306                                           6.333333
# 12307                                          -4.057143
#
#        DIFF_PLAYER_SHOTS_TOTAL_5_last_match_average_mean_offensive  \
# ID
# 12303                                          -9.633117
# 12304                                         -17.154762
# 12305                                          -4.494048
# 12306                                           1.600000
# 12307                                          -3.921429
#
#        DIFF_SUCCESSFUL_PASSES_PERCENTAGE_season_average  \
# ID
# 12303                                               2.0
# 12304                                              -7.0
# 12305                                               1.0
# 12306                                               1.0
# 12307                                              -2.0
#
#        DIFF_PLAYER_ASSISTS_5_last_match_average_mean_defender  \
# ID
# 12303                                           0.000000
# 12304                                           0.000000
# 12305                                          -2.750000
# 12306                                           0.000000
# 12307                                          -1.885714
#
#        DIFF_PLAYER_SAVES_5_last_match_average_mean_goalkeeper  \
# ID
# 12303                                              -12.5
# 12304                                                2.0
# 12305                                              -14.5
# 12306                                                0.0
# 12307                                                2.0
#
#        DIFF_GOALS_5_last_match_average  DIFF_SAVES_5_last_match_average  \
# ID
# 12303                              2.0                             -4.0
# 12304                             -4.0                              4.0
# 12305                             -1.0                             -2.0
# 12306                             -3.0                              3.0
# 12307                              2.0                              1.0
#
#        DIFF_PLAYER_YELLOWCARDS_5_last_match_average_mean_defender  \
# ID
# 12303                                          11.433333
# 12304                                           3.333333
# 12305                                         -27.500000
# 12306                                          10.000000
# 12307                                          -3.514286
#
#        DIFF_PLAYER_GOALS_5_last_match_average_mean_offensive  \
# ID
# 12303                                          -3.019481
# 12304                                         -16.904762
# 12305                                          -1.041667
# 12306                                           0.000000
# 12307                                           3.839286
#
#        DIFF_PLAYER_SHOTS_ON_TARGET_5_last_match_average_mean_offensive  \
# ID
# 12303                                         -14.778139
# 12304                                         -14.516667
# 12305                                           2.601190
# 12306                                           1.000000
# 12307                                          -4.017857
#
#        DIFF_PLAYER_ASSISTS_5_last_match_average_mean_offensive  \
# ID
# 12303                                           4.642857
# 12304                                         -10.380952
# 12305                                          -2.946429
# 12306                                           8.000000
# 12307                                           4.125000
#
#        DIFF_PLAYER_YELLOWCARDS_5_last_match_average_mean_offensive  \
# ID
# 12303                                         -19.352273
# 12304                                          -4.523810
# 12305                                           8.125000
# 12306                                          -8.000000
# 12307                                          13.917857
#
#        DIFF_PLAYER_RATING_season_average_mean_offensive  \
# ID
# 12303                                         -7.536797
# 12304                                        -18.602381
# 12305                                        -12.458333
# 12306                                          5.000000
# 12307                                         10.128571
#
#        DIFF_PLAYER_PENALTIES_WON_season_average_mean_offensive  \
# ID
# 12303                                            1.50000
# 12304                                          -15.10000
# 12305                                            4.60119
# 12306                                           -0.80000
# 12307                                            8.00000
#
#        DIFF_OFFSIDES_season_average  \
# ID
# 12303                          -3.0
# 12304                          -1.0
# 12305                          -7.0
# 12306                           3.0
# 12307                          -5.0
#
#        DIFF_SHOTS_OFF_TARGET_5_last_match_average  \
# ID
# 12303                                         0.0
# 12304                                         6.0
# 12305                                         1.0
# 12306                                        -2.0
# 12307                                         0.0
#
#        DIFF_PLAYER_PENALTIES_COMMITTED_season_average_mean_defender  \
# ID
# 12303                                          -5.200000
# 12304                                           9.833333
# 12305                                           1.166667
# 12306                                           7.333333
# 12307                                          -5.600000
#
#        DIFF_PLAYER_OFFSIDES_season_average_mean_offensive  \
# ID
# 12303                                          -4.070346
# 12304                                          -1.357143
# 12305                                          -1.196429
# 12306                                           7.800000
# 12307                                         -11.482143
#
#        DIFF_PLAYER_GOALS_5_last_match_average_mean_defender  \
# ID
# 12303                                           3.333333
# 12304                                           6.666667
# 12305                                           4.166667
# 12306                                          -4.166667
# 12307                                           0.000000
#
#        DIFF_PLAYER_GOALS_season_average_mean_defender  \
# ID
# 12303                                        0.900000
# 12304                                        4.666667
# 12305                                       -0.916667
# 12306                                        0.500000
# 12307                                        4.714286
#
#        DIFF_PLAYER_PENALTIES_SCORED_season_average_mean_offensive  \
# ID
# 12303                                          -2.142857
# 12304                                         -29.650000
# 12305                                           1.267857
# 12306                                          -3.500000
# 12307                                           3.125000
#
#        DIFF_PLAYER_ACCURATE_CROSSES_season_average_mean_offensive  \
# ID
# 12303                                          -2.076299
# 12304                                          -0.714286
# 12305                                           8.934524
# 12306                                          -8.700000
# 12307                                          -3.696429
#
#        DIFF_PLAYER_ACCURATE_CROSSES_season_average_mean_defender  \
# ID
# 12303                                           5.200000
# 12304                                           8.000000
# 12305                                         -10.416667
# 12306                                          -1.333333
# 12307                                           9.342857
#
#        DIFF_PLAYER_SHOTS_BLOCKED_5_last_match_average_mean_offensive  \
# ID
# 12303                                          -0.942641
# 12304                                          -2.628571
# 12305                                         -11.000000
# 12306                                           4.000000
# 12307                                           1.678571
#
#        DIFF_PLAYER_YELLOWCARDS_season_average_mean_defender  \
# ID
# 12303                                           8.600000
# 12304                                           4.583333
# 12305                                         -11.333333
# 12306                                           4.666667
# 12307                                          14.685714
#
#        DIFF_PLAYER_TOTAL_CROSSES_5_last_match_average_mean_offensive  \
# ID
# 12303                                          -2.250000
# 12304                                           1.414286
# 12305                                           8.994048
# 12306                                          -8.900000
# 12307                                          -6.075000
#
#        DIFF_PLAYER_AERIALS_WON_season_average_mean_offensive  \
# ID
# 12303                                         -18.590909
# 12304                                          -2.328571
# 12305                                          -0.148810
# 12306                                           4.000000
# 12307                                          -4.710714
#
#        DIFF_PLAYER_FOULS_5_last_match_average_mean_offensive  \
# ID
# 12303                                          -4.740260
# 12304                                           5.142857
# 12305                                           4.333333
# 12306                                          -5.800000
# 12307                                           4.267857
#
#        DIFF_PLAYER_MINUTES_PLAYED_season_average_mean_offensive  \
# ID
# 12303                                         -22.820346
# 12304                                         -22.016667
# 12305                                          -8.380952
# 12306                                           6.900000
# 12307                                          -6.132143
#
#        DIFF_PLAYER_TOTAL_CROSSES_season_average_mean_offensive  \
# ID
# 12303                                          -2.652597
# 12304                                          -0.835714
# 12305                                           8.809524
# 12306                                          -6.700000
# 12307                                          -6.303571
#
#        DIFF_PLAYER_MINUTES_PLAYED_5_last_match_average_mean_offensive  \
# ID
# 12303                                         -22.271645
# 12304                                         -22.821429
# 12305                                         -12.732143
# 12306                                          10.700000
# 12307                                           1.582143
#
#        DIFF_PLAYER_ACCURATE_PASSES_PERCENTAGE_5_last_match_average_mean_offensive  \
# ID
# 12303                                          10.403571
# 12304                                          -7.150000
# 12305                                           0.488095
# 12306                                          11.411111
# 12307                                           3.666667
#
#        DIFF_PLAYER_BIG_CHANCES_MISSED_season_average_mean_defender  \
# ID
# 12303                                           2.333333
# 12304                                           2.250000
# 12305                                          -0.500000
# 12306                                          -1.000000
# 12307                                           4.571429
#
#        DIFF_PLAYER_MINUTES_PLAYED_season_average_mean_goalkeeper  \
# ID
# 12303                                               -6.5
# 12304                                               -1.0
# 12305                                               -0.5
# 12306                                              -17.0
# 12307                                               10.0
#
#        DIFF_PLAYER_FOULS_season_average_mean_defender  \
# ID
# 12303                                       -1.533333
# 12304                                       21.833333
# 12305                                       -4.250000
# 12306                                       -2.833333
# 12307                                       12.028571
#
#        DIFF_PLAYER_GOALKEEPER_GOALS_CONCEDED_5_last_match_average_mean_goalkeeper  \
# ID
# 12303                                               11.0
# 12304                                                6.0
# 12305                                              -24.5
# 12306                                              -38.5
# 12307                                               -3.5
#
#        DIFF_PLAYER_ACCURATE_CROSSES_5_last_match_average_mean_offensive  \
# ID
# 12303                                          -2.434524
# 12304                                           2.892857
# 12305                                           8.666667
# 12306                                         -11.300000
# 12307                                          -3.750000
#
#        DIFF_PLAYER_HIT_WOODWORK_season_average_mean_offensive  \
# ID
# 12303                                          -8.500000
# 12304                                         -17.935714
# 12305                                          -6.714286
# 12306                                          -0.800000
# 12307                                          -0.196429
#
#        DIFF_PENALTIES_season_average  \
# ID
# 12303                            1.0
# 12304                           -7.0
# 12305                            4.0
# 12306                            0.0
# 12307                            2.0
#
#        DIFF_PLAYER_AERIALS_WON_season_average_mean_defender  \
# ID
# 12303                                           0.200000
# 12304                                          15.000000
# 12305                                           3.666667
# 12306                                          -1.833333
# 12307                                           4.971429
#
#        DIFF_PLAYER_CLEARANCE_OFFLINE_season_average_mean_defender  \
# ID
# 12303                                           0.000000
# 12304                                           3.833333
# 12305                                           2.083333
# 12306                                           1.000000
# 12307                                           6.742857
#
#        DIFF_PLAYER_OFFSIDES_5_last_match_average_mean_offensive  \
# ID
# 12303                                          -2.376082
# 12304                                          -8.466667
# 12305                                           1.928571
# 12306                                           2.700000
# 12307                                          -6.475000
#
#        DIFF_PLAYER_OWN_GOALS_season_average_mean_offensive  \
# ID
# 12303                                           2.090909
# 12304                                           0.000000
# 12305                                          -5.928571
# 12306                                           0.000000
# 12307                                           0.000000
#
#        DIFF_PLAYER_STARTING_LINEUP_season_average_mean_offensive  \
# ID
# 12303                                         -26.188853
# 12304                                         -24.173810
# 12305                                          -9.565476
# 12306                                           6.100000
# 12307                                          -7.103571
#
#        DIFF_PLAYER_PASSES_5_last_match_average_mean_defender  \
# ID
# 12303                                          13.633333
# 12304                                          11.833333
# 12305                                          10.166667
# 12306                                          12.000000
# 12307                                         -17.628571
#
#        DIFF_PLAYER_SUCCESSFUL_DRIBBLES_season_average_mean_offensive  \
# ID
# 12303                                           1.399351
# 12304                                          -7.104762
# 12305                                           1.547619
# 12306                                           4.500000
# 12307                                          -3.978571
#
#        DIFF_PLAYER_FOULS_5_last_match_average_mean_defender  \
# ID
# 12303                                          -0.566667
# 12304                                          23.166667
# 12305                                           0.333333
# 12306                                           1.000000
# 12307                                          16.142857
#
#        DIFF_GAME_LOST_5_last_match_average  \
# ID
# 12303                                  0.0
# 12304                                  3.0
# 12305                                 -5.0
# 12306                                  0.0
# 12307                                 -2.0
#
#        DIFF_PLAYER_KEY_PASSES_5_last_match_average_mean_defender  \
# ID
# 12303                                           4.000000
# 12304                                          13.000000
# 12305                                          -2.666667
# 12306                                           3.000000
# 12307                                          -6.828571
#
#        DIFF_PLAYER_MINUTES_PLAYED_season_average_mean_defender  \
# ID
# 12303                                           2.166667
# 12304                                          47.083333
# ...
#
#        DIFF_PLAYER_SAVES_INSIDE_BOX_5_last_match_average_mean_offensive  \
# ID
# 12303                                                0.0
# 12304                                                0.0
# 12305                                                0.0
# 12306                                                0.0
# 12307                                                0.0
#
#        DIFF_PLAYER_YELLOWCARDS_5_last_match_average_mean_goalkeeper  \
# ID
# 12303                                                0.0
# 12304                                                0.0
# 12305                                                0.0
# 12306                                               10.0
# 12307                                                0.0
#
#        DIFF_PLAYER_FOULS_DRAWN_season_average_mean_goalkeeper  \
# ID
# 12303                                                1.5
# 12304                                               -2.5
# 12305                                               -1.5
# 12306                                                5.0
# 12307                                               -3.5
#
#        DIFF_PLAYER_REDCARDS_5_last_match_average_mean_defender  \
# ID
# 12303                                                0.0
# 12304                                                0.0
# 12305                                                0.0
# 12306                                              -10.0
# 12307                                                0.0
#
#        DIFF_PLAYER_REDCARDS_season_average_mean_goalkeeper  \
# ID
# 12303                                                0.0
# 12304                                                0.0
# 12305                                                0.0
# 12306                                                0.0
# 12307                                                0.0
#
#        DIFF_PLAYER_PENALTIES_MISSES_5_last_match_average_mean_offensive  \
# ID
# 12303                                                0.0
# 12304                                                0.0
# 12305                                                0.0
# 12306                                                0.0
# 12307                                                0.0
#
#        DIFF_PLAYER_PENALTIES_MISSES_season_average_mean_defender  \
# ID
# 12303                                                0.0
# 12304                                                0.0
# 12305                                                0.0
# 12306                                                0.0
# 12307                                                0.0
#
#        DIFF_PLAYER_PENALTIES_SCORED_season_average_mean_defender  \
# ID
# 12303                                           0.000000
# 12304                                           4.166667
# 12305                                           0.000000
# 12306                                           0.000000
# 12307                                           0.000000
#
#        DIFF_PLAYER_ERROR_LEAD_TO_GOAL_5_last_match_average_mean_defender  \
# ID
# 12303                                                0.0
# 12304                                                0.0
# 12305                                                0.0
# 12306                                                0.0
# 12307                                                0.0
#
#        DIFF_PLAYER_INTERCEPTIONS_season_average_mean_goalkeeper  \
# ID
# 12303                                                2.0
# 12304                                                1.0
# 12305                                                2.5
# 12306                                                0.5
# 12307                                                0.0
#
#        DIFF_PLAYER_PENALTIES_WON_season_average_mean_defender  \
# ID
# 12303                                               -8.2
# 12304                                                0.0
# 12305                                                0.0
# 12306                                                0.0
# 12307                                                0.0
#
#        DIFF_PLAYER_TOTAL_DUELS_season_average_mean_goalkeeper  \
# ID
# 12303                                               -1.0
# 12304                                                0.0
# 12305                                                0.0
# 12306                                                0.5
# 12307                                               -0.5
#
#        DIFF_PLAYER_DRIBBLED_PAST_season_average_mean_goalkeeper  \
# ID
# 12303                                               -1.0
# 12304                                               -2.0
# 12305                                               -0.5
# 12306                                                0.0
# 12307                                                1.0
#
#        DIFF_PLAYER_OWN_GOALS_5_last_match_average_mean_offensive  \
# ID
# 12303                                           0.000000
# 12304                                           0.000000
# 12305                                         -16.666667
# 12306                                           0.000000
# 12307                                           0.000000
#
#        DIFF_PLAYER_TOTAL_DUELS_5_last_match_average_mean_goalkeeper  \
# ID
# 12303                                               -0.5
# 12304                                               -1.0
# 12305                                                0.0
# 12306                                                0.0
# 12307                                               -1.5
#
#        DIFF_PLAYER_ERROR_LEAD_TO_GOAL_5_last_match_average_mean_goalkeeper  \
# ID
# 12303                                               20.0
# 12304                                                0.0
# 12305                                                0.0
# 12306                                                0.0
# 12307                                                0.0
#
#        DIFF_PLAYER_DUELS_LOST_5_last_match_average_mean_goalkeeper  \
# ID
# 12303                                               -0.5
# 12304                                                0.0
# 12305                                                0.0
# 12306                                                0.5
# 12307                                                0.0
#
#        DIFF_PLAYER_ASSISTS_season_average_mean_goalkeeper  \
# ID
# 12303                                                0.0
# 12304                                                0.0
# 12305                                                2.5
# 12306                                                1.0
# 12307                                               -5.0
#
#        DIFF_PLAYER_KEY_PASSES_season_average_mean_goalkeeper  \
# ID
# 12303                                                0.0
# 12304                                                0.0
# 12305                                                0.5
# 12306                                               -0.5
# 12307                                                2.0
#
#        DIFF_PLAYER_OWN_GOALS_5_last_match_average_mean_defender  \
# ID
# 12303                                           0.000000
# 12304                                           8.333333
# 12305                                           0.000000
# 12306                                           0.000000
# 12307                                           0.000000
#
#        DIFF_PLAYER_TACKLES_5_last_match_average_mean_goalkeeper  \
# ID
# 12303                                                0.0
# 12304                                                0.0
# 12305                                                0.0
# 12306                                                0.0
# 12307                                                0.0
#
#        DIFF_PLAYER_DRIBBLED_PAST_5_last_match_average_mean_goalkeeper  \
# ID
# 12303                                               -3.0
# 12304                                                0.0
# 12305                                                0.0
# 12306                                                0.0
# 12307                                                0.0
#
#        DIFF_PLAYER_FOULS_season_average_mean_goalkeeper  \
# ID
# 12303                                               0.0
# 12304                                              -0.5
# 12305                                               0.0
# 12306                                               0.5
# 12307                                               0.5
#
#        DIFF_PLAYER_TACKLES_season_average_mean_goalkeeper  \
# ID
# 12303                                                0.0
# 12304                                                0.0
# 12305                                                0.0
# 12306                                                0.0
# 12307                                                0.0
#
#        DIFF_PLAYER_KEY_PASSES_5_last_match_average_mean_goalkeeper  \
# ID
# 12303                                                0.0
# 12304                                                0.0
# 12305                                                0.0
# 12306                                                0.0
# 12307                                                2.5
#
#        DIFF_PLAYER_INTERCEPTIONS_5_last_match_average_mean_goalkeeper  \
# ID
# 12303                                                2.0
# 12304                                                0.0
# 12305                                                6.0
# 12306                                                0.0
# 12307                                                0.0
#
#        DIFF_PLAYER_SUCCESSFUL_DRIBBLES_season_average_mean_goalkeeper  \
# ID
# 12303                                               -0.5
# 12304                                                0.0
# 12305                                               -1.0
# 12306                                               -0.5
# 12307                                                0.0
#
#        DIFF_PLAYER_SUCCESSFUL_DRIBBLES_5_last_match_average_mean_goalkeeper  \
# ID
# 12303                                                0.0
# 12304                                                0.0
# 12305                                               -2.5
# 12306                                                0.0
# 12307                                                0.0
#
#        DIFF_PLAYER_FOULS_5_last_match_average_mean_goalkeeper  \
# ID
# 12303                                                0.0
# 12304                                                0.0
# 12305                                                0.0
# 12306                                                2.0
# 12307                                                0.0
#
#        DIFF_PLAYER_DUELS_LOST_season_average_mean_goalkeeper  \
# ID
# 12303                                                0.0
# 12304                                               -0.5
# 12305                                                0.0
# 12306                                                0.0
# 12307                                                0.0
#
#        DIFF_PLAYER_PENALTIES_SCORED_5_last_match_average_mean_defender  \
# ID
# 12303                                           0.000000
# 12304                                           8.333333
# 12305                                           0.000000
# 12306                                           0.000000
# 12307                                           0.000000
#
#        DIFF_PLAYER_PENALTIES_SAVED_5_last_match_average_mean_goalkeeper  \
# ID
# 12303                                                0.0
# 12304                                                0.0
# 12305                                                0.0
# 12306                                                0.0
# 12307                                                0.0
#
#        DIFF_PLAYER_PENALTIES_COMMITTED_5_last_match_average_mean_goalkeeper
# ID
# 12303                                                0.0
# 12304                                                0.0
# 12305                                                0.0
# 12306                                                0.0
# 12307                                                0.0

# %%
# Store test data

test_data_path = PROCESSED_DATA_DIR / "test_data.csv"
test_aligned.to_csv(test_data_path, index=True)
