# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
elif PROJECT_ROOT.name.startswith("0"):
    PROJECT_ROOT = PROJECT_ROOT.parent.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings("ignore")

# Data Management
import json
import numpy as np
import pandas as pd

# Modelling
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import RandomForestClassifier

# Opti
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from match_forecast.utils import *
# Out:
# 2025-04-17 12:13:41.844 | INFO     | match_forecast.config:<module>:11 - PROJ_ROOT path is: /home/onyxia/work/QRT-Challenge-2024

# %%
PROJ_ROOT = Path("QRT-Challenge-2024").resolve().parents[1]
DATA_DIR = PROJ_ROOT / "data"
RAW_DATA_DIR = DATA_DIR / "raw"
PROCESSED_DATA_DIR = DATA_DIR / "processed"

# %%
try:
    train_data = pd.read_csv(PROCESSED_DATA_DIR / "train_data.csv", index_col=0)
    train_scores = pd.read_csv(RAW_DATA_DIR / "Y_train.csv", index_col=0)
    print("Files loaded")
    
except FileNotFoundError as e:
    print(e)
# Out:
# Files loaded

# %%
train_scores = train_scores.loc[train_data.index]
train_scores_1c = train_scores[['HOME_WINS', 'DRAW', 'AWAY_WINS']].idxmax(axis=1)
label_mapping = {'HOME_WINS': 0, 'DRAW': 1, 'AWAY_WINS': 2}
train_scores_1c = train_scores_1c.replace(label_mapping)

train_scores_1c.head(5)
# Out:
# ID
# 0    2
# 1    1
# 2    2
# 3    0
# 4    1
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(train_data, train_scores_1c, train_size=0.8, random_state=42)

# %%
space = {
    'n_estimators': hp.quniform('n_estimators', 100, 2000, 50),  
    'max_depth': hp.quniform('max_depth', 3, 30, 1),  
    'max_features': hp.uniform('max_features', 0.2, 0.8),
    'min_samples_split': hp.quniform('min_samples_split', 2, 50, 2),  
    'min_samples_leaf': hp.quniform('min_samples_leaf', 1, 20, 1),  
    'bootstrap': hp.choice('bootstrap', [True, False]),  
    'criterion': hp.choice('criterion', ['gini', 'entropy']),  
    'class_weight': hp.choice('class_weight', [None, 'balanced', 'balanced_subsample']),  
    'max_leaf_nodes': hp.quniform('max_leaf_nodes', 10, 1000, 10),  
    'min_impurity_decrease': hp.uniform('min_impurity_decrease', 0.0, 0.5)  
}

# %%
n_splits = 3

def objective(params):
    params['n_estimators'] = int(params['n_estimators'])
    params['max_depth'] = int(params['max_depth'])
    params['min_samples_split'] = int(params['min_samples_split'])
    params['min_samples_leaf'] = int(params['min_samples_leaf'])
    params['max_leaf_nodes'] = int(params['max_leaf_nodes']) if params['max_leaf_nodes'] is not None else None

    max_features = params['max_features']
    if isinstance(max_features, float):  # If it's a fraction, keep it
        params['max_features'] = max_features
    elif isinstance(max_features, str):  # Otherwise, keep string values like 'sqrt', 'log2'
        params['max_features'] = max_features
    else:  # If it's None, do nothing
        params['max_features'] = None
    
    # Stratified K-Fold Cross-Validation
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []

    for train_index, valid_index in skf.split(X_train, y_train):
        X_train_fold, X_valid_fold = X_train.iloc[train_index], X_train.iloc[valid_index]
        y_train_fold, y_valid_fold = y_train.iloc[train_index], y_train.iloc[valid_index]

        model = RandomForestClassifier(**params, n_jobs=-1, random_state=42)
        model.fit(X_train_fold, y_train_fold)

        y_pred = model.predict(X_valid_fold)
        accuracy = accuracy_score(y_valid_fold, y_pred)
        accuracies.append(accuracy)

    mean_loss = 1 - np.mean(accuracies)
    return {'loss': mean_loss, 'status': STATUS_OK}

# %%
trials = Trials()
best = fmin(fn=objective,
            space=space,
            algo=tpe.suggest,
            max_evals=150, 
            trials=trials)

print("Best hyperparameters:", best)
# Out:
# 100%|██████████| 150/150 [30:15<00:00, 12.10s/trial, best loss: 0.50619779315745]
# Best hyperparameters: {'bootstrap': np.int64(0), 'class_weight': np.int64(0), 'criterion': np.int64(1), 'max_depth': np.float64(28.0), 'max_features': np.float64(0.2680750004428999), 'max_leaf_nodes': np.float64(750.0), 'min_impurity_decrease': np.float64(0.0001767471340795863), 'min_samples_leaf': np.float64(3.0), 'min_samples_split': np.float64(14.0), 'n_estimators': np.float64(800.0)}

# %%
for trial in trials.trials:
    print(trial['result']['loss'], trial['misc']['vals'])
# Out:
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(10.0)], 'max_features': [np.float64(0.2709424915133423)], 'max_leaf_nodes': [np.float64(400.0)], 'min_impurity_decrease': [np.float64(0.29013316764157576)], 'min_samples_leaf': [np.float64(17.0)], 'min_samples_split': [np.float64(26.0)], 'n_estimators': [np.float64(1150.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(27.0)], 'max_features': [np.float64(0.5533272808909834)], 'max_leaf_nodes': [np.float64(730.0)], 'min_impurity_decrease': [np.float64(0.2666391642741491)], 'min_samples_leaf': [np.float64(17.0)], 'min_samples_split': [np.float64(26.0)], 'n_estimators': [np.float64(1000.0)]}
# 0.7244477628028339 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(5.0)], 'max_features': [np.float64(0.5627739913118228)], 'max_leaf_nodes': [np.float64(530.0)], 'min_impurity_decrease': [np.float64(0.452527934857721)], 'min_samples_leaf': [np.float64(8.0)], 'min_samples_split': [np.float64(42.0)], 'n_estimators': [np.float64(750.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(29.0)], 'max_features': [np.float64(0.4551223778438691)], 'max_leaf_nodes': [np.float64(390.0)], 'min_impurity_decrease': [np.float64(0.4423561075276247)], 'min_samples_leaf': [np.float64(14.0)], 'min_samples_split': [np.float64(32.0)], 'n_estimators': [np.float64(1150.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(16.0)], 'max_features': [np.float64(0.4308518257181855)], 'max_leaf_nodes': [np.float64(700.0)], 'min_impurity_decrease': [np.float64(0.28933550298043215)], 'min_samples_leaf': [np.float64(6.0)], 'min_samples_split': [np.float64(40.0)], 'n_estimators': [np.float64(800.0)]}
# 0.6813714649261702 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(18.0)], 'max_features': [np.float64(0.5348033524846915)], 'max_leaf_nodes': [np.float64(460.0)], 'min_impurity_decrease': [np.float64(0.0918527833509627)], 'min_samples_leaf': [np.float64(13.0)], 'min_samples_split': [np.float64(6.0)], 'n_estimators': [np.float64(100.0)]}
# 0.608814980560656 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(30.0)], 'max_features': [np.float64(0.617794000041926)], 'max_leaf_nodes': [np.float64(80.0)], 'min_impurity_decrease': [np.float64(0.07871193253915765)], 'min_samples_leaf': [np.float64(10.0)], 'min_samples_split': [np.float64(10.0)], 'n_estimators': [np.float64(250.0)]}
# 0.7244477628028339 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(17.0)], 'max_features': [np.float64(0.539362107662065)], 'max_leaf_nodes': [np.float64(750.0)], 'min_impurity_decrease': [np.float64(0.13402783846507604)], 'min_samples_leaf': [np.float64(10.0)], 'min_samples_split': [np.float64(24.0)], 'n_estimators': [np.float64(1950.0)]}
# 0.6813714649261702 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(23.0)], 'max_features': [np.float64(0.215126475827994)], 'max_leaf_nodes': [np.float64(650.0)], 'min_impurity_decrease': [np.float64(0.3354022482500008)], 'min_samples_leaf': [np.float64(18.0)], 'min_samples_split': [np.float64(16.0)], 'n_estimators': [np.float64(700.0)]}
# 0.6236654809781867 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(8.0)], 'max_features': [np.float64(0.7994734071599048)], 'max_leaf_nodes': [np.float64(620.0)], 'min_impurity_decrease': [np.float64(0.07174202024396481)], 'min_samples_leaf': [np.float64(2.0)], 'min_samples_split': [np.float64(26.0)], 'n_estimators': [np.float64(1950.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(4.0)], 'max_features': [np.float64(0.7775033635401871)], 'max_leaf_nodes': [np.float64(170.0)], 'min_impurity_decrease': [np.float64(0.4238641963580368)], 'min_samples_leaf': [np.float64(1.0)], 'min_samples_split': [np.float64(48.0)], 'n_estimators': [np.float64(800.0)]}
# 0.7244477628028339 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(17.0)], 'max_features': [np.float64(0.21068633908456125)], 'max_leaf_nodes': [np.float64(710.0)], 'min_impurity_decrease': [np.float64(0.17221429733396232)], 'min_samples_leaf': [np.float64(12.0)], 'min_samples_split': [np.float64(40.0)], 'n_estimators': [np.float64(1450.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(5.0)], 'max_features': [np.float64(0.4122229770018057)], 'max_leaf_nodes': [np.float64(330.0)], 'min_impurity_decrease': [np.float64(0.09848179739272495)], 'min_samples_leaf': [np.float64(10.0)], 'min_samples_split': [np.float64(28.0)], 'n_estimators': [np.float64(1800.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(29.0)], 'max_features': [np.float64(0.7322172147888122)], 'max_leaf_nodes': [np.float64(540.0)], 'min_impurity_decrease': [np.float64(0.028015841248276885)], 'min_samples_leaf': [np.float64(5.0)], 'min_samples_split': [np.float64(36.0)], 'n_estimators': [np.float64(1400.0)]}
# 0.7244477628028339 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(17.0)], 'max_features': [np.float64(0.608159432092835)], 'max_leaf_nodes': [np.float64(700.0)], 'min_impurity_decrease': [np.float64(0.4422715640708476)], 'min_samples_leaf': [np.float64(2.0)], 'min_samples_split': [np.float64(10.0)], 'n_estimators': [np.float64(1900.0)]}
# 0.6236654809781867 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(9.0)], 'max_features': [np.float64(0.5732242016839242)], 'max_leaf_nodes': [np.float64(540.0)], 'min_impurity_decrease': [np.float64(0.0639742704520232)], 'min_samples_leaf': [np.float64(8.0)], 'min_samples_split': [np.float64(34.0)], 'n_estimators': [np.float64(1600.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(14.0)], 'max_features': [np.float64(0.6938373220192757)], 'max_leaf_nodes': [np.float64(250.0)], 'min_impurity_decrease': [np.float64(0.17353952932172506)], 'min_samples_leaf': [np.float64(8.0)], 'min_samples_split': [np.float64(50.0)], 'n_estimators': [np.float64(100.0)]}
# 0.6236654809781867 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(5.0)], 'max_features': [np.float64(0.6912793797284789)], 'max_leaf_nodes': [np.float64(740.0)], 'min_impurity_decrease': [np.float64(0.07682385395282981)], 'min_samples_leaf': [np.float64(5.0)], 'min_samples_split': [np.float64(36.0)], 'n_estimators': [np.float64(1650.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(9.0)], 'max_features': [np.float64(0.36471351420547626)], 'max_leaf_nodes': [np.float64(170.0)], 'min_impurity_decrease': [np.float64(0.3798459844284572)], 'min_samples_leaf': [np.float64(6.0)], 'min_samples_split': [np.float64(42.0)], 'n_estimators': [np.float64(1950.0)]}
# 0.6237494517584614 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(12.0)], 'max_features': [np.float64(0.43109975789940286)], 'max_leaf_nodes': [np.float64(440.0)], 'min_impurity_decrease': [np.float64(0.08052576054692484)], 'min_samples_leaf': [np.float64(11.0)], 'min_samples_split': [np.float64(36.0)], 'n_estimators': [np.float64(800.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(24.0)], 'max_features': [np.float64(0.2988338694079679)], 'max_leaf_nodes': [np.float64(920.0)], 'min_impurity_decrease': [np.float64(0.2593947797765907)], 'min_samples_leaf': [np.float64(19.0)], 'min_samples_split': [np.float64(20.0)], 'n_estimators': [np.float64(1150.0)]}
# 0.6089165756028179 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(21.0)], 'max_features': [np.float64(0.297040657747413)], 'max_leaf_nodes': [np.float64(1000.0)], 'min_impurity_decrease': [np.float64(0.2177122456780109)], 'min_samples_leaf': [np.float64(16.0)], 'min_samples_split': [np.float64(18.0)], 'n_estimators': [np.float64(450.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(26.0)], 'max_features': [np.float64(0.4889770359366943)], 'max_leaf_nodes': [np.float64(920.0)], 'min_impurity_decrease': [np.float64(0.3205842915629562)], 'min_samples_leaf': [np.float64(16.0)], 'min_samples_split': [np.float64(22.0)], 'n_estimators': [np.float64(1000.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(11.0)], 'max_features': [np.float64(0.3373895215896662)], 'max_leaf_nodes': [np.float64(850.0)], 'min_impurity_decrease': [np.float64(0.49428955715987405)], 'min_samples_leaf': [np.float64(20.0)], 'min_samples_split': [np.float64(30.0)], 'n_estimators': [np.float64(1300.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(20.0)], 'max_features': [np.float64(0.6379592446248458)], 'max_leaf_nodes': [np.float64(330.0)], 'min_impurity_decrease': [np.float64(0.23162370299588192)], 'min_samples_leaf': [np.float64(17.0)], 'min_samples_split': [np.float64(14.0)], 'n_estimators': [np.float64(1050.0)]}
# 0.6089165756028179 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(14.0)], 'max_features': [np.float64(0.2511022761463114)], 'max_leaf_nodes': [np.float64(840.0)], 'min_impurity_decrease': [np.float64(0.3513129672324572)], 'min_samples_leaf': [np.float64(15.0)], 'min_samples_split': [np.float64(2.0)], 'n_estimators': [np.float64(450.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(27.0)], 'max_features': [np.float64(0.48947702304823304)], 'max_leaf_nodes': [np.float64(30.0)], 'min_impurity_decrease': [np.float64(0.3013205462442084)], 'min_samples_leaf': [np.float64(19.0)], 'min_samples_split': [np.float64(24.0)], 'n_estimators': [np.float64(950.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(7.0)], 'max_features': [np.float64(0.36410981899971673)], 'max_leaf_nodes': [np.float64(810.0)], 'min_impurity_decrease': [np.float64(0.38264249449565313)], 'min_samples_leaf': [np.float64(20.0)], 'min_samples_split': [np.float64(28.0)], 'n_estimators': [np.float64(600.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(12.0)], 'max_features': [np.float64(0.5668389593178788)], 'max_leaf_nodes': [np.float64(600.0)], 'min_impurity_decrease': [np.float64(0.27408055233656015)], 'min_samples_leaf': [np.float64(14.0)], 'min_samples_split': [np.float64(12.0)], 'n_estimators': [np.float64(1250.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(20.0)], 'max_features': [np.float64(0.6662049193332616)], 'max_leaf_nodes': [np.float64(480.0)], 'min_impurity_decrease': [np.float64(0.22378072461710388)], 'min_samples_leaf': [np.float64(17.0)], 'min_samples_split': [np.float64(20.0)], 'n_estimators': [np.float64(1550.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(3.0)], 'max_features': [np.float64(0.3928119064121371)], 'max_leaf_nodes': [np.float64(390.0)], 'min_impurity_decrease': [np.float64(0.18551552788327286)], 'min_samples_leaf': [np.float64(14.0)], 'min_samples_split': [np.float64(32.0)], 'n_estimators': [np.float64(950.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(14.0)], 'max_features': [np.float64(0.4706644559918909)], 'max_leaf_nodes': [np.float64(570.0)], 'min_impurity_decrease': [np.float64(0.3773683183440105)], 'min_samples_leaf': [np.float64(18.0)], 'min_samples_split': [np.float64(44.0)], 'n_estimators': [np.float64(1150.0)]}
# 0.6237494517584614 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(27.0)], 'max_features': [np.float64(0.27536360430984647)], 'max_leaf_nodes': [np.float64(250.0)], 'min_impurity_decrease': [np.float64(0.47415903290233763)], 'min_samples_leaf': [np.float64(13.0)], 'min_samples_split': [np.float64(30.0)], 'n_estimators': [np.float64(600.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(7.0)], 'max_features': [np.float64(0.5239005384234172)], 'max_leaf_nodes': [np.float64(990.0)], 'min_impurity_decrease': [np.float64(0.1393687178734702)], 'min_samples_leaf': [np.float64(15.0)], 'min_samples_split': [np.float64(4.0)], 'n_estimators': [np.float64(1300.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(23.0)], 'max_features': [np.float64(0.5944976690990613)], 'max_leaf_nodes': [np.float64(420.0)], 'min_impurity_decrease': [np.float64(0.29767992163717755)], 'min_samples_leaf': [np.float64(12.0)], 'min_samples_split': [np.float64(24.0)], 'n_estimators': [np.float64(1100.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(10.0)], 'max_features': [np.float64(0.5149344372427908)], 'max_leaf_nodes': [np.float64(330.0)], 'min_impurity_decrease': [np.float64(0.4108511499672366)], 'min_samples_leaf': [np.float64(19.0)], 'min_samples_split': [np.float64(16.0)], 'n_estimators': [np.float64(900.0)]}
# 0.6236654809781867 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(15.0)], 'max_features': [np.float64(0.45875124193944194)], 'max_leaf_nodes': [np.float64(490.0)], 'min_impurity_decrease': [np.float64(0.2525083504136305)], 'min_samples_leaf': [np.float64(17.0)], 'min_samples_split': [np.float64(8.0)], 'n_estimators': [np.float64(350.0)]}
# 0.6237494517584614 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(19.0)], 'max_features': [np.float64(0.7340780345415661)], 'max_leaf_nodes': [np.float64(670.0)], 'min_impurity_decrease': [np.float64(0.3475377181173745)], 'min_samples_leaf': [np.float64(15.0)], 'min_samples_split': [np.float64(26.0)], 'n_estimators': [np.float64(700.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(12.0)], 'max_features': [np.float64(0.2458400637308034)], 'max_leaf_nodes': [np.float64(780.0)], 'min_impurity_decrease': [np.float64(0.19295248315307673)], 'min_samples_leaf': [np.float64(9.0)], 'min_samples_split': [np.float64(20.0)], 'n_estimators': [np.float64(1700.0)]}
# 0.7244477628028339 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(6.0)], 'max_features': [np.float64(0.5507266935202896)], 'max_leaf_nodes': [np.float64(130.0)], 'min_impurity_decrease': [np.float64(0.12759562682581363)], 'min_samples_leaf': [np.float64(12.0)], 'min_samples_split': [np.float64(40.0)], 'n_estimators': [np.float64(1450.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(16.0)], 'max_features': [np.float64(0.41291842583509863)], 'max_leaf_nodes': [np.float64(240.0)], 'min_impurity_decrease': [np.float64(0.314595437595344)], 'min_samples_leaf': [np.float64(18.0)], 'min_samples_split': [np.float64(46.0)], 'n_estimators': [np.float64(1200.0)]}
# 0.7244477628028339 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(25.0)], 'max_features': [np.float64(0.3394011914412529)], 'max_leaf_nodes': [np.float64(640.0)], 'min_impurity_decrease': [np.float64(0.2694539912395629)], 'min_samples_leaf': [np.float64(13.0)], 'min_samples_split': [np.float64(32.0)], 'n_estimators': [np.float64(1350.0)]}
# 0.6236654809781867 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(29.0)], 'max_features': [np.float64(0.6510049906184194)], 'max_leaf_nodes': [np.float64(920.0)], 'min_impurity_decrease': [np.float64(0.2838519051260548)], 'min_samples_leaf': [np.float64(16.0)], 'min_samples_split': [np.float64(16.0)], 'n_estimators': [np.float64(850.0)]}
# 0.5090422994674932 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(30.0)], 'max_features': [np.float64(0.20020916304285477)], 'max_leaf_nodes': [np.float64(590.0)], 'min_impurity_decrease': [np.float64(0.0007145441544741116)], 'min_samples_leaf': [np.float64(13.0)], 'min_samples_split': [np.float64(28.0)], 'n_estimators': [np.float64(650.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(22.0)], 'max_features': [np.float64(0.20117541438178585)], 'max_leaf_nodes': [np.float64(590.0)], 'min_impurity_decrease': [np.float64(0.024844732799788667)], 'min_samples_leaf': [np.float64(11.0)], 'min_samples_split': [np.float64(38.0)], 'n_estimators': [np.float64(250.0)]}
# 0.7244477628028339 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(18.0)], 'max_features': [np.float64(0.2293233698183888)], 'max_leaf_nodes': [np.float64(380.0)], 'min_impurity_decrease': [np.float64(0.0479657434710912)], 'min_samples_leaf': [np.float64(14.0)], 'min_samples_split': [np.float64(28.0)], 'n_estimators': [np.float64(650.0)]}
# 0.5099567787433437 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(10.0)], 'max_features': [np.float64(0.2759548266151874)], 'max_leaf_nodes': [np.float64(520.0)], 'min_impurity_decrease': [np.float64(0.003132237208723354)], 'min_samples_leaf': [np.float64(9.0)], 'min_samples_split': [np.float64(34.0)], 'n_estimators': [np.float64(100.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(10.0)], 'max_features': [np.float64(0.3059994298484172)], 'max_leaf_nodes': [np.float64(510.0)], 'min_impurity_decrease': [np.float64(0.1105346730308232)], 'min_samples_leaf': [np.float64(6.0)], 'min_samples_split': [np.float64(34.0)], 'n_estimators': [np.float64(200.0)]}
# 0.5118873633113046 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(8.0)], 'max_features': [np.float64(0.25993424440657753)], 'max_leaf_nodes': [np.float64(670.0)], 'min_impurity_decrease': [np.float64(0.008922072196450232)], 'min_samples_leaf': [np.float64(7.0)], 'min_samples_split': [np.float64(50.0)], 'n_estimators': [np.float64(450.0)]}
# 0.5079248159519083 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(4.0)], 'max_features': [np.float64(0.21885271357237962)], 'max_leaf_nodes': [np.float64(290.0)], 'min_impurity_decrease': [np.float64(0.0022358999114153767)], 'min_samples_leaf': [np.float64(4.0)], 'min_samples_split': [np.float64(42.0)], 'n_estimators': [np.float64(300.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(3.0)], 'max_features': [np.float64(0.20349293484136613)], 'max_leaf_nodes': [np.float64(290.0)], 'min_impurity_decrease': [np.float64(0.05121879608339211)], 'min_samples_leaf': [np.float64(3.0)], 'min_samples_split': [np.float64(46.0)], 'n_estimators': [np.float64(350.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(29.0)], 'max_features': [np.float64(0.2251236304732267)], 'max_leaf_nodes': [np.float64(70.0)], 'min_impurity_decrease': [np.float64(0.1499614798823457)], 'min_samples_leaf': [np.float64(4.0)], 'min_samples_split': [np.float64(42.0)], 'n_estimators': [np.float64(550.0)]}
# 0.5195076419295128 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(28.0)], 'max_features': [np.float64(0.3231676903575497)], 'max_leaf_nodes': [np.float64(210.0)], 'min_impurity_decrease': [np.float64(0.025790051110310484)], 'min_samples_leaf': [np.float64(1.0)], 'min_samples_split': [np.float64(46.0)], 'n_estimators': [np.float64(200.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(25.0)], 'max_features': [np.float64(0.3797191707884924)], 'max_leaf_nodes': [np.float64(140.0)], 'min_impurity_decrease': [np.float64(0.10804450592961118)], 'min_samples_leaf': [np.float64(9.0)], 'min_samples_split': [np.float64(40.0)], 'n_estimators': [np.float64(500.0)]}
# 0.7244477628028339 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(13.0)], 'max_features': [np.float64(0.44211659620613775)], 'max_leaf_nodes': [np.float64(370.0)], 'min_impurity_decrease': [np.float64(0.04347999001640376)], 'min_samples_leaf': [np.float64(7.0)], 'min_samples_split': [np.float64(48.0)], 'n_estimators': [np.float64(350.0)]}
# 0.5077215019711916 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(4.0)], 'max_features': [np.float64(0.22981613126496886)], 'max_leaf_nodes': [np.float64(460.0)], 'min_impurity_decrease': [np.float64(0.0016387672153805061)], 'min_samples_leaf': [np.float64(2.0)], 'min_samples_split': [np.float64(38.0)], 'n_estimators': [np.float64(750.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(4.0)], 'max_features': [np.float64(0.3542849591532008)], 'max_leaf_nodes': [np.float64(300.0)], 'min_impurity_decrease': [np.float64(0.2047766031017737)], 'min_samples_leaf': [np.float64(2.0)], 'min_samples_split': [np.float64(38.0)], 'n_estimators': [np.float64(750.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(5.0)], 'max_features': [np.float64(0.2360354878323022)], 'max_leaf_nodes': [np.float64(460.0)], 'min_impurity_decrease': [np.float64(0.0932158245573743)], 'min_samples_leaf': [np.float64(4.0)], 'min_samples_split': [np.float64(48.0)], 'n_estimators': [np.float64(150.0)]}
# 0.7097164816893522 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(4.0)], 'max_features': [np.float64(0.31440733767198387)], 'max_leaf_nodes': [np.float64(30.0)], 'min_impurity_decrease': [np.float64(0.06531756706878489)], 'min_samples_leaf': [np.float64(3.0)], 'min_samples_split': [np.float64(44.0)], 'n_estimators': [np.float64(300.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(6.0)], 'max_features': [np.float64(0.28964238442096274)], 'max_leaf_nodes': [np.float64(210.0)], 'min_impurity_decrease': [np.float64(0.16271344824452047)], 'min_samples_leaf': [np.float64(5.0)], 'min_samples_split': [np.float64(38.0)], 'n_estimators': [np.float64(750.0)]}
# 0.5182886562940607 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(8.0)], 'max_features': [np.float64(0.38820294766339525)], 'max_leaf_nodes': [np.float64(90.0)], 'min_impurity_decrease': [np.float64(0.014992975557531485)], 'min_samples_leaf': [np.float64(1.0)], 'min_samples_split': [np.float64(44.0)], 'n_estimators': [np.float64(850.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(3.0)], 'max_features': [np.float64(0.7872730709695874)], 'max_leaf_nodes': [np.float64(420.0)], 'min_impurity_decrease': [np.float64(0.12491576684450087)], 'min_samples_leaf': [np.float64(3.0)], 'min_samples_split': [np.float64(36.0)], 'n_estimators': [np.float64(500.0)]}
# 0.7244477628028339 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(9.0)], 'max_features': [np.float64(0.4107975278659176)], 'max_leaf_nodes': [np.float64(290.0)], 'min_impurity_decrease': [np.float64(0.2400194111419935)], 'min_samples_leaf': [np.float64(2.0)], 'min_samples_split': [np.float64(42.0)], 'n_estimators': [np.float64(400.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(6.0)], 'max_features': [np.float64(0.2642923033327358)], 'max_leaf_nodes': [np.float64(550.0)], 'min_impurity_decrease': [np.float64(0.08222006948017185)], 'min_samples_leaf': [np.float64(4.0)], 'min_samples_split': [np.float64(32.0)], 'n_estimators': [np.float64(550.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(11.0)], 'max_features': [np.float64(0.2162699707833042)], 'max_leaf_nodes': [np.float64(460.0)], 'min_impurity_decrease': [np.float64(0.03531253366287118)], 'min_samples_leaf': [np.float64(7.0)], 'min_samples_split': [np.float64(40.0)], 'n_estimators': [np.float64(1050.0)]}
# 0.5105666897113956 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(7.0)], 'max_features': [np.float64(0.2863454514575794)], 'max_leaf_nodes': [np.float64(620.0)], 'min_impurity_decrease': [np.float64(0.007167614179586017)], 'min_samples_leaf': [np.float64(10.0)], 'min_samples_split': [np.float64(30.0)], 'n_estimators': [np.float64(650.0)]}
# 0.507822880194666 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(16.0)], 'max_features': [np.float64(0.2025646306212713)], 'max_leaf_nodes': [np.float64(360.0)], 'min_impurity_decrease': [np.float64(0.001487828196128092)], 'min_samples_leaf': [np.float64(11.0)], 'min_samples_split': [np.float64(22.0)], 'n_estimators': [np.float64(850.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(16.0)], 'max_features': [np.float64(0.32740860237697106)], 'max_leaf_nodes': [np.float64(360.0)], 'min_impurity_decrease': [np.float64(0.049626747994823917)], 'min_samples_leaf': [np.float64(11.0)], 'min_samples_split': [np.float64(22.0)], 'n_estimators': [np.float64(1000.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(5.0)], 'max_features': [np.float64(0.3482249657839641)], 'max_leaf_nodes': [np.float64(340.0)], 'min_impurity_decrease': [np.float64(0.07169223230879801)], 'min_samples_leaf': [np.float64(8.0)], 'min_samples_split': [np.float64(22.0)], 'n_estimators': [np.float64(850.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(13.0)], 'max_features': [np.float64(0.2338009097800436)], 'max_leaf_nodes': [np.float64(410.0)], 'min_impurity_decrease': [np.float64(0.10684614415173728)], 'min_samples_leaf': [np.float64(6.0)], 'min_samples_split': [np.float64(18.0)], 'n_estimators': [np.float64(950.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(18.0)], 'max_features': [np.float64(0.24992318295629318)], 'max_leaf_nodes': [np.float64(190.0)], 'min_impurity_decrease': [np.float64(0.059030005082205655)], 'min_samples_leaf': [np.float64(1.0)], 'min_samples_split': [np.float64(12.0)], 'n_estimators': [np.float64(800.0)]}
# 0.5177806191350545 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(21.0)], 'max_features': [np.float64(0.20098820852719512)], 'max_leaf_nodes': [np.float64(260.0)], 'min_impurity_decrease': [np.float64(0.01675550426539206)], 'min_samples_leaf': [np.float64(6.0)], 'min_samples_split': [np.float64(24.0)], 'n_estimators': [np.float64(1200.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(8.0)], 'max_features': [np.float64(0.27940771561979827)], 'max_leaf_nodes': [np.float64(320.0)], 'min_impurity_decrease': [np.float64(0.03762647681919637)], 'min_samples_leaf': [np.float64(8.0)], 'min_samples_split': [np.float64(26.0)], 'n_estimators': [np.float64(1100.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(15.0)], 'max_features': [np.float64(0.37348304812773164)], 'max_leaf_nodes': [np.float64(160.0)], 'min_impurity_decrease': [np.float64(0.14698530918177333)], 'min_samples_leaf': [np.float64(12.0)], 'min_samples_split': [np.float64(50.0)], 'n_estimators': [np.float64(900.0)]}
# 0.511582051625149 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(4.0)], 'max_features': [np.float64(0.7468018903766123)], 'max_leaf_nodes': [np.float64(100.0)], 'min_impurity_decrease': [np.float64(0.00010276814952575337)], 'min_samples_leaf': [np.float64(9.0)], 'min_samples_split': [np.float64(30.0)], 'n_estimators': [np.float64(600.0)]}
# 0.7244477628028339 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(6.0)], 'max_features': [np.float64(0.21348142034623566)], 'max_leaf_nodes': [np.float64(490.0)], 'min_impurity_decrease': [np.float64(0.09705119630830697)], 'min_samples_leaf': [np.float64(10.0)], 'min_samples_split': [np.float64(34.0)], 'n_estimators': [np.float64(1450.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(11.0)], 'max_features': [np.float64(0.3013639623000651)], 'max_leaf_nodes': [np.float64(440.0)], 'min_impurity_decrease': [np.float64(0.08612552459549719)], 'min_samples_leaf': [np.float64(5.0)], 'min_samples_split': [np.float64(18.0)], 'n_estimators': [np.float64(700.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(9.0)], 'max_features': [np.float64(0.47692707207174356)], 'max_leaf_nodes': [np.float64(270.0)], 'min_impurity_decrease': [np.float64(0.16713664559266228)], 'min_samples_leaf': [np.float64(4.0)], 'min_samples_split': [np.float64(14.0)], 'n_estimators': [np.float64(1850.0)]}
# 0.5228615792329823 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(19.0)], 'max_features': [np.float64(0.5814960168213144)], 'max_leaf_nodes': [np.float64(230.0)], 'min_impurity_decrease': [np.float64(0.02687947034082111)], 'min_samples_leaf': [np.float64(11.0)], 'min_samples_split': [np.float64(38.0)], 'n_estimators': [np.float64(250.0)]}
# 0.7244477628028339 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(23.0)], 'max_features': [np.float64(0.26406166007098864)], 'max_leaf_nodes': [np.float64(560.0)], 'min_impurity_decrease': [np.float64(0.1885387933271273)], 'min_samples_leaf': [np.float64(3.0)], 'min_samples_split': [np.float64(8.0)], 'n_estimators': [np.float64(500.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(3.0)], 'max_features': [np.float64(0.403086087276317)], 'max_leaf_nodes': [np.float64(350.0)], 'min_impurity_decrease': [np.float64(0.12039450631241294)], 'min_samples_leaf': [np.float64(7.0)], 'min_samples_split': [np.float64(36.0)], 'n_estimators': [np.float64(400.0)]}
# 0.7244477628028339 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(13.0)], 'max_features': [np.float64(0.4273788171194095)], 'max_leaf_nodes': [np.float64(390.0)], 'min_impurity_decrease': [np.float64(0.05752706936966701)], 'min_samples_leaf': [np.float64(2.0)], 'min_samples_split': [np.float64(42.0)], 'n_estimators': [np.float64(1100.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(7.0)], 'max_features': [np.float64(0.24236305348384898)], 'max_leaf_nodes': [np.float64(710.0)], 'min_impurity_decrease': [np.float64(0.40608038767911686)], 'min_samples_leaf': [np.float64(13.0)], 'min_samples_split': [np.float64(26.0)], 'n_estimators': [np.float64(1500.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(11.0)], 'max_features': [np.float64(0.22133176166322677)], 'max_leaf_nodes': [np.float64(310.0)], 'min_impurity_decrease': [np.float64(0.2103198656019333)], 'min_samples_leaf': [np.float64(10.0)], 'min_samples_split': [np.float64(44.0)], 'n_estimators': [np.float64(750.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(26.0)], 'max_features': [np.float64(0.503230411406367)], 'max_leaf_nodes': [np.float64(120.0)], 'min_impurity_decrease': [np.float64(0.48945023129812965)], 'min_samples_leaf': [np.float64(5.0)], 'min_samples_split': [np.float64(32.0)], 'n_estimators': [np.float64(1350.0)]}
# 0.7244477628028339 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(15.0)], 'max_features': [np.float64(0.3150161774985052)], 'max_leaf_nodes': [np.float64(440.0)], 'min_impurity_decrease': [np.float64(0.07058094093825477)], 'min_samples_leaf': [np.float64(9.0)], 'min_samples_split': [np.float64(22.0)], 'n_estimators': [np.float64(1700.0)]}
# 0.7244477628028339 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(17.0)], 'max_features': [np.float64(0.3371324092377501)], 'max_leaf_nodes': [np.float64(10.0)], 'min_impurity_decrease': [np.float64(0.45852040543177697)], 'min_samples_leaf': [np.float64(12.0)], 'min_samples_split': [np.float64(30.0)], 'n_estimators': [np.float64(900.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(5.0)], 'max_features': [np.float64(0.2564100078248708)], 'max_leaf_nodes': [np.float64(60.0)], 'min_impurity_decrease': [np.float64(0.03848600248910486)], 'min_samples_leaf': [np.float64(2.0)], 'min_samples_split': [np.float64(28.0)], 'n_estimators': [np.float64(1250.0)]}
# 0.5197109249361314 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(12.0)], 'max_features': [np.float64(0.3664591480669864)], 'max_leaf_nodes': [np.float64(520.0)], 'min_impurity_decrease': [np.float64(0.01747991901868995)], 'min_samples_leaf': [np.float64(8.0)], 'min_samples_split': [np.float64(46.0)], 'n_estimators': [np.float64(700.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(21.0)], 'max_features': [np.float64(0.6084033020290001)], 'max_leaf_nodes': [np.float64(180.0)], 'min_impurity_decrease': [np.float64(0.13425519437392344)], 'min_samples_leaf': [np.float64(6.0)], 'min_samples_split': [np.float64(4.0)], 'n_estimators': [np.float64(150.0)]}
# 0.7244477628028339 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(14.0)], 'max_features': [np.float64(0.693412130821597)], 'max_leaf_nodes': [np.float64(220.0)], 'min_impurity_decrease': [np.float64(0.15669416314662438)], 'min_samples_leaf': [np.float64(15.0)], 'min_samples_split': [np.float64(24.0)], 'n_estimators': [np.float64(1000.0)]}
# 0.7244477628028339 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(24.0)], 'max_features': [np.float64(0.5348882484155719)], 'max_leaf_nodes': [np.float64(670.0)], 'min_impurity_decrease': [np.float64(0.17449369487658017)], 'min_samples_leaf': [np.float64(1.0)], 'min_samples_split': [np.float64(48.0)], 'n_estimators': [np.float64(550.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(7.0)], 'max_features': [np.float64(0.35246138736306165)], 'max_leaf_nodes': [np.float64(480.0)], 'min_impurity_decrease': [np.float64(0.11996041474794751)], 'min_samples_leaf': [np.float64(11.0)], 'min_samples_split': [np.float64(20.0)], 'n_estimators': [np.float64(300.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(9.0)], 'max_features': [np.float64(0.29093309695991054)], 'max_leaf_nodes': [np.float64(280.0)], 'min_impurity_decrease': [np.float64(0.07921543433794952)], 'min_samples_leaf': [np.float64(14.0)], 'min_samples_split': [np.float64(36.0)], 'n_estimators': [np.float64(450.0)]}
# 0.50619779315745 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(28.0)], 'max_features': [np.float64(0.2680750004428999)], 'max_leaf_nodes': [np.float64(750.0)], 'min_impurity_decrease': [np.float64(0.0001767471340795863)], 'min_samples_leaf': [np.float64(3.0)], 'min_samples_split': [np.float64(14.0)], 'n_estimators': [np.float64(800.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(30.0)], 'max_features': [np.float64(0.44909407139854574)], 'max_leaf_nodes': [np.float64(870.0)], 'min_impurity_decrease': [np.float64(0.10071101956555337)], 'min_samples_leaf': [np.float64(3.0)], 'min_samples_split': [np.float64(10.0)], 'n_estimators': [np.float64(950.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(28.0)], 'max_features': [np.float64(0.6301030895753066)], 'max_leaf_nodes': [np.float64(740.0)], 'min_impurity_decrease': [np.float64(0.3631494408831542)], 'min_samples_leaf': [np.float64(7.0)], 'min_samples_split': [np.float64(14.0)], 'n_estimators': [np.float64(1050.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(19.0)], 'max_features': [np.float64(0.5495612044947371)], 'max_leaf_nodes': [np.float64(900.0)], 'min_impurity_decrease': [np.float64(0.05716566787668149)], 'min_samples_leaf': [np.float64(13.0)], 'min_samples_split': [np.float64(12.0)], 'n_estimators': [np.float64(1200.0)]}
# 0.5362726823321267 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(22.0)], 'max_features': [np.float64(0.31025598380715014)], 'max_leaf_nodes': [np.float64(980.0)], 'min_impurity_decrease': [np.float64(0.031126026903905497)], 'min_samples_leaf': [np.float64(16.0)], 'min_samples_split': [np.float64(16.0)], 'n_estimators': [np.float64(850.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(26.0)], 'max_features': [np.float64(0.2689423069311665)], 'max_leaf_nodes': [np.float64(960.0)], 'min_impurity_decrease': [np.float64(0.31543033509294954)], 'min_samples_leaf': [np.float64(8.0)], 'min_samples_split': [np.float64(6.0)], 'n_estimators': [np.float64(650.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(20.0)], 'max_features': [np.float64(0.6686968487656165)], 'max_leaf_nodes': [np.float64(820.0)], 'min_impurity_decrease': [np.float64(0.19806313229339717)], 'min_samples_leaf': [np.float64(5.0)], 'min_samples_split': [np.float64(8.0)], 'n_estimators': [np.float64(800.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(28.0)], 'max_features': [np.float64(0.23931305462267533)], 'max_leaf_nodes': [np.float64(690.0)], 'min_impurity_decrease': [np.float64(0.2353192903473334)], 'min_samples_leaf': [np.float64(12.0)], 'min_samples_split': [np.float64(2.0)], 'n_estimators': [np.float64(750.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(25.0)], 'max_features': [np.float64(0.4693651996765646)], 'max_leaf_nodes': [np.float64(790.0)], 'min_impurity_decrease': [np.float64(0.08756100790385311)], 'min_samples_leaf': [np.float64(1.0)], 'min_samples_split': [np.float64(16.0)], 'n_estimators': [np.float64(1150.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(24.0)], 'max_features': [np.float64(0.4224587076893922)], 'max_leaf_nodes': [np.float64(630.0)], 'min_impurity_decrease': [np.float64(0.1426596580079921)], 'min_samples_leaf': [np.float64(2.0)], 'min_samples_split': [np.float64(22.0)], 'n_estimators': [np.float64(600.0)]}
# 0.5353580481857851 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(22.0)], 'max_features': [np.float64(0.390734974309347)], 'max_leaf_nodes': [np.float64(760.0)], 'min_impurity_decrease': [np.float64(0.01608546947060742)], 'min_samples_leaf': [np.float64(18.0)], 'min_samples_split': [np.float64(18.0)], 'n_estimators': [np.float64(1000.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(27.0)], 'max_features': [np.float64(0.32874293284509115)], 'max_leaf_nodes': [np.float64(540.0)], 'min_impurity_decrease': [np.float64(0.32766170827742025)], 'min_samples_leaf': [np.float64(9.0)], 'min_samples_split': [np.float64(20.0)], 'n_estimators': [np.float64(1300.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(18.0)], 'max_features': [np.float64(0.20486885237248015)], 'max_leaf_nodes': [np.float64(720.0)], 'min_impurity_decrease': [np.float64(0.1820150701918987)], 'min_samples_leaf': [np.float64(10.0)], 'min_samples_split': [np.float64(14.0)], 'n_estimators': [np.float64(700.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(17.0)], 'max_features': [np.float64(0.2762082967978502)], 'max_leaf_nodes': [np.float64(570.0)], 'min_impurity_decrease': [np.float64(0.284005139931985)], 'min_samples_leaf': [np.float64(7.0)], 'min_samples_split': [np.float64(6.0)], 'n_estimators': [np.float64(2000.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(23.0)], 'max_features': [np.float64(0.24821084341631766)], 'max_leaf_nodes': [np.float64(600.0)], 'min_impurity_decrease': [np.float64(0.2536642932616849)], 'min_samples_leaf': [np.float64(4.0)], 'min_samples_split': [np.float64(12.0)], 'n_estimators': [np.float64(1100.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(14.0)], 'max_features': [np.float64(0.2281603991435588)], 'max_leaf_nodes': [np.float64(770.0)], 'min_impurity_decrease': [np.float64(0.2249052785545235)], 'min_samples_leaf': [np.float64(3.0)], 'min_samples_split': [np.float64(18.0)], 'n_estimators': [np.float64(900.0)]}
# 0.6813714649261702 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(16.0)], 'max_features': [np.float64(0.379690232381535)], 'max_leaf_nodes': [np.float64(500.0)], 'min_impurity_decrease': [np.float64(0.11253529629515527)], 'min_samples_leaf': [np.float64(14.0)], 'min_samples_split': [np.float64(4.0)], 'n_estimators': [np.float64(800.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(20.0)], 'max_features': [np.float64(0.3395583470943909)], 'max_leaf_nodes': [np.float64(660.0)], 'min_impurity_decrease': [np.float64(0.04841484495425618)], 'min_samples_leaf': [np.float64(11.0)], 'min_samples_split': [np.float64(10.0)], 'n_estimators': [np.float64(400.0)]}
# 0.5087376692114987 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(29.0)], 'max_features': [np.float64(0.2934418999178852)], 'max_leaf_nodes': [np.float64(690.0)], 'min_impurity_decrease': [np.float64(0.007322069895407163)], 'min_samples_leaf': [np.float64(6.0)], 'min_samples_split': [np.float64(28.0)], 'n_estimators': [np.float64(550.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(28.0)], 'max_features': [np.float64(0.21338297765207404)], 'max_leaf_nodes': [np.float64(400.0)], 'min_impurity_decrease': [np.float64(0.06510716630882507)], 'min_samples_leaf': [np.float64(15.0)], 'min_samples_split': [np.float64(10.0)], 'n_estimators': [np.float64(1400.0)]}
# 0.7244477628028339 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(13.0)], 'max_features': [np.float64(0.2001327480929682)], 'max_leaf_nodes': [np.float64(460.0)], 'min_impurity_decrease': [np.float64(0.42287455573768756)], 'min_samples_leaf': [np.float64(5.0)], 'min_samples_split': [np.float64(34.0)], 'n_estimators': [np.float64(1600.0)]}
# 0.5200157100626173 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(26.0)], 'max_features': [np.float64(0.3993323238975551)], 'max_leaf_nodes': [np.float64(860.0)], 'min_impurity_decrease': [np.float64(0.023394456255014885)], 'min_samples_leaf': [np.float64(12.0)], 'min_samples_split': [np.float64(24.0)], 'n_estimators': [np.float64(1050.0)]}
# 0.5481602314880205 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(15.0)], 'max_features': [np.float64(0.7085174566635539)], 'max_leaf_nodes': [np.float64(950.0)], 'min_impurity_decrease': [np.float64(0.038753159450900646)], 'min_samples_leaf': [np.float64(16.0)], 'min_samples_split': [np.float64(26.0)], 'n_estimators': [np.float64(1250.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(18.0)], 'max_features': [np.float64(0.32077788974825205)], 'max_leaf_nodes': [np.float64(800.0)], 'min_impurity_decrease': [np.float64(0.13342018109665366)], 'min_samples_leaf': [np.float64(10.0)], 'min_samples_split': [np.float64(20.0)], 'n_estimators': [np.float64(950.0)]}
# 0.5109731008541418 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(10.0)], 'max_features': [np.float64(0.5139620538643315)], 'max_leaf_nodes': [np.float64(430.0)], 'min_impurity_decrease': [np.float64(0.0015647605635569805)], 'min_samples_leaf': [np.float64(1.0)], 'min_samples_split': [np.float64(16.0)], 'n_estimators': [np.float64(750.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(16.0)], 'max_features': [np.float64(0.3650425599443039)], 'max_leaf_nodes': [np.float64(620.0)], 'min_impurity_decrease': [np.float64(0.07562618342216629)], 'min_samples_leaf': [np.float64(8.0)], 'min_samples_split': [np.float64(28.0)], 'n_estimators': [np.float64(850.0)]}
# 0.7244477628028339 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(21.0)], 'max_features': [np.float64(0.2557766099936199)], 'max_leaf_nodes': [np.float64(590.0)], 'min_impurity_decrease': [np.float64(0.09063880076321491)], 'min_samples_leaf': [np.float64(4.0)], 'min_samples_split': [np.float64(24.0)], 'n_estimators': [np.float64(1150.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(24.0)], 'max_features': [np.float64(0.4426314191917854)], 'max_leaf_nodes': [np.float64(830.0)], 'min_impurity_decrease': [np.float64(0.10359661414769629)], 'min_samples_leaf': [np.float64(14.0)], 'min_samples_split': [np.float64(12.0)], 'n_estimators': [np.float64(650.0)]}
# 0.6116727437847373 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(27.0)], 'max_features': [np.float64(0.756752331345997)], 'max_leaf_nodes': [np.float64(350.0)], 'min_impurity_decrease': [np.float64(0.04448972015609064)], 'min_samples_leaf': [np.float64(17.0)], 'min_samples_split': [np.float64(32.0)], 'n_estimators': [np.float64(500.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(11.0)], 'max_features': [np.float64(0.30268441056480855)], 'max_leaf_nodes': [np.float64(890.0)], 'min_impurity_decrease': [np.float64(0.15649082197199596)], 'min_samples_leaf': [np.float64(20.0)], 'min_samples_split': [np.float64(14.0)], 'n_estimators': [np.float64(900.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(19.0)], 'max_features': [np.float64(0.28199957720162805)], 'max_leaf_nodes': [np.float64(530.0)], 'min_impurity_decrease': [np.float64(0.26432219122335715)], 'min_samples_leaf': [np.float64(9.0)], 'min_samples_split': [np.float64(18.0)], 'n_estimators': [np.float64(800.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(22.0)], 'max_features': [np.float64(0.4881889633383309)], 'max_leaf_nodes': [np.float64(250.0)], 'min_impurity_decrease': [np.float64(0.2971720225491083)], 'min_samples_leaf': [np.float64(13.0)], 'min_samples_split': [np.float64(30.0)], 'n_estimators': [np.float64(700.0)]}
# 0.5110744171294197 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(8.0)], 'max_features': [np.float64(0.23136433724172747)], 'max_leaf_nodes': [np.float64(650.0)], 'min_impurity_decrease': [np.float64(0.01350784037900375)], 'min_samples_leaf': [np.float64(3.0)], 'min_samples_split': [np.float64(20.0)], 'n_estimators': [np.float64(1350.0)]}
# 0.5407431429541361 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(25.0)], 'max_features': [np.float64(0.3518129691376454)], 'max_leaf_nodes': [np.float64(470.0)], 'min_impurity_decrease': [np.float64(0.02834992524286454)], 'min_samples_leaf': [np.float64(7.0)], 'min_samples_split': [np.float64(6.0)], 'n_estimators': [np.float64(450.0)]}
# 0.7244477628028339 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(21.0)], 'max_features': [np.float64(0.5899362689360237)], 'max_leaf_nodes': [np.float64(390.0)], 'min_impurity_decrease': [np.float64(0.1179635318874367)], 'min_samples_leaf': [np.float64(2.0)], 'min_samples_split': [np.float64(40.0)], 'n_estimators': [np.float64(350.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(23.0)], 'max_features': [np.float64(0.2199075939327232)], 'max_leaf_nodes': [np.float64(150.0)], 'min_impurity_decrease': [np.float64(0.39719794043317813)], 'min_samples_leaf': [np.float64(1.0)], 'min_samples_split': [np.float64(22.0)], 'n_estimators': [np.float64(950.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(15.0)], 'max_features': [np.float64(0.4177293739448158)], 'max_leaf_nodes': [np.float64(730.0)], 'min_impurity_decrease': [np.float64(0.3420777084013188)], 'min_samples_leaf': [np.float64(6.0)], 'min_samples_split': [np.float64(26.0)], 'n_estimators': [np.float64(200.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(20.0)], 'max_features': [np.float64(0.4616889989860079)], 'max_leaf_nodes': [np.float64(370.0)], 'min_impurity_decrease': [np.float64(0.05644732174234533)], 'min_samples_leaf': [np.float64(19.0)], 'min_samples_split': [np.float64(8.0)], 'n_estimators': [np.float64(600.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(6.0)], 'max_features': [np.float64(0.33467537317826535)], 'max_leaf_nodes': [np.float64(320.0)], 'min_impurity_decrease': [np.float64(0.06718040315877619)], 'min_samples_leaf': [np.float64(4.0)], 'min_samples_split': [np.float64(16.0)], 'n_estimators': [np.float64(1000.0)]}
# 0.7244477628028339 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(12.0)], 'max_features': [np.float64(0.2637199155197133)], 'max_leaf_nodes': [np.float64(450.0)], 'min_impurity_decrease': [np.float64(0.09659596554551758)], 'min_samples_leaf': [np.float64(2.0)], 'min_samples_split': [np.float64(38.0)], 'n_estimators': [np.float64(1500.0)]}
# 0.6088280826042032 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(10.0)], 'max_features': [np.float64(0.3095597455796555)], 'max_leaf_nodes': [np.float64(410.0)], 'min_impurity_decrease': [np.float64(0.43909944745341034)], 'min_samples_leaf': [np.float64(7.0)], 'min_samples_split': [np.float64(32.0)], 'n_estimators': [np.float64(1100.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(30.0)], 'max_features': [np.float64(0.24086984017295954)], 'max_leaf_nodes': [np.float64(560.0)], 'min_impurity_decrease': [np.float64(0.21161282629713118)], 'min_samples_leaf': [np.float64(11.0)], 'min_samples_split': [np.float64(2.0)], 'n_estimators': [np.float64(1200.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(4.0)], 'max_features': [np.float64(0.43200274389612225)], 'max_leaf_nodes': [np.float64(510.0)], 'min_impurity_decrease': [np.float64(0.24592626322197103)], 'min_samples_leaf': [np.float64(9.0)], 'min_samples_split': [np.float64(34.0)], 'n_estimators': [np.float64(600.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(14.0)], 'max_features': [np.float64(0.27416921187273097)], 'max_leaf_nodes': [np.float64(200.0)], 'min_impurity_decrease': [np.float64(0.1728954231468585)], 'min_samples_leaf': [np.float64(5.0)], 'min_samples_split': [np.float64(14.0)], 'n_estimators': [np.float64(100.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(18.0)], 'max_features': [np.float64(0.206915774251556)], 'max_leaf_nodes': [np.float64(110.0)], 'min_impurity_decrease': [np.float64(0.07922558551929501)], 'min_samples_leaf': [np.float64(12.0)], 'min_samples_split': [np.float64(24.0)], 'n_estimators': [np.float64(850.0)]}
# 0.5686849389066886 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(1)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(29.0)], 'max_features': [np.float64(0.2978837753954893)], 'max_leaf_nodes': [np.float64(600.0)], 'min_impurity_decrease': [np.float64(0.020452086133956493)], 'min_samples_leaf': [np.float64(10.0)], 'min_samples_split': [np.float64(30.0)], 'n_estimators': [np.float64(700.0)]}
# 0.5077213161266023 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(26.0)], 'max_features': [np.float64(0.3856321381571234)], 'max_leaf_nodes': [np.float64(330.0)], 'min_impurity_decrease': [np.float64(0.0016263989169196219)], 'min_samples_leaf': [np.float64(6.0)], 'min_samples_split': [np.float64(22.0)], 'n_estimators': [np.float64(1750.0)]}
# 0.5502945326999749 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(2)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(28.0)], 'max_features': [np.float64(0.5637209066015764)], 'max_leaf_nodes': [np.float64(270.0)], 'min_impurity_decrease': [np.float64(0.001882732629559041)], 'min_samples_leaf': [np.float64(4.0)], 'min_samples_split': [np.float64(10.0)], 'n_estimators': [np.float64(1750.0)]}
# 0.5197109249361314 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(24.0)], 'max_features': [np.float64(0.38271398989955585)], 'max_leaf_nodes': [np.float64(750.0)], 'min_impurity_decrease': [np.float64(0.0315377519158761)], 'min_samples_leaf': [np.float64(2.0)], 'min_samples_split': [np.float64(28.0)], 'n_estimators': [np.float64(1550.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(30.0)], 'max_features': [np.float64(0.47972163664262835)], 'max_leaf_nodes': [np.float64(50.0)], 'min_impurity_decrease': [np.float64(0.12643610135564015)], 'min_samples_leaf': [np.float64(5.0)], 'min_samples_split': [np.float64(44.0)], 'n_estimators': [np.float64(1900.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(0)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(0)], 'max_depth': [np.float64(26.0)], 'max_features': [np.float64(0.3974667253828378)], 'max_leaf_nodes': [np.float64(940.0)], 'min_impurity_decrease': [np.float64(0.4709443600999472)], 'min_samples_leaf': [np.float64(3.0)], 'min_samples_split': [np.float64(22.0)], 'n_estimators': [np.float64(1750.0)]}
# 0.5088391403572676 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(25.0)], 'max_features': [np.float64(0.36508439502455886)], 'max_leaf_nodes': [np.float64(340.0)], 'min_impurity_decrease': [np.float64(0.00037649962260417473)], 'min_samples_leaf': [np.float64(6.0)], 'min_samples_split': [np.float64(18.0)], 'n_estimators': [np.float64(1000.0)]}
# 0.5137166316039876 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(29.0)], 'max_features': [np.float64(0.4098795571916636)], 'max_leaf_nodes': [np.float64(300.0)], 'min_impurity_decrease': [np.float64(0.009802798309078488)], 'min_samples_leaf': [np.float64(4.0)], 'min_samples_split': [np.float64(20.0)], 'n_estimators': [np.float64(900.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(29.0)], 'max_features': [np.float64(0.34498399466915697)], 'max_leaf_nodes': [np.float64(370.0)], 'min_impurity_decrease': [np.float64(0.048442721780031034)], 'min_samples_leaf': [np.float64(3.0)], 'min_samples_split': [np.float64(26.0)], 'n_estimators': [np.float64(750.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(23.0)], 'max_features': [np.float64(0.31932801827826574)], 'max_leaf_nodes': [np.float64(240.0)], 'min_impurity_decrease': [np.float64(0.03833802967351318)], 'min_samples_leaf': [np.float64(2.0)], 'min_samples_split': [np.float64(22.0)], 'n_estimators': [np.float64(1050.0)]}
# 0.5658402777261542 {'bootstrap': [np.int64(1)], 'class_weight': [np.int64(0)], 'criterion': [np.int64(1)], 'max_depth': [np.float64(26.0)], 'max_features': [np.float64(0.249638732498705)], 'max_leaf_nodes': [np.float64(430.0)], 'min_impurity_decrease': [np.float64(0.05885656068918602)], 'min_samples_leaf': [np.float64(1.0)], 'min_samples_split': [np.float64(24.0)], 'n_estimators': [np.float64(1850.0)]}

# %%
# Convert NumPy types to native Python types for JSON serialization
def convert_numpy(obj):
    if isinstance(obj, np.integer):
        return int(obj)  
    elif isinstance(obj, np.floating):
        return float(obj)  
    elif isinstance(obj, list):  
        return [convert_numpy(i) for i in obj]  
    elif isinstance(obj, dict):  
        return {key: convert_numpy(value) for key, value in obj.items()}  
    else:
        return obj

results_with_params = [
    {
        **convert_numpy(trial['result']),
        'params': {key: convert_numpy(value[0]) if value else None for key, value in trial['misc']['vals'].items()}  # Convert hyperparameters
    }
    for trial in trials.trials
]

with open('rf_model.json', 'w') as f:
    json.dump(results_with_params, f, indent=4)

print("Optimization results saved to 'rf_model.json'")
# Out:
# Optimization results saved to 'rf_model.json'

# %%
with open("rf_model.json", "r") as f:
    results_with_params = json.load(f)

# %%
print("\nBest trial")
best_trial = min(results_with_params, key=lambda x: x["loss"])
print("Best hyperparameters:", best_trial["params"])
print("Best loss:", best_trial["loss"])
# Out:
# Best trial
# Best hyperparameters: {'bootstrap': 0, 'class_weight': 0, 'criterion': 1, 'max_depth': 28.0, 'max_features': 0.2680750004428999, 'max_leaf_nodes': 750.0, 'min_impurity_decrease': 0.0001767471340795863, 'min_samples_leaf': 3.0, 'min_samples_split': 14.0, 'n_estimators': 800.0}
# Best loss: 0.50619779315745

# %%
# Convert hyperparameters to correct types
best_trial['params']['n_estimators'] = int(best_trial['params']['n_estimators'])
best_trial['params']['max_depth'] = int(best_trial['params']['max_depth'])
best_trial['params']['min_samples_split'] = int(best_trial['params']['min_samples_split'])
best_trial['params']['min_samples_leaf'] = int(best_trial['params']['min_samples_leaf'])
best_trial['params']['max_leaf_nodes'] = int(best_trial['params']['max_leaf_nodes']) if best_trial['params']['max_leaf_nodes'] is not None else None
best_trial['params']['bootstrap'] = bool(best_trial['params']['bootstrap'])

class_weight_options = [None, 'balanced', 'balanced_subsample']
if isinstance(best_trial['params']['class_weight'], (int, np.integer)):  # Ensure it's an index
    best_trial['params']['class_weight'] = class_weight_options[int(best_trial['params']['class_weight'])]

criterion_options = ['gini', 'entropy']
if isinstance(best_trial['params']['criterion'], (int, np.integer)):
    best_trial['params']['criterion'] = criterion_options[int(best_trial['params']['criterion'])]

# %%
final_model = RandomForestClassifier(
    **best_trial['params'],
    n_jobs=-1,
    random_state=42
)

final_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=False, criterion='entropy', max_depth=28,
#                        max_features=0.2680750004428999, max_leaf_nodes=750,
#                        min_impurity_decrease=0.0001767471340795863,
#                        min_samples_leaf=3, min_samples_split=14,
#                        n_estimators=800, n_jobs=-1, random_state=42)

# %%
y_pred_final = final_model.predict(X_test)

final_accuracy = accuracy_score(y_test, y_pred_final)
print(f"Accuracy (test) : {final_accuracy * 100:.2f}%")
# Out:
# Accuracy (test) : 49.13%

# %%
importance_dict = dict(zip(
    X_train.columns,
    final_model.feature_importances_
))

sorted_features = sorted(
    importance_dict.items(),
    key=lambda x: x[1],
    reverse=True
)
top_features = [feature for feature, score in sorted_features[:10]]

X_reduced = train_data[top_features]

# %%
plot_correlation_matrix(X_reduced, title="Correlation Matrix (X_reduced)")

# %%
num_cols = X_reduced.select_dtypes(include=[np.number]).columns
cat_cols = X_reduced.select_dtypes(include=["object", "category"]).columns
plot_univariate_analysis(X_reduced, numeric_cols=num_cols, categorical_cols=cat_cols)
