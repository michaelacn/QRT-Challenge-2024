# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
elif PROJECT_ROOT.name.startswith("0"):
    PROJECT_ROOT = PROJECT_ROOT.parent.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %load_ext autoreload
# %autoreload 2

# %%
# !pip install shap
# !pip install hyperopt
# !pip install loguru
# !pip install lightgbm
# !pip install pytorch-tabnet

# %%
import warnings
warnings.filterwarnings("ignore")

# Data Management
import json
import numpy as np
import pandas as pd

# Modelling
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import StratifiedKFold
from pytorch_tabnet.tab_model import TabNetClassifier
import torch
import gc

# Opti
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from match_forecast.utils import *

# %%
PROJ_ROOT = Path("QRT-Challenge-2024").resolve().parents[1]
DATA_DIR = PROJ_ROOT / "data"
RAW_DATA_DIR = DATA_DIR / "raw"
PROCESSED_DATA_DIR = DATA_DIR / "processed"

# %%
try:
    train_data = pd.read_csv(PROCESSED_DATA_DIR / "train_data.csv", index_col=0)
    train_scores = pd.read_csv(RAW_DATA_DIR / "Y_train.csv", index_col=0)
    print("Files loaded")
    
except FileNotFoundError as e:
    print(e)
# Out:
# Files loaded

# %%
train_data.shape
# Out:
# (12303, 275)

# %%
train_scores = train_scores.loc[train_data.index]
train_scores_1c = train_scores[['HOME_WINS', 'DRAW', 'AWAY_WINS']].idxmax(axis=1)
label_mapping = {'HOME_WINS': 0, 'DRAW': 1, 'AWAY_WINS': 2}
train_scores_1c = train_scores_1c.replace(label_mapping)

train_scores_1c.head(5)
# Out:
# ID
# 0    2
# 1    1
# 2    2
# 3    0
# 4    1
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(train_data, train_scores_1c, train_size=0.8, random_state=42)

# %%
space = {
    'n_d': hp.quniform('n_d', 8, 64, 4),  # Number of decision steps (8-64)
    'n_a': hp.quniform('n_a', 8, 64, 4),  # Number of attention steps (same as n_d)
    'n_steps': hp.quniform('n_steps', 3, 10, 1),  # Number of sequential decision steps
    'gamma': hp.uniform('gamma', 1.0, 2.0),  # Scaling factor for importance weights
    'lambda_sparse': hp.loguniform('lambda_sparse', -8, -2),  # L1 regularization
    'clip_value': hp.uniform('clip_value', 1.0, 5.0),  # Gradient clipping value
    'learning_rate': hp.loguniform('learning_rate', -5, -1),  # Learning rate (1e-5 to 1e-1)
    'n_shared': hp.quniform('n_shared', 1, 5, 1),  # Shared layers in feature transformer
    'n_independent': hp.quniform('n_independent', 1, 5, 1),  # Independent layers in feature transformer
}

# %%
n_splits = 3

def objective(params):
    """
    Hyperopt objective for TabNet with:
      - Single StandardScaler applied once
      - CUDA device
      - Verbose disabled
    """
    for key in ['n_d', 'n_a', 'n_steps', 'n_independent', 'n_shared']:
        params[key] = int(params[key])

    scaler = StandardScaler().fit(X_train.values)
    X_train_scaled = scaler.transform(X_train.values)

    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
    accuracies = []

    for train_idx, valid_idx in skf.split(X_train_scaled, y_train):
        X_tr = X_train_scaled[train_idx]
        y_tr = y_train.values[train_idx]
        X_val = X_train_scaled[valid_idx]
        y_val = y_train.values[valid_idx]

        model = TabNetClassifier(
            n_d=params['n_d'],
            n_a=params['n_a'],
            n_steps=params['n_steps'],
            gamma=params['gamma'],
            lambda_sparse=params['lambda_sparse'],
            optimizer_fn=torch.optim.Adam,
            optimizer_params={'lr': params['learning_rate']},
            n_independent=params['n_independent'],
            n_shared=params['n_shared'],
            clip_value=params['clip_value'],
            verbose=0,
            device_name='cuda' if torch.cuda.is_available() else 'cpu'
        )

        model.fit(
            X_tr, y_tr,
            eval_set=[(X_val, y_val)],
            max_epochs=150,
            patience=30,
            batch_size=128,
            virtual_batch_size=32,
            num_workers=2,
            drop_last=False,
        )

        preds = model.predict(X_val)
        accuracies.append(accuracy_score(y_val, preds))

        # Cleanup
        del model
        torch.cuda.empty_cache()
        gc.collect()

    mean_acc = np.mean(accuracies)
    return {'loss': 1 - mean_acc, 'status': STATUS_OK}

# %%
trials = Trials()
best_params = fmin(
    fn=objective,
    space=space,
    algo=tpe.suggest,
    max_evals=50,
    trials=trials
)

print("Best hyperparameters:", best_params)
# Out:
#   0%|          | 0/50 [00:00<?, ?trial/s, best loss=?]
#
# Early stopping occurred at epoch 53 with best_epoch = 23 and best_val_0_accuracy = 0.4904
#
# Early stopping occurred at epoch 57 with best_epoch = 27 and best_val_0_accuracy = 0.48034
#
# Early stopping occurred at epoch 65 with best_epoch = 35 and best_val_0_accuracy = 0.48933
#
# Early stopping occurred at epoch 83 with best_epoch = 53 and best_val_0_accuracy = 0.49649
#
# Early stopping occurred at epoch 45 with best_epoch = 15 and best_val_0_accuracy = 0.48827
#
# Early stopping occurred at epoch 138 with best_epoch = 108 and best_val_0_accuracy = 0.5
#
# Early stopping occurred at epoch 55 with best_epoch = 25 and best_val_0_accuracy = 0.45504
#
# Early stopping occurred at epoch 58 with best_epoch = 28 and best_val_0_accuracy = 0.43889
#
# Early stopping occurred at epoch 55 with best_epoch = 25 and best_val_0_accuracy = 0.44055
#
# Early stopping occurred at epoch 92 with best_epoch = 62 and best_val_0_accuracy = 0.49558
#
# Early stopping occurred at epoch 52 with best_epoch = 22 and best_val_0_accuracy = 0.48613
#
# Early stopping occurred at epoch 34 with best_epoch = 4 and best_val_0_accuracy = 0.45488
#
# Early stopping occurred at epoch 60 with best_epoch = 30 and best_val_0_accuracy = 0.48796
#
# Early stopping occurred at epoch 70 with best_epoch = 40 and best_val_0_accuracy = 0.49314
#
# Early stopping occurred at epoch 53 with best_epoch = 23 and best_val_0_accuracy = 0.49787
#
# Early stopping occurred at epoch 82 with best_epoch = 52 and best_val_0_accuracy = 0.48796
#
# Early stopping occurred at epoch 51 with best_epoch = 21 and best_val_0_accuracy = 0.484
#
# Early stopping occurred at epoch 46 with best_epoch = 16 and best_val_0_accuracy = 0.49451
#
# Early stopping occurred at epoch 55 with best_epoch = 25 and best_val_0_accuracy = 0.48491
#
# Early stopping occurred at epoch 72 with best_epoch = 42 and best_val_0_accuracy = 0.48308
#
# Early stopping occurred at epoch 92 with best_epoch = 62 and best_val_0_accuracy = 0.48659
#
# Early stopping occurred at epoch 57 with best_epoch = 27 and best_val_0_accuracy = 0.48034
#
# Early stopping occurred at epoch 70 with best_epoch = 40 and best_val_0_accuracy = 0.48613
#
# Early stopping occurred at epoch 38 with best_epoch = 8 and best_val_0_accuracy = 0.47683
#
# Early stopping occurred at epoch 36 with best_epoch = 6 and best_val_0_accuracy = 0.4843
#
# Early stopping occurred at epoch 34 with best_epoch = 4 and best_val_0_accuracy = 0.44133
#
# Early stopping occurred at epoch 47 with best_epoch = 17 and best_val_0_accuracy = 0.475
#
# Early stopping occurred at epoch 62 with best_epoch = 32 and best_val_0_accuracy = 0.49223
#
# Early stopping occurred at epoch 65 with best_epoch = 35 and best_val_0_accuracy = 0.48217
#
# Early stopping occurred at epoch 75 with best_epoch = 45 and best_val_0_accuracy = 0.4936
#
# Early stopping occurred at epoch 71 with best_epoch = 41 and best_val_0_accuracy = 0.49832
#
# Early stopping occurred at epoch 47 with best_epoch = 17 and best_val_0_accuracy = 0.48247
#
# Early stopping occurred at epoch 126 with best_epoch = 96 and best_val_0_accuracy = 0.4997
#
# Early stopping occurred at epoch 90 with best_epoch = 60 and best_val_0_accuracy = 0.48796
#
# Early stopping occurred at epoch 53 with best_epoch = 23 and best_val_0_accuracy = 0.4779
#
# Early stopping occurred at epoch 76 with best_epoch = 46 and best_val_0_accuracy = 0.4936
#
# Early stopping occurred at epoch 33 with best_epoch = 3 and best_val_0_accuracy = 0.46693
#
# Early stopping occurred at epoch 37 with best_epoch = 7 and best_val_0_accuracy = 0.46358
#
# Early stopping occurred at epoch 32 with best_epoch = 2 and best_val_0_accuracy = 0.48049
#
# Early stopping occurred at epoch 48 with best_epoch = 18 and best_val_0_accuracy = 0.47851
#
# Early stopping occurred at epoch 76 with best_epoch = 46 and best_val_0_accuracy = 0.49101
#
# Early stopping occurred at epoch 72 with best_epoch = 42 and best_val_0_accuracy = 0.50366
#
# Early stopping occurred at epoch 62 with best_epoch = 32 and best_val_0_accuracy = 0.49009
#
# Early stopping occurred at epoch 96 with best_epoch = 66 and best_val_0_accuracy = 0.4843
#
# Early stopping occurred at epoch 107 with best_epoch = 77 and best_val_0_accuracy = 0.5003
#
# Early stopping occurred at epoch 128 with best_epoch = 98 and best_val_0_accuracy = 0.49771
#
# Early stopping occurred at epoch 92 with best_epoch = 62 and best_val_0_accuracy = 0.49284
#
# Early stopping occurred at epoch 106 with best_epoch = 76 and best_val_0_accuracy = 0.49024
#
# Early stopping occurred at epoch 94 with best_epoch = 64 and best_val_0_accuracy = 0.49162
#
# Early stopping occurred at epoch 71 with best_epoch = 41 and best_val_0_accuracy = 0.49528
#
# Early stopping occurred at epoch 66 with best_epoch = 36 and best_val_0_accuracy = 0.48872
#
# Early stopping occurred at epoch 53 with best_epoch = 23 and best_val_0_accuracy = 0.43859
#
# Early stopping occurred at epoch 38 with best_epoch = 8 and best_val_0_accuracy = 0.4715
#
# Early stopping occurred at epoch 48 with best_epoch = 18 and best_val_0_accuracy = 0.49909
#
# Early stopping occurred at epoch 47 with best_epoch = 17 and best_val_0_accuracy = 0.47546
#
# Early stopping occurred at epoch 61 with best_epoch = 31 and best_val_0_accuracy = 0.48156
#
# Early stopping occurred at epoch 63 with best_epoch = 33 and best_val_0_accuracy = 0.49024
#
# Early stopping occurred at epoch 36 with best_epoch = 6 and best_val_0_accuracy = 0.47851
#
# Early stopping occurred at epoch 82 with best_epoch = 52 and best_val_0_accuracy = 0.48613
#
# Early stopping occurred at epoch 113 with best_epoch = 83 and best_val_0_accuracy = 0.48476
#
# Early stopping occurred at epoch 46 with best_epoch = 16 and best_val_0_accuracy = 0.48979
#
# Early stopping occurred at epoch 93 with best_epoch = 63 and best_val_0_accuracy = 0.49406
#
# Early stopping occurred at epoch 82 with best_epoch = 52 and best_val_0_accuracy = 0.49451
#
# Early stopping occurred at epoch 93 with best_epoch = 63 and best_val_0_accuracy = 0.49009
#
# Early stopping occurred at epoch 115 with best_epoch = 85 and best_val_0_accuracy = 0.48522
#
# Early stopping occurred at epoch 64 with best_epoch = 34 and best_val_0_accuracy = 0.48994
#
# Early stopping occurred at epoch 79 with best_epoch = 49 and best_val_0_accuracy = 0.4968
#
# Early stopping occurred at epoch 44 with best_epoch = 14 and best_val_0_accuracy = 0.48369
#
# Early stopping occurred at epoch 88 with best_epoch = 58 and best_val_0_accuracy = 0.49787
#
# Early stopping occurred at epoch 76 with best_epoch = 46 and best_val_0_accuracy = 0.4971
#
# Early stopping occurred at epoch 50 with best_epoch = 20 and best_val_0_accuracy = 0.48095
#
# Early stopping occurred at epoch 51 with best_epoch = 21 and best_val_0_accuracy = 0.48445
#
# Early stopping occurred at epoch 97 with best_epoch = 67 and best_val_0_accuracy = 0.48766
#
# Early stopping occurred at epoch 95 with best_epoch = 65 and best_val_0_accuracy = 0.48369
#
# Early stopping occurred at epoch 80 with best_epoch = 50 and best_val_0_accuracy = 0.48933
#
# Early stopping occurred at epoch 69 with best_epoch = 39 and best_val_0_accuracy = 0.49589
#
# Early stopping occurred at epoch 81 with best_epoch = 51 and best_val_0_accuracy = 0.48674
#
# Early stopping occurred at epoch 58 with best_epoch = 28 and best_val_0_accuracy = 0.4936
#
# Early stopping occurred at epoch 94 with best_epoch = 64 and best_val_0_accuracy = 0.4843
#
# Early stopping occurred at epoch 41 with best_epoch = 11 and best_val_0_accuracy = 0.47577
#
# Early stopping occurred at epoch 60 with best_epoch = 30 and best_val_0_accuracy = 0.49451
#
# Early stopping occurred at epoch 48 with best_epoch = 18 and best_val_0_accuracy = 0.48644
#
# Early stopping occurred at epoch 57 with best_epoch = 27 and best_val_0_accuracy = 0.4843
#
# Early stopping occurred at epoch 72 with best_epoch = 42 and best_val_0_accuracy = 0.4936
#
# Early stopping occurred at epoch 111 with best_epoch = 81 and best_val_0_accuracy = 0.50076
#
# Early stopping occurred at epoch 50 with best_epoch = 20 and best_val_0_accuracy = 0.48339
#
# Early stopping occurred at epoch 102 with best_epoch = 72 and best_val_0_accuracy = 0.5003
#
# Early stopping occurred at epoch 77 with best_epoch = 47 and best_val_0_accuracy = 0.49528
#
# Early stopping occurred at epoch 49 with best_epoch = 19 and best_val_0_accuracy = 0.48247
#
# Early stopping occurred at epoch 108 with best_epoch = 78 and best_val_0_accuracy = 0.49878
#
# Early stopping occurred at epoch 86 with best_epoch = 56 and best_val_0_accuracy = 0.48857
#
# Early stopping occurred at epoch 78 with best_epoch = 48 and best_val_0_accuracy = 0.49131
#
# Early stopping occurred at epoch 62 with best_epoch = 32 and best_val_0_accuracy = 0.48659
#
# Early stopping occurred at epoch 106 with best_epoch = 76 and best_val_0_accuracy = 0.49284
#
# Early stopping occurred at epoch 47 with best_epoch = 17 and best_val_0_accuracy = 0.48247
#
# Early stopping occurred at epoch 100 with best_epoch = 70 and best_val_0_accuracy = 0.49451
#
# Early stopping occurred at epoch 61 with best_epoch = 31 and best_val_0_accuracy = 0.49985
#
# Early stopping occurred at epoch 37 with best_epoch = 7 and best_val_0_accuracy = 0.48613
#
# Early stopping occurred at epoch 54 with best_epoch = 24 and best_val_0_accuracy = 0.4939
#
# Early stopping occurred at epoch 124 with best_epoch = 94 and best_val_0_accuracy = 0.49863
#
# Early stopping occurred at epoch 79 with best_epoch = 49 and best_val_0_accuracy = 0.49009
#
# Early stopping occurred at epoch 58 with best_epoch = 28 and best_val_0_accuracy = 0.49482
#
# Early stopping occurred at epoch 58 with best_epoch = 28 and best_val_0_accuracy = 0.48674
#
# Early stopping occurred at epoch 59 with best_epoch = 29 and best_val_0_accuracy = 0.48827
#
# Early stopping occurred at epoch 49 with best_epoch = 19 and best_val_0_accuracy = 0.48841
#
# Early stopping occurred at epoch 48 with best_epoch = 18 and best_val_0_accuracy = 0.4968
#
# Early stopping occurred at epoch 54 with best_epoch = 24 and best_val_0_accuracy = 0.48583
#
# Early stopping occurred at epoch 87 with best_epoch = 57 and best_val_0_accuracy = 0.4997
#
# Early stopping occurred at epoch 101 with best_epoch = 71 and best_val_0_accuracy = 0.49253
#
# Early stopping occurred at epoch 93 with best_epoch = 63 and best_val_0_accuracy = 0.48247
#
# Early stopping occurred at epoch 126 with best_epoch = 96 and best_val_0_accuracy = 0.49878
#
# Early stopping occurred at epoch 57 with best_epoch = 27 and best_val_0_accuracy = 0.48796
#
# Early stopping occurred at epoch 76 with best_epoch = 46 and best_val_0_accuracy = 0.48491
#
# Early stopping occurred at epoch 102 with best_epoch = 72 and best_val_0_accuracy = 0.48872
#
# Early stopping occurred at epoch 32 with best_epoch = 2 and best_val_0_accuracy = 0.44316
#
# Early stopping occurred at epoch 38 with best_epoch = 8 and best_val_0_accuracy = 0.43798
#
# Early stopping occurred at epoch 40 with best_epoch = 10 and best_val_0_accuracy = 0.45244
#
# Early stopping occurred at epoch 62 with best_epoch = 32 and best_val_0_accuracy = 0.49436
#
# Early stopping occurred at epoch 88 with best_epoch = 58 and best_val_0_accuracy = 0.48156
#
# Early stopping occurred at epoch 47 with best_epoch = 17 and best_val_0_accuracy = 0.48689
#
# Early stopping occurred at epoch 59 with best_epoch = 29 and best_val_0_accuracy = 0.48979
#
# Early stopping occurred at epoch 83 with best_epoch = 53 and best_val_0_accuracy = 0.48705
#
# Early stopping occurred at epoch 56 with best_epoch = 26 and best_val_0_accuracy = 0.49604
#
# Early stopping occurred at epoch 55 with best_epoch = 25 and best_val_0_accuracy = 0.48613
#
# Early stopping occurred at epoch 108 with best_epoch = 78 and best_val_0_accuracy = 0.48522
#
# Early stopping occurred at epoch 78 with best_epoch = 48 and best_val_0_accuracy = 0.48537
#
# Early stopping occurred at epoch 68 with best_epoch = 38 and best_val_0_accuracy = 0.48522
#
# Early stopping occurred at epoch 54 with best_epoch = 24 and best_val_0_accuracy = 0.48735
#
# Early stopping occurred at epoch 119 with best_epoch = 89 and best_val_0_accuracy = 0.49878
#
# Early stopping occurred at epoch 51 with best_epoch = 21 and best_val_0_accuracy = 0.48217
#
# Early stopping occurred at epoch 40 with best_epoch = 10 and best_val_0_accuracy = 0.48156
#
# Early stopping occurred at epoch 66 with best_epoch = 36 and best_val_0_accuracy = 0.48628
#
# Early stopping occurred at epoch 57 with best_epoch = 27 and best_val_0_accuracy = 0.49345
#
# Early stopping occurred at epoch 71 with best_epoch = 41 and best_val_0_accuracy = 0.4843
#
# Early stopping occurred at epoch 102 with best_epoch = 72 and best_val_0_accuracy = 0.49756
#
# Early stopping occurred at epoch 48 with best_epoch = 18 and best_val_0_accuracy = 0.49893
#
# Early stopping occurred at epoch 56 with best_epoch = 26 and best_val_0_accuracy = 0.484
#
# Early stopping occurred at epoch 51 with best_epoch = 21 and best_val_0_accuracy = 0.49207
#
# Early stopping occurred at epoch 114 with best_epoch = 84 and best_val_0_accuracy = 0.49467
#
# Early stopping occurred at epoch 105 with best_epoch = 75 and best_val_0_accuracy = 0.48766
#
# Early stopping occurred at epoch 45 with best_epoch = 15 and best_val_0_accuracy = 0.48445
#
# Early stopping occurred at epoch 88 with best_epoch = 58 and best_val_0_accuracy = 0.50107
#
# Early stopping occurred at epoch 83 with best_epoch = 53 and best_val_0_accuracy = 0.484
#
# Early stopping occurred at epoch 87 with best_epoch = 57 and best_val_0_accuracy = 0.4939
#
# Early stopping occurred at epoch 74 with best_epoch = 44 and best_val_0_accuracy = 0.48491
#
# Early stopping occurred at epoch 68 with best_epoch = 38 and best_val_0_accuracy = 0.484
#
# Early stopping occurred at epoch 81 with best_epoch = 51 and best_val_0_accuracy = 0.49756
#
# Early stopping occurred at epoch 107 with best_epoch = 77 and best_val_0_accuracy = 0.49649
#
# Early stopping occurred at epoch 51 with best_epoch = 21 and best_val_0_accuracy = 0.48705
#
# Early stopping occurred at epoch 96 with best_epoch = 66 and best_val_0_accuracy = 0.49116
# 100%|██████████| 50/50 [21:03:43<00:00, 1516.46s/trial, best loss: 0.5050797521080972]
# Best hyperparameters: {'clip_value': np.float64(2.039306564397546), 'gamma': np.float64(1.0373107804827173), 'lambda_sparse': np.float64(0.0007629251680237833), 'learning_rate': np.float64(0.020892188021323258), 'n_a': np.float64(16.0), 'n_d': np.float64(40.0), 'n_independent': np.float64(5.0), 'n_shared': np.float64(2.0), 'n_steps': np.float64(5.0)}

# %%
# Convert NumPy types to native Python types for JSON serialization
def convert_numpy(obj):
    if isinstance(obj, np.integer):
        return int(obj)  
    elif isinstance(obj, np.floating):
        return float(obj)  
    elif isinstance(obj, list):  
        return [convert_numpy(i) for i in obj]  
    elif isinstance(obj, dict):  
        return {key: convert_numpy(value) for key, value in obj.items()}  
    else:
        return obj

results_with_params = [
    {
        **convert_numpy(trial['result']),
        'params': {key: convert_numpy(value[0]) if value else None for key, value in trial['misc']['vals'].items()}  # Convert hyperparameters
    }
    for trial in trials.trials
]

with open('tabnet_model.json', 'w') as f:
    json.dump(results_with_params, f, indent=4)

print("Optimization results saved to 'tabnet_model.json'")
# Out:
# Optimization results saved to 'tabnet_model.json'

# %%
with open("tabnet_model.json", "r") as f:
    results_with_params = json.load(f)

print("\nBest trial")
best_trial = min(results_with_params, key=lambda x: x["loss"])
print("Best hyperparameters:", best_trial["params"])
print("Best loss:", best_trial["loss"])

best_params = best_trial['params']
best_params['n_d'] = int(best_params['n_d'])
best_params['n_a'] = int(best_params['n_a'])
best_params['n_steps'] = int(best_params['n_steps'])
best_params['n_shared'] = int(best_params['n_shared'])
best_params['n_independent'] = int(best_params['n_independent'])

final_model = TabNetClassifier(
    n_d=best_params['n_d'],
    n_a=best_params['n_a'],
    n_steps=best_params['n_steps'],
    gamma=best_params['gamma'],
    lambda_sparse=best_params['lambda_sparse'],
    optimizer_fn=torch.optim.Adam,
    optimizer_params=dict(lr=best_params['learning_rate']),
    n_independent=best_params['n_independent'],
    n_shared=best_params['n_shared'],
    clip_value=best_params['clip_value'],
    verbose=0,
    device_name='cuda' if torch.cuda.is_available() else 'cpu'
)
# Out:
# Best trial
# Best hyperparameters: {'clip_value': 2.039306564397546, 'gamma': 1.0373107804827173, 'lambda_sparse': 0.0007629251680237833, 'learning_rate': 0.020892188021323258, 'n_a': 16.0, 'n_d': 40.0, 'n_independent': 5.0, 'n_shared': 2.0, 'n_steps': 5.0}
# Best loss: 0.5050797521080972

# %%
scaler = StandardScaler().fit(X_train.values)
X_train_scaled = scaler.transform(X_train.values)

X_tr, X_val, y_tr, y_val = train_test_split(
    X_train_scaled, 
    y_train.values, 
    test_size=0.20, 
    stratify=y_train, 
    random_state=42
)

final_model.fit(
    X_tr, y_tr,
    eval_set=[(X_val, y_val)],
    max_epochs=150,
    patience=30,
    batch_size=128,
    virtual_batch_size=32,
    num_workers=2,
    drop_last=False,
)
# Out:
# Early stopping occurred at epoch 83 with best_epoch = 53 and best_val_0_accuracy = 0.50025

# %%
y_pred_final = final_model.predict(X_test.values)

final_accuracy = accuracy_score(y_test, y_pred_final)
print(f"Accuracy (test) : {final_accuracy * 100:.2f}%")
# Out:
# Accuracy (test) : 47.09%
