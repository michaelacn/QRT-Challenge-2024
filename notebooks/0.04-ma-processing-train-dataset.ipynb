# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
elif PROJECT_ROOT.name.startswith("0"):
    PROJECT_ROOT = PROJECT_ROOT.parent.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
from pathlib import Path
from sklearn import model_selection
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from match_forecast.utils import *

# %%
PROJ_ROOT = Path("QRT-Challenge-2024").resolve().parents[1]
DATA_DIR = PROJ_ROOT / "data"
RAW_DATA_DIR = DATA_DIR / "raw"
PROCESSED_DATA_DIR = DATA_DIR / "processed"
INTERIM_DATA_DIR = DATA_DIR / "interim"

# %%
try:
    train_data_teams = pd.read_csv(INTERIM_DATA_DIR / "train_data_teams.csv", index_col=0)
    train_data_players = pd.read_csv(INTERIM_DATA_DIR / "train_data_players.csv", index_col=0)
    train_scores = pd.read_csv(RAW_DATA_DIR / "Y_train.csv", index_col=0)
    print("Files loaded")
    
except FileNotFoundError as e:
    print(e)
# Out:
# Files loaded

# %%
train_data_interim = train_data_teams.merge(train_data_players, left_index=True, right_index=True, how='inner')

# %%
train_data_interim.shape
# Out:
# (12303, 326)

# %%
train_scores = train_scores.loc[train_data_interim.index]
train_new_y = train_scores['AWAY_WINS']

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(train_data_interim, train_new_y, train_size=0.8, random_state=42)
X_train, X_valid, y_train, y_valid = model_selection.train_test_split(X_train, y_train, train_size=0.8, random_state=42)

# %%
model = RandomForestClassifier(
    n_jobs=-1,
    random_state=42
)

# %%
retained_features, dropped_features = keep_top_shap_features(X_train, y_train, model, n_keep=275)

# %%
train_data = train_data_interim[retained_features]
train_data.shape
# Out:
# (12303, 275)

# %%
dropped_features
# Out:
# {'DIFF_PLAYER_ACCURATE_CROSSES_5_last_match_average_mean_goalkeeper',
#  'DIFF_PLAYER_ACCURATE_CROSSES_season_average_mean_goalkeeper',
#  'DIFF_PLAYER_ASSISTS_5_last_match_average_mean_goalkeeper',
#  'DIFF_PLAYER_BIG_CHANCES_CREATED_5_last_match_average_mean_goalkeeper',
#  'DIFF_PLAYER_BIG_CHANCES_CREATED_season_average_mean_goalkeeper',
#  'DIFF_PLAYER_BIG_CHANCES_MISSED_5_last_match_average_mean_goalkeeper',
#  'DIFF_PLAYER_BIG_CHANCES_MISSED_season_average_mean_goalkeeper',
#  'DIFF_PLAYER_BLOCKED_SHOTS_5_last_match_average_mean_goalkeeper',
#  'DIFF_PLAYER_BLOCKED_SHOTS_season_average_mean_goalkeeper',
#  'DIFF_PLAYER_CLEARANCE_OFFLINE_5_last_match_average_mean_goalkeeper',
#  'DIFF_PLAYER_CLEARANCE_OFFLINE_season_average_mean_goalkeeper',
#  'DIFF_PLAYER_DISPOSSESSED_5_last_match_average_mean_goalkeeper',
#  'DIFF_PLAYER_DISPOSSESSED_season_average_mean_goalkeeper',
#  'DIFF_PLAYER_DRIBBLED_ATTEMPTS_5_last_match_average_mean_goalkeeper',
#  'DIFF_PLAYER_DRIBBLED_ATTEMPTS_season_average_mean_goalkeeper',
#  'DIFF_PLAYER_GOALKEEPER_GOALS_CONCEDED_5_last_match_average_mean_defender',
#  'DIFF_PLAYER_GOALKEEPER_GOALS_CONCEDED_5_last_match_average_mean_offensive',
#  'DIFF_PLAYER_GOALKEEPER_GOALS_CONCEDED_season_average_mean_defender',
#  'DIFF_PLAYER_GOALKEEPER_GOALS_CONCEDED_season_average_mean_offensive',
#  'DIFF_PLAYER_GOALS_5_last_match_average_mean_goalkeeper',
#  'DIFF_PLAYER_GOALS_season_average_mean_goalkeeper',
#  'DIFF_PLAYER_HIT_WOODWORK_5_last_match_average_mean_goalkeeper',
#  'DIFF_PLAYER_HIT_WOODWORK_season_average_mean_goalkeeper',
#  'DIFF_PLAYER_OFFSIDES_5_last_match_average_mean_goalkeeper',
#  'DIFF_PLAYER_OFFSIDES_season_average_mean_goalkeeper',
#  'DIFF_PLAYER_OWN_GOALS_5_last_match_average_mean_goalkeeper',
#  'DIFF_PLAYER_PENALTIES_MISSES_5_last_match_average_mean_defender',
#  'DIFF_PLAYER_PENALTIES_MISSES_5_last_match_average_mean_goalkeeper',
#  'DIFF_PLAYER_PENALTIES_MISSES_season_average_mean_goalkeeper',
#  'DIFF_PLAYER_PENALTIES_SAVED_5_last_match_average_mean_defender',
#  'DIFF_PLAYER_PENALTIES_SAVED_5_last_match_average_mean_offensive',
#  'DIFF_PLAYER_PENALTIES_SAVED_season_average_mean_defender',
#  'DIFF_PLAYER_PENALTIES_SAVED_season_average_mean_offensive',
#  'DIFF_PLAYER_PENALTIES_SCORED_5_last_match_average_mean_goalkeeper',
#  'DIFF_PLAYER_PENALTIES_SCORED_season_average_mean_goalkeeper',
#  'DIFF_PLAYER_PENALTIES_WON_5_last_match_average_mean_defender',
#  'DIFF_PLAYER_PENALTIES_WON_5_last_match_average_mean_goalkeeper',
#  'DIFF_PLAYER_PENALTIES_WON_season_average_mean_goalkeeper',
#  'DIFF_PLAYER_REDCARDS_5_last_match_average_mean_goalkeeper',
#  'DIFF_PLAYER_SAVES_5_last_match_average_mean_defender',
#  'DIFF_PLAYER_SAVES_INSIDE_BOX_5_last_match_average_mean_defender',
#  'DIFF_PLAYER_SAVES_INSIDE_BOX_season_average_mean_defender',
#  'DIFF_PLAYER_SAVES_season_average_mean_defender',
#  'DIFF_PLAYER_SHOTS_BLOCKED_5_last_match_average_mean_goalkeeper',
#  'DIFF_PLAYER_SHOTS_BLOCKED_season_average_mean_goalkeeper',
#  'DIFF_PLAYER_SHOTS_ON_TARGET_5_last_match_average_mean_goalkeeper',
#  'DIFF_PLAYER_SHOTS_ON_TARGET_season_average_mean_goalkeeper',
#  'DIFF_PLAYER_SHOTS_TOTAL_5_last_match_average_mean_goalkeeper',
#  'DIFF_PLAYER_SHOTS_TOTAL_season_average_mean_goalkeeper',
#  'DIFF_PLAYER_TOTAL_CROSSES_5_last_match_average_mean_goalkeeper',
#  'DIFF_PLAYER_TOTAL_CROSSES_season_average_mean_goalkeeper'}

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(train_data, train_new_y, train_size=0.8, random_state=42)
X_train, X_valid, y_train, y_valid = model_selection.train_test_split(X_train, y_train, train_size=0.8, random_state=42)

# %%
params_1 = {
    'booster': 'gbtree',
    'tree_method':'hist',
    'max_depth': 8, 
    'learning_rate': 0.025,
    'objective': 'multi:softprob',
    'num_class': 2,
    'eval_metric':'mlogloss'
    }


d_train = xgb.DMatrix(X_train.replace({0:np.nan}), y_train)
d_valid = xgb.DMatrix(X_valid.replace({0:np.nan}), y_valid)

num_round = 10000
evallist = [(d_train, 'train'), (d_valid, 'eval')]

bst = xgb.train(params_1, d_train, num_round, evallist, early_stopping_rounds=100)
# Out:
# [0]	train-mlogloss:0.68313	eval-mlogloss:0.68745
# [1]	train-mlogloss:0.67374	eval-mlogloss:0.68242
# [2]	train-mlogloss:0.66465	eval-mlogloss:0.67745
# [3]	train-mlogloss:0.65592	eval-mlogloss:0.67287
# [4]	train-mlogloss:0.64742	eval-mlogloss:0.66854
# [5]	train-mlogloss:0.63913	eval-mlogloss:0.66407
# [6]	train-mlogloss:0.63147	eval-mlogloss:0.65984
# [7]	train-mlogloss:0.62365	eval-mlogloss:0.65599
# [8]	train-mlogloss:0.61645	eval-mlogloss:0.65254
# [9]	train-mlogloss:0.60910	eval-mlogloss:0.64932
# [10]	train-mlogloss:0.60233	eval-mlogloss:0.64581
# [11]	train-mlogloss:0.59558	eval-mlogloss:0.64302
# [12]	train-mlogloss:0.58887	eval-mlogloss:0.64044
# [13]	train-mlogloss:0.58265	eval-mlogloss:0.63747
# [14]	train-mlogloss:0.57625	eval-mlogloss:0.63437
# [15]	train-mlogloss:0.57011	eval-mlogloss:0.63219
# [16]	train-mlogloss:0.56388	eval-mlogloss:0.62989
# [17]	train-mlogloss:0.55742	eval-mlogloss:0.62736
# [18]	train-mlogloss:0.55179	eval-mlogloss:0.62554
# [19]	train-mlogloss:0.54568	eval-mlogloss:0.62297
# [20]	train-mlogloss:0.54037	eval-mlogloss:0.62025
# [21]	train-mlogloss:0.53492	eval-mlogloss:0.61831
# [22]	train-mlogloss:0.52977	eval-mlogloss:0.61654
# [23]	train-mlogloss:0.52483	eval-mlogloss:0.61406
# [24]	train-mlogloss:0.51991	eval-mlogloss:0.61220
# [25]	train-mlogloss:0.51466	eval-mlogloss:0.61036
# [26]	train-mlogloss:0.51024	eval-mlogloss:0.60855
# [27]	train-mlogloss:0.50532	eval-mlogloss:0.60678
# [28]	train-mlogloss:0.50048	eval-mlogloss:0.60493
# [29]	train-mlogloss:0.49563	eval-mlogloss:0.60327
# [30]	train-mlogloss:0.49167	eval-mlogloss:0.60140
# [31]	train-mlogloss:0.48691	eval-mlogloss:0.59994
# [32]	train-mlogloss:0.48255	eval-mlogloss:0.59861
# [33]	train-mlogloss:0.47887	eval-mlogloss:0.59686
# [34]	train-mlogloss:0.47501	eval-mlogloss:0.59576
# [35]	train-mlogloss:0.47080	eval-mlogloss:0.59458
# [36]	train-mlogloss:0.46703	eval-mlogloss:0.59345
# [37]	train-mlogloss:0.46342	eval-mlogloss:0.59224
# [38]	train-mlogloss:0.45997	eval-mlogloss:0.59121
# [39]	train-mlogloss:0.45642	eval-mlogloss:0.59021
# [40]	train-mlogloss:0.45287	eval-mlogloss:0.58896
# [41]	train-mlogloss:0.44929	eval-mlogloss:0.58808
# [42]	train-mlogloss:0.44641	eval-mlogloss:0.58686
# [43]	train-mlogloss:0.44286	eval-mlogloss:0.58608
# [44]	train-mlogloss:0.43915	eval-mlogloss:0.58553
# [45]	train-mlogloss:0.43575	eval-mlogloss:0.58463
# [46]	train-mlogloss:0.43266	eval-mlogloss:0.58379
# [47]	train-mlogloss:0.42944	eval-mlogloss:0.58331
# [48]	train-mlogloss:0.42615	eval-mlogloss:0.58283
# [49]	train-mlogloss:0.42335	eval-mlogloss:0.58236
# [50]	train-mlogloss:0.42010	eval-mlogloss:0.58193
# [51]	train-mlogloss:0.41687	eval-mlogloss:0.58119
# [52]	train-mlogloss:0.41382	eval-mlogloss:0.58064
# [53]	train-mlogloss:0.41053	eval-mlogloss:0.58004
# [54]	train-mlogloss:0.40778	eval-mlogloss:0.57957
# [55]	train-mlogloss:0.40475	eval-mlogloss:0.57910
# [56]	train-mlogloss:0.40192	eval-mlogloss:0.57844
# [57]	train-mlogloss:0.39878	eval-mlogloss:0.57815
# [58]	train-mlogloss:0.39559	eval-mlogloss:0.57770
# [59]	train-mlogloss:0.39271	eval-mlogloss:0.57715
# [60]	train-mlogloss:0.38978	eval-mlogloss:0.57657
# [61]	train-mlogloss:0.38713	eval-mlogloss:0.57591
# [62]	train-mlogloss:0.38435	eval-mlogloss:0.57558
# [63]	train-mlogloss:0.38151	eval-mlogloss:0.57521
# [64]	train-mlogloss:0.37891	eval-mlogloss:0.57474
# [65]	train-mlogloss:0.37638	eval-mlogloss:0.57430
# [66]	train-mlogloss:0.37400	eval-mlogloss:0.57412
# [67]	train-mlogloss:0.37180	eval-mlogloss:0.57396
# [68]	train-mlogloss:0.36969	eval-mlogloss:0.57348
# [69]	train-mlogloss:0.36797	eval-mlogloss:0.57324
# [70]	train-mlogloss:0.36582	eval-mlogloss:0.57317
# [71]	train-mlogloss:0.36400	eval-mlogloss:0.57300
# [72]	train-mlogloss:0.36201	eval-mlogloss:0.57276
# [73]	train-mlogloss:0.36036	eval-mlogloss:0.57248
# [74]	train-mlogloss:0.35826	eval-mlogloss:0.57227
# [75]	train-mlogloss:0.35639	eval-mlogloss:0.57169
# [76]	train-mlogloss:0.35437	eval-mlogloss:0.57158
# [77]	train-mlogloss:0.35251	eval-mlogloss:0.57147
# [78]	train-mlogloss:0.35060	eval-mlogloss:0.57149
# [79]	train-mlogloss:0.34884	eval-mlogloss:0.57128
# [80]	train-mlogloss:0.34716	eval-mlogloss:0.57140
# [81]	train-mlogloss:0.34542	eval-mlogloss:0.57116
# [82]	train-mlogloss:0.34368	eval-mlogloss:0.57097
# [83]	train-mlogloss:0.34189	eval-mlogloss:0.57098
# [84]	train-mlogloss:0.34030	eval-mlogloss:0.57071
# [85]	train-mlogloss:0.33915	eval-mlogloss:0.57074
# [86]	train-mlogloss:0.33748	eval-mlogloss:0.57067
# [87]	train-mlogloss:0.33532	eval-mlogloss:0.57045
# [88]	train-mlogloss:0.33331	eval-mlogloss:0.57023
# [89]	train-mlogloss:0.33108	eval-mlogloss:0.56996
# [90]	train-mlogloss:0.32916	eval-mlogloss:0.56970
# [91]	train-mlogloss:0.32817	eval-mlogloss:0.56964
# [92]	train-mlogloss:0.32701	eval-mlogloss:0.56952
# [93]	train-mlogloss:0.32556	eval-mlogloss:0.56963
# [94]	train-mlogloss:0.32424	eval-mlogloss:0.56975
# [95]	train-mlogloss:0.32229	eval-mlogloss:0.56974
# [96]	train-mlogloss:0.32150	eval-mlogloss:0.56966
# [97]	train-mlogloss:0.31964	eval-mlogloss:0.56960
# [98]	train-mlogloss:0.31889	eval-mlogloss:0.56952
# [99]	train-mlogloss:0.31699	eval-mlogloss:0.56938
# [100]	train-mlogloss:0.31540	eval-mlogloss:0.56919
# [101]	train-mlogloss:0.31445	eval-mlogloss:0.56913
# [102]	train-mlogloss:0.31326	eval-mlogloss:0.56910
# [103]	train-mlogloss:0.31166	eval-mlogloss:0.56906
# [104]	train-mlogloss:0.31004	eval-mlogloss:0.56876
# [105]	train-mlogloss:0.30921	eval-mlogloss:0.56862
# [106]	train-mlogloss:0.30763	eval-mlogloss:0.56842
# [107]	train-mlogloss:0.30634	eval-mlogloss:0.56832
# [108]	train-mlogloss:0.30547	eval-mlogloss:0.56832
# [109]	train-mlogloss:0.30470	eval-mlogloss:0.56810
# [110]	train-mlogloss:0.30325	eval-mlogloss:0.56777
# [111]	train-mlogloss:0.30269	eval-mlogloss:0.56767
# [112]	train-mlogloss:0.30115	eval-mlogloss:0.56759
# [113]	train-mlogloss:0.30054	eval-mlogloss:0.56758
# [114]	train-mlogloss:0.29896	eval-mlogloss:0.56755
# [115]	train-mlogloss:0.29777	eval-mlogloss:0.56745
# [116]	train-mlogloss:0.29735	eval-mlogloss:0.56743
# [117]	train-mlogloss:0.29556	eval-mlogloss:0.56720
# [118]	train-mlogloss:0.29515	eval-mlogloss:0.56724
# [119]	train-mlogloss:0.29439	eval-mlogloss:0.56724
# [120]	train-mlogloss:0.29395	eval-mlogloss:0.56734
# [121]	train-mlogloss:0.29219	eval-mlogloss:0.56714
# [122]	train-mlogloss:0.29093	eval-mlogloss:0.56707
# [123]	train-mlogloss:0.29053	eval-mlogloss:0.56714
# [124]	train-mlogloss:0.28943	eval-mlogloss:0.56705
# [125]	train-mlogloss:0.28796	eval-mlogloss:0.56707
# [126]	train-mlogloss:0.28758	eval-mlogloss:0.56704
# [127]	train-mlogloss:0.28643	eval-mlogloss:0.56681
# [128]	train-mlogloss:0.28609	eval-mlogloss:0.56684
# [129]	train-mlogloss:0.28507	eval-mlogloss:0.56672
# [130]	train-mlogloss:0.28354	eval-mlogloss:0.56670
# [131]	train-mlogloss:0.28292	eval-mlogloss:0.56680
# [132]	train-mlogloss:0.28188	eval-mlogloss:0.56659
# [133]	train-mlogloss:0.28051	eval-mlogloss:0.56644
# [134]	train-mlogloss:0.28018	eval-mlogloss:0.56643
# [135]	train-mlogloss:0.27923	eval-mlogloss:0.56639
# [136]	train-mlogloss:0.27825	eval-mlogloss:0.56623
# [137]	train-mlogloss:0.27730	eval-mlogloss:0.56621
# [138]	train-mlogloss:0.27606	eval-mlogloss:0.56616
# [139]	train-mlogloss:0.27527	eval-mlogloss:0.56621
# [140]	train-mlogloss:0.27468	eval-mlogloss:0.56630
# [141]	train-mlogloss:0.27343	eval-mlogloss:0.56639
# [142]	train-mlogloss:0.27245	eval-mlogloss:0.56635
# [143]	train-mlogloss:0.27127	eval-mlogloss:0.56596
# [144]	train-mlogloss:0.27052	eval-mlogloss:0.56596
# [145]	train-mlogloss:0.26964	eval-mlogloss:0.56591
# [146]	train-mlogloss:0.26814	eval-mlogloss:0.56591
# [147]	train-mlogloss:0.26715	eval-mlogloss:0.56593
# [148]	train-mlogloss:0.26598	eval-mlogloss:0.56592
# [149]	train-mlogloss:0.26556	eval-mlogloss:0.56601
# [150]	train-mlogloss:0.26488	eval-mlogloss:0.56616
# [151]	train-mlogloss:0.26429	eval-mlogloss:0.56615
# [152]	train-mlogloss:0.26310	eval-mlogloss:0.56603
# [153]	train-mlogloss:0.26210	eval-mlogloss:0.56595
# [154]	train-mlogloss:0.26134	eval-mlogloss:0.56615
# [155]	train-mlogloss:0.26029	eval-mlogloss:0.56603
# [156]	train-mlogloss:0.25980	eval-mlogloss:0.56617
# [157]	train-mlogloss:0.25877	eval-mlogloss:0.56599
# [158]	train-mlogloss:0.25810	eval-mlogloss:0.56612
# [159]	train-mlogloss:0.25711	eval-mlogloss:0.56609
# [160]	train-mlogloss:0.25647	eval-mlogloss:0.56626
# [161]	train-mlogloss:0.25521	eval-mlogloss:0.56635
# [162]	train-mlogloss:0.25451	eval-mlogloss:0.56646
# [163]	train-mlogloss:0.25360	eval-mlogloss:0.56657
# [164]	train-mlogloss:0.25301	eval-mlogloss:0.56661
# [165]	train-mlogloss:0.25246	eval-mlogloss:0.56679
# [166]	train-mlogloss:0.25183	eval-mlogloss:0.56673
# [167]	train-mlogloss:0.25116	eval-mlogloss:0.56684
# [168]	train-mlogloss:0.25012	eval-mlogloss:0.56671
# [169]	train-mlogloss:0.24926	eval-mlogloss:0.56670
# [170]	train-mlogloss:0.24883	eval-mlogloss:0.56686
# [171]	train-mlogloss:0.24839	eval-mlogloss:0.56682
# [172]	train-mlogloss:0.24767	eval-mlogloss:0.56676
# [173]	train-mlogloss:0.24680	eval-mlogloss:0.56671
# [174]	train-mlogloss:0.24634	eval-mlogloss:0.56683
# [175]	train-mlogloss:0.24555	eval-mlogloss:0.56676
# [176]	train-mlogloss:0.24445	eval-mlogloss:0.56665
# [177]	train-mlogloss:0.24366	eval-mlogloss:0.56665
# [178]	train-mlogloss:0.24315	eval-mlogloss:0.56662
# [179]	train-mlogloss:0.24253	eval-mlogloss:0.56670
# [180]	train-mlogloss:0.24135	eval-mlogloss:0.56675
# [181]	train-mlogloss:0.24048	eval-mlogloss:0.56676
# [182]	train-mlogloss:0.23989	eval-mlogloss:0.56673
# [183]	train-mlogloss:0.23936	eval-mlogloss:0.56693
# [184]	train-mlogloss:0.23888	eval-mlogloss:0.56699
# [185]	train-mlogloss:0.23819	eval-mlogloss:0.56692
# [186]	train-mlogloss:0.23769	eval-mlogloss:0.56703
# [187]	train-mlogloss:0.23693	eval-mlogloss:0.56718
# [188]	train-mlogloss:0.23640	eval-mlogloss:0.56720
# [189]	train-mlogloss:0.23572	eval-mlogloss:0.56728
# [190]	train-mlogloss:0.23531	eval-mlogloss:0.56747
# [191]	train-mlogloss:0.23469	eval-mlogloss:0.56748
# [192]	train-mlogloss:0.23413	eval-mlogloss:0.56764
# [193]	train-mlogloss:0.23342	eval-mlogloss:0.56758
# [194]	train-mlogloss:0.23262	eval-mlogloss:0.56755
# [195]	train-mlogloss:0.23218	eval-mlogloss:0.56758
# [196]	train-mlogloss:0.23162	eval-mlogloss:0.56768
# [197]	train-mlogloss:0.23085	eval-mlogloss:0.56769
# [198]	train-mlogloss:0.23032	eval-mlogloss:0.56780
# [199]	train-mlogloss:0.22995	eval-mlogloss:0.56775
# [200]	train-mlogloss:0.22935	eval-mlogloss:0.56784
# [201]	train-mlogloss:0.22884	eval-mlogloss:0.56799
# [202]	train-mlogloss:0.22754	eval-mlogloss:0.56765
# [203]	train-mlogloss:0.22719	eval-mlogloss:0.56755
# [204]	train-mlogloss:0.22652	eval-mlogloss:0.56746
# [205]	train-mlogloss:0.22607	eval-mlogloss:0.56760
# [206]	train-mlogloss:0.22544	eval-mlogloss:0.56760
# [207]	train-mlogloss:0.22466	eval-mlogloss:0.56765
# [208]	train-mlogloss:0.22384	eval-mlogloss:0.56767
# [209]	train-mlogloss:0.22311	eval-mlogloss:0.56781
# [210]	train-mlogloss:0.22263	eval-mlogloss:0.56795
# [211]	train-mlogloss:0.22155	eval-mlogloss:0.56824
# [212]	train-mlogloss:0.22114	eval-mlogloss:0.56840
# [213]	train-mlogloss:0.22064	eval-mlogloss:0.56835
# [214]	train-mlogloss:0.22027	eval-mlogloss:0.56837
# [215]	train-mlogloss:0.21960	eval-mlogloss:0.56839
# [216]	train-mlogloss:0.21856	eval-mlogloss:0.56842
# [217]	train-mlogloss:0.21781	eval-mlogloss:0.56840
# [218]	train-mlogloss:0.21759	eval-mlogloss:0.56845
# [219]	train-mlogloss:0.21722	eval-mlogloss:0.56851
# [220]	train-mlogloss:0.21675	eval-mlogloss:0.56864
# [221]	train-mlogloss:0.21647	eval-mlogloss:0.56876
# [222]	train-mlogloss:0.21574	eval-mlogloss:0.56884
# [223]	train-mlogloss:0.21509	eval-mlogloss:0.56891
# [224]	train-mlogloss:0.21464	eval-mlogloss:0.56885
# [225]	train-mlogloss:0.21374	eval-mlogloss:0.56899
# [226]	train-mlogloss:0.21316	eval-mlogloss:0.56914
# [227]	train-mlogloss:0.21282	eval-mlogloss:0.56915
# [228]	train-mlogloss:0.21221	eval-mlogloss:0.56927
# [229]	train-mlogloss:0.21178	eval-mlogloss:0.56935
# [230]	train-mlogloss:0.21129	eval-mlogloss:0.56933
# [231]	train-mlogloss:0.21017	eval-mlogloss:0.56938
# [232]	train-mlogloss:0.20964	eval-mlogloss:0.56941
# [233]	train-mlogloss:0.20919	eval-mlogloss:0.56949
# [234]	train-mlogloss:0.20880	eval-mlogloss:0.56932
# [235]	train-mlogloss:0.20804	eval-mlogloss:0.56933
# [236]	train-mlogloss:0.20706	eval-mlogloss:0.56928
# [237]	train-mlogloss:0.20647	eval-mlogloss:0.56931
# [238]	train-mlogloss:0.20620	eval-mlogloss:0.56942
# [239]	train-mlogloss:0.20531	eval-mlogloss:0.56968
# [240]	train-mlogloss:0.20443	eval-mlogloss:0.56984
# [241]	train-mlogloss:0.20389	eval-mlogloss:0.56970
# [242]	train-mlogloss:0.20298	eval-mlogloss:0.56958
# [243]	train-mlogloss:0.20210	eval-mlogloss:0.56975
# [244]	train-mlogloss:0.20162	eval-mlogloss:0.56964
# [245]	train-mlogloss:0.20141	eval-mlogloss:0.56971

# %%
X_test_xgb = xgb.DMatrix(X_test)

target = train_scores.loc[X_test.index].copy()
predictions = bst.predict(X_test_xgb, iteration_range=(0, bst.best_iteration))
predictions = pd.DataFrame(predictions)

predictions[2] = 0
predictions.columns = [0,2,1]
predictions = (predictions.reindex(columns=[0,1,2]).rank(1,ascending=False)==1).astype(int).values
np.round(accuracy_score(predictions,target),4)
# Out:
# 0.4746

# %%
xgb.plot_importance(bst, max_num_features=10)
fig = plt.gcf()
fig.set_size_inches(15, 20)

# %%
# {feature_name: score}
importance_dict = bst.get_score(importance_type='weight')
sorted_features = sorted(importance_dict.items(), key=lambda x: x[1], reverse=True)
top_features = [feature for feature, score in sorted_features[:10]]
X_reduced = train_data[top_features]

# %%
plot_correlation_matrix(X_reduced, title="Correlation Matrix (X_reduced)")

# %%
num_cols = X_reduced.select_dtypes(include=[np.number]).columns
cat_cols = X_reduced.select_dtypes(include=["object", "category"]).columns

# %%
plot_univariate_analysis(X_reduced, numeric_cols=num_cols, categorical_cols=cat_cols)

# %%
# Store training data

train_data_path = PROCESSED_DATA_DIR / "train_data.csv"
train_data.to_csv(train_data_path, index=True)
